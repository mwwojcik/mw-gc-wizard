// %%
%use dataframe
%use kandy


import org.jetbrains.kotlinx.dataframe.io.readCSV
val dfRaw = DataFrame.readCSV("../gclogs/pauses.csv")


// print dataframe
dfRaw.columnsCount()
// Out:
// 16

// %%
dfRaw.convert { startedAt }.toLocalDateTime(kotlinx.datetime.TimeZone.UTC)
val df = dfRaw.sortBy { startedAt }

// %%
df.countDistinct{type}
// Out:
// 9

// %%
df.columnTypes()
// Out:
// [kotlin.String, kotlin.String, kotlinx.datetime.Instant, kotlin.Double, kotlin.String, kotlin.Double, kotlin.Double, kotlin.Double, kotlin.Int, kotlin.Int, kotlin.Int, kotlin.Int, kotlin.Int, kotlin.Int, kotlin.Int, kotlin.Int]

// %%
df.head(5)
// Out:
//         <html>
//         <head>
//             <style type="text/css">
//                 :root {
//     --background: #fff;
//     --background-odd: #f5f5f5;
//     --background-hover: #d9edfd;
//     --header-text-color: #474747;
//     --text-color: #848484;
//     --text-color-dark: #000;
//     --text-color-medium: #737373;
//     --text-color-pale: #b3b3b3;
//     --inner-border-color: #aaa;
//     --bold-border-color: #000;
//     --link-color: #296eaa;
//     --link-color-pale: #296eaa;
//     --link-hover: #1a466c;
// }
//
// :root[theme="dark"], :root [data-jp-theme-light="false"], .dataframe_dark{
//     --background: #303030;
//     --background-odd: #3c3c3c;
//     --background-hover: #464646;
//     --header-text-color: #dddddd;
//     --text-color: #b3b3b3;
//     --text-color-dark: #dddddd;
//     --text-color-medium: #b2b2b2;
//     --text-color-pale: #737373;
//     --inner-border-color: #707070;
//     --bold-border-color: #777777;
//     --link-color: #008dc0;
//     --link-color-pale: #97e1fb;
//     --link-hover: #00688e;
// }
//
// p.dataframe_description {
//     color: var(--text-color-dark);
// }
//
// table.dataframe {
//     font-family: "Helvetica Neue", Helvetica, Arial, sans-serif;
//     font-size: 12px;
//     background-color: var(--background);
//     color: var(--text-color-dark);
//     border: none;
//     border-collapse: collapse;
// }
//
// table.dataframe th, td {
//     padding: 6px;
//     border: 1px solid transparent;
//     text-align: left;
// }
//
// table.dataframe th {
//     background-color: var(--background);
//     color: var(--header-text-color);
// }
//
// table.dataframe td {
//     vertical-align: top;
// }
//
// table.dataframe th.bottomBorder {
//     border-bottom-color: var(--bold-border-color);
// }
//
// table.dataframe tbody > tr:nth-child(odd) {
//     background: var(--background-odd);
// }
//
// table.dataframe tbody > tr:nth-child(even) {
//     background: var(--background);
// }
//
// table.dataframe tbody > tr:hover {
//     background: var(--background-hover);
// }
//
// table.dataframe a {
//     cursor: pointer;
//     color: var(--link-color);
//     text-decoration: none;
// }
//
// table.dataframe tr:hover > td a {
//     color: var(--link-color-pale);
// }
//
// table.dataframe a:hover {
//     color: var(--link-hover);
//     text-decoration: underline;
// }
//
// table.dataframe img {
//     max-width: fit-content;
// }
//
// table.dataframe th.complex {
//     background-color: var(--background);
//     border: 1px solid var(--background);
// }
//
// table.dataframe .leftBorder {
//     border-left-color: var(--inner-border-color);
// }
//
// table.dataframe .rightBorder {
//     border-right-color: var(--inner-border-color);
// }
//
// table.dataframe .rightAlign {
//     text-align: right;
// }
//
// table.dataframe .expanderSvg {
//     width: 8px;
//     height: 8px;
//     margin-right: 3px;
// }
//
// table.dataframe .expander {
//     display: flex;
//     align-items: center;
// }
//
// /* formatting */
//
// table.dataframe .null {
//     color: var(--text-color-pale);
// }
//
// table.dataframe .structural {
//     color: var(--text-color-medium);
//     font-weight: bold;
// }
//
// table.dataframe .dataFrameCaption {
//     font-weight: bold;
// }
//
// table.dataframe .numbers {
//     color: var(--text-color-dark);
// }
//
// table.dataframe td:hover .formatted .structural, .null {
//     color: var(--text-color-dark);
// }
//
// table.dataframe tr:hover .formatted .structural, .null {
//     color: var(--text-color-dark);
// }
//
//
//
//
//             </style>
//         </head>
//         <body>
//
// <table class="dataframe" id="df_520093696"></table>
//
// <p class="dataframe_description">DataFrame: rowsCount = 5, columnsCount = 16</p>
//         </body>
//         <script>
//
// /*<!--*/
// call_DataFrame(function() { DataFrame.addTable({ cols: [{ name: "<span title=\"type: String\">type</span>", children: [], rightAlign: false, values: ["Young","Young","Young","Young","Young"] },
// { name: "<span title=\"event_type: String\">event_type</span>", children: [], rightAlign: false, values: ["PauseEvent","PauseEvent","PauseEvent","PauseEvent","PauseEvent"] },
// { name: "<span title=\"startedAt: kotlinx.datetime.Instant\">startedAt</span>", children: [], rightAlign: false, values: ["2023-07-18T16:38:34.550Z","2023-07-18T16:38:40.761Z","2023-07-18T16:38:47.252Z","2023-07-18T16:38:53.418Z","2023-07-18T16:38:58.973Z"] },
// { name: "<span title=\"duration: Double\">duration</span>", children: [], rightAlign: true, values: ["<span class=\"formatted\" title=\"\"><span class=\"numbers\">0,007961</span></span>","<span class=\"formatted\" title=\"\"><span class=\"numbers\">0,007288</span></span>","<span class=\"formatted\" title=\"\"><span class=\"numbers\">0,007701</span></span>","<span class=\"formatted\" title=\"\"><span class=\"numbers\">0,006213</span></span>","<span class=\"formatted\" title=\"\"><span class=\"numbers\">0,007023</span></span>"] },
// { name: "<span title=\"cause: String\">cause</span>", children: [], rightAlign: false, values: ["G1_EVACUATION_PAUSE","G1_EVACUATION_PAUSE","G1_EVACUATION_PAUSE","G1_EVACUATION_PAUSE","G1_EVACUATION_PAUSE"] },
// { name: "<span title=\"cpu_user: Double\">cpu_user</span>", children: [], rightAlign: true, values: ["<span class=\"formatted\" title=\"\"><span class=\"numbers\">0,02</span></span>","<span class=\"formatted\" title=\"\"><span class=\"numbers\">0,01</span></span>","<span class=\"formatted\" title=\"\"><span class=\"numbers\">0,01</span></span>","<span class=\"formatted\" title=\"\"><span class=\"numbers\">0,01</span></span>","<span class=\"formatted\" title=\"\"><span class=\"numbers\">0,01</span></span>"] },
// { name: "<span title=\"cpu_kernel: Double\">cpu_kernel</span>", children: [], rightAlign: true, values: ["<span class=\"formatted\" title=\"\"><span class=\"numbers\">0,0</span></span>","<span class=\"formatted\" title=\"\"><span class=\"numbers\">0,0</span></span>","<span class=\"formatted\" title=\"\"><span class=\"numbers\">0,0</span></span>","<span class=\"formatted\" title=\"\"><span class=\"numbers\">0,0</span></span>","<span class=\"formatted\" title=\"\"><span class=\"numbers\">0,0</span></span>"] },
// { name: "<span title=\"cpu_wallClock: Double\">cpu_wallClock</span>", children: [], rightAlign: true, values: ["<span class=\"formatted\" title=\"\"><span class=\"numbers\">0,01</span></span>","<span class=\"formatted\" title=\"\"><span class=\"numbers\">0,01</span></span>","<span class=\"formatted\" title=\"\"><span class=\"numbers\">0,01</span></span>","<span class=\"formatted\" title=\"\"><span class=\"numbers\">0,00</span></span>","<span class=\"formatted\" title=\"\"><span class=\"numbers\">0,01</span></span>"] },
// { name: "<span title=\"heap_occupancy_before_coll: Int\">heap_occupancy_before_coll</span>", children: [], rightAlign: true, values: ["<span class=\"formatted\" title=\"\"><span class=\"numbers\">742400</span></span>","<span class=\"formatted\" title=\"\"><span class=\"numbers\">751616</span></span>","<span class=\"formatted\" title=\"\"><span class=\"numbers\">745472</span></span>","<span class=\"formatted\" title=\"\"><span class=\"numbers\">746496</span></span>","<span class=\"formatted\" title=\"\"><span class=\"numbers\">733184</span></span>"] },
// { name: "<span title=\"heap_occupancy_after_coll: Int\">heap_occupancy_after_coll</span>", children: [], rightAlign: true, values: ["<span class=\"formatted\" title=\"\"><span class=\"numbers\">177152</span></span>","<span class=\"formatted\" title=\"\"><span class=\"numbers\">177152</span></span>","<span class=\"formatted\" title=\"\"><span class=\"numbers\">178176</span></span>","<span class=\"formatted\" title=\"\"><span class=\"numbers\">177152</span></span>","<span class=\"formatted\" title=\"\"><span class=\"numbers\">178176</span></span>"] },
// { name: "<span title=\"heap_size_before_coll: Int\">heap_size_before_coll</span>", children: [], rightAlign: true, values: ["<span class=\"formatted\" title=\"\"><span class=\"numbers\">921600</span></span>","<span class=\"formatted\" title=\"\"><span class=\"numbers\">921600</span></span>","<span class=\"formatted\" title=\"\"><span class=\"numbers\">921600</span></span>","<span class=\"formatted\" title=\"\"><span class=\"numbers\">921600</span></span>","<span class=\"formatted\" title=\"\"><span class=\"numbers\">921

// %%
df.maxBy{duration}
// Out:
//         <html>
//         <head>
//             <style type="text/css">
//                 :root {
//     --background: #fff;
//     --background-odd: #f5f5f5;
//     --background-hover: #d9edfd;
//     --header-text-color: #474747;
//     --text-color: #848484;
//     --text-color-dark: #000;
//     --text-color-medium: #737373;
//     --text-color-pale: #b3b3b3;
//     --inner-border-color: #aaa;
//     --bold-border-color: #000;
//     --link-color: #296eaa;
//     --link-color-pale: #296eaa;
//     --link-hover: #1a466c;
// }
//
// :root[theme="dark"], :root [data-jp-theme-light="false"], .dataframe_dark{
//     --background: #303030;
//     --background-odd: #3c3c3c;
//     --background-hover: #464646;
//     --header-text-color: #dddddd;
//     --text-color: #b3b3b3;
//     --text-color-dark: #dddddd;
//     --text-color-medium: #b2b2b2;
//     --text-color-pale: #737373;
//     --inner-border-color: #707070;
//     --bold-border-color: #777777;
//     --link-color: #008dc0;
//     --link-color-pale: #97e1fb;
//     --link-hover: #00688e;
// }
//
// p.dataframe_description {
//     color: var(--text-color-dark);
// }
//
// table.dataframe {
//     font-family: "Helvetica Neue", Helvetica, Arial, sans-serif;
//     font-size: 12px;
//     background-color: var(--background);
//     color: var(--text-color-dark);
//     border: none;
//     border-collapse: collapse;
// }
//
// table.dataframe th, td {
//     padding: 6px;
//     border: 1px solid transparent;
//     text-align: left;
// }
//
// table.dataframe th {
//     background-color: var(--background);
//     color: var(--header-text-color);
// }
//
// table.dataframe td {
//     vertical-align: top;
// }
//
// table.dataframe th.bottomBorder {
//     border-bottom-color: var(--bold-border-color);
// }
//
// table.dataframe tbody > tr:nth-child(odd) {
//     background: var(--background-odd);
// }
//
// table.dataframe tbody > tr:nth-child(even) {
//     background: var(--background);
// }
//
// table.dataframe tbody > tr:hover {
//     background: var(--background-hover);
// }
//
// table.dataframe a {
//     cursor: pointer;
//     color: var(--link-color);
//     text-decoration: none;
// }
//
// table.dataframe tr:hover > td a {
//     color: var(--link-color-pale);
// }
//
// table.dataframe a:hover {
//     color: var(--link-hover);
//     text-decoration: underline;
// }
//
// table.dataframe img {
//     max-width: fit-content;
// }
//
// table.dataframe th.complex {
//     background-color: var(--background);
//     border: 1px solid var(--background);
// }
//
// table.dataframe .leftBorder {
//     border-left-color: var(--inner-border-color);
// }
//
// table.dataframe .rightBorder {
//     border-right-color: var(--inner-border-color);
// }
//
// table.dataframe .rightAlign {
//     text-align: right;
// }
//
// table.dataframe .expanderSvg {
//     width: 8px;
//     height: 8px;
//     margin-right: 3px;
// }
//
// table.dataframe .expander {
//     display: flex;
//     align-items: center;
// }
//
// /* formatting */
//
// table.dataframe .null {
//     color: var(--text-color-pale);
// }
//
// table.dataframe .structural {
//     color: var(--text-color-medium);
//     font-weight: bold;
// }
//
// table.dataframe .dataFrameCaption {
//     font-weight: bold;
// }
//
// table.dataframe .numbers {
//     color: var(--text-color-dark);
// }
//
// table.dataframe td:hover .formatted .structural, .null {
//     color: var(--text-color-dark);
// }
//
// table.dataframe tr:hover .formatted .structural, .null {
//     color: var(--text-color-dark);
// }
//
//
//
//
//             </style>
//         </head>
//         <body>
//
// <table class="dataframe" id="df_520093697"></table>
//
// <p class="dataframe_description">DataRow: index = 13510, columnsCount = 16</p>
//         </body>
//         <script>
//
// /*<!--*/
// call_DataFrame(function() { DataFrame.addTable({ cols: [{ name: "<span title=\"type: String\">type</span>", children: [], rightAlign: false, values: ["G1GCConcurrentCleanup"] },
// { name: "<span title=\"event_type: String\">event_type</span>", children: [], rightAlign: false, values: ["ConcurrentEvent"] },
// { name: "<span title=\"startedAt: kotlinx.datetime.Instant\">startedAt</span>", children: [], rightAlign: false, values: ["2023-07-19T10:20:59.560Z"] },
// { name: "<span title=\"duration: Double\">duration</span>", children: [], rightAlign: true, values: ["<span class=\"formatted\" title=\"\"><span class=\"numbers\">0,07057</span></span>"] },
// { name: "<span title=\"cause: String\">cause</span>", children: [], rightAlign: false, values: ["GCCAUSE_NOT_SET"] },
// { name: "<span title=\"cpu_user: Double\">cpu_user</span>", children: [], rightAlign: true, values: ["<span class=\"formatted\" title=\"\"><span class=\"numbers\">0,0</span></span>"] },
// { name: "<span title=\"cpu_kernel: Double\">cpu_kernel</span>", children: [], rightAlign: true, values: ["<span class=\"formatted\" title=\"\"><span class=\"numbers\">0,0</span></span>"] },
// { name: "<span title=\"cpu_wallClock: Double\">cpu_wallClock</span>", children: [], rightAlign: true, values: ["<span class=\"formatted\" title=\"\"><span class=\"numbers\">0,0</span></span>"] },
// { name: "<span title=\"heap_occupancy_before_coll: Int\">heap_occupancy_before_coll</span>", children: [], rightAlign: true, values: ["<span class=\"formatted\" title=\"\"><span class=\"numbers\">0</span></span>"] },
// { name: "<span title=\"heap_occupancy_after_coll: Int\">heap_occupancy_after_coll</span>", children: [], rightAlign: true, values: ["<span class=\"formatted\" title=\"\"><span class=\"numbers\">0</span></span>"] },
// { name: "<span title=\"heap_size_before_coll: Int\">heap_size_before_coll</span>", children: [], rightAlign: true, values: ["<span class=\"formatted\" title=\"\"><span class=\"numbers\">0</span></span>"] },
// { name: "<span title=\"heap_size_after_coll: Int\">heap_size_after_coll</span>", children: [], rightAlign: true, values: ["<span class=\"formatted\" title=\"\"><span class=\"numbers\">0</span></span>"] },
// { name: "<span title=\"perm_or_meta_occupancy_before_coll: Int\">perm_or_meta_occupancy_before_coll</span>", children: [], rightAlign: true, values: ["<span class=\"formatted\" title=\"\"><span class=\"numbers\">0</span></span>"] },
// { name: "<span title=\"perm_or_meta_occupancy_after_coll: Int\">perm_or_meta_occupancy_after_coll</span>", children: [], rightAlign: true, values: ["<span class=\"formatted\" title=\"\"><span class=\"numbers\">0</span></span>"] },
// { name: "<span title=\"perm_or_meta_size_before_coll: Int\">perm_or_meta_size_before_coll</span>", children: [], rightAlign: true, values: ["<span class=\"formatted\" title=\"\"><span class=\"numbers\">0</span></span>"] },
// { name: "<span title=\"perm_or_meta_size_after_coll: Int\">perm_or_meta_size_after_coll</span>", children: [], rightAlign: true, values: ["<span class=\"formatted\" title=\"\"><span class=\"numbers\">0</span></span>"] },
// ], id: 520093697, rootId: 520093697, totalRows: 1 } ) });
// /*-->*/
//
// call_DataFrame(function() { DataFrame.renderTable(520093697) });
//
//
//         </script>
//         </html>

// %%
df.groupBy{type}.sum()
// Out:
//         <html>
//         <head>
//             <style type="text/css">
//                 :root {
//     --background: #fff;
//     --background-odd: #f5f5f5;
//     --background-hover: #d9edfd;
//     --header-text-color: #474747;
//     --text-color: #848484;
//     --text-color-dark: #000;
//     --text-color-medium: #737373;
//     --text-color-pale: #b3b3b3;
//     --inner-border-color: #aaa;
//     --bold-border-color: #000;
//     --link-color: #296eaa;
//     --link-color-pale: #296eaa;
//     --link-hover: #1a466c;
// }
//
// :root[theme="dark"], :root [data-jp-theme-light="false"], .dataframe_dark{
//     --background: #303030;
//     --background-odd: #3c3c3c;
//     --background-hover: #464646;
//     --header-text-color: #dddddd;
//     --text-color: #b3b3b3;
//     --text-color-dark: #dddddd;
//     --text-color-medium: #b2b2b2;
//     --text-color-pale: #737373;
//     --inner-border-color: #707070;
//     --bold-border-color: #777777;
//     --link-color: #008dc0;
//     --link-color-pale: #97e1fb;
//     --link-hover: #00688e;
// }
//
// p.dataframe_description {
//     color: var(--text-color-dark);
// }
//
// table.dataframe {
//     font-family: "Helvetica Neue", Helvetica, Arial, sans-serif;
//     font-size: 12px;
//     background-color: var(--background);
//     color: var(--text-color-dark);
//     border: none;
//     border-collapse: collapse;
// }
//
// table.dataframe th, td {
//     padding: 6px;
//     border: 1px solid transparent;
//     text-align: left;
// }
//
// table.dataframe th {
//     background-color: var(--background);
//     color: var(--header-text-color);
// }
//
// table.dataframe td {
//     vertical-align: top;
// }
//
// table.dataframe th.bottomBorder {
//     border-bottom-color: var(--bold-border-color);
// }
//
// table.dataframe tbody > tr:nth-child(odd) {
//     background: var(--background-odd);
// }
//
// table.dataframe tbody > tr:nth-child(even) {
//     background: var(--background);
// }
//
// table.dataframe tbody > tr:hover {
//     background: var(--background-hover);
// }
//
// table.dataframe a {
//     cursor: pointer;
//     color: var(--link-color);
//     text-decoration: none;
// }
//
// table.dataframe tr:hover > td a {
//     color: var(--link-color-pale);
// }
//
// table.dataframe a:hover {
//     color: var(--link-hover);
//     text-decoration: underline;
// }
//
// table.dataframe img {
//     max-width: fit-content;
// }
//
// table.dataframe th.complex {
//     background-color: var(--background);
//     border: 1px solid var(--background);
// }
//
// table.dataframe .leftBorder {
//     border-left-color: var(--inner-border-color);
// }
//
// table.dataframe .rightBorder {
//     border-right-color: var(--inner-border-color);
// }
//
// table.dataframe .rightAlign {
//     text-align: right;
// }
//
// table.dataframe .expanderSvg {
//     width: 8px;
//     height: 8px;
//     margin-right: 3px;
// }
//
// table.dataframe .expander {
//     display: flex;
//     align-items: center;
// }
//
// /* formatting */
//
// table.dataframe .null {
//     color: var(--text-color-pale);
// }
//
// table.dataframe .structural {
//     color: var(--text-color-medium);
//     font-weight: bold;
// }
//
// table.dataframe .dataFrameCaption {
//     font-weight: bold;
// }
//
// table.dataframe .numbers {
//     color: var(--text-color-dark);
// }
//
// table.dataframe td:hover .formatted .structural, .null {
//     color: var(--text-color-dark);
// }
//
// table.dataframe tr:hover .formatted .structural, .null {
//     color: var(--text-color-dark);
// }
//
//
//
//
//             </style>
//         </head>
//         <body>
//
// <table class="dataframe" id="df_520093698"></table>
//
// <p class="dataframe_description">DataFrame: rowsCount = 9, columnsCount = 13</p>
//         </body>
//         <script>
//
// /*<!--*/
// call_DataFrame(function() { DataFrame.addTable({ cols: [{ name: "<span title=\"type: String\">type</span>", children: [], rightAlign: false, values: ["Young","G1GCYoungInitialMark","G1GCConcurrentUndoCycle","ConcurrentCleanupForNextMark","ConcurrentClearClaimedMarks","ConcurrentRootRegionScan","G1GCRemark","G1GCConcurrentCleanup","Mixed"] },
// { name: "<span title=\"duration: Double\">duration</span>", children: [], rightAlign: true, values: ["<span class=\"formatted\" title=\"\"><span class=\"numbers\">67,066846</span></span>","<span class=\"formatted\" title=\"\"><span class=\"numbers\">13,436891</span></span>","<span class=\"formatted\" title=\"\"><span class=\"numbers\">3,207935</span></span>","<span class=\"formatted\" title=\"\"><span class=\"numbers\">3,305661</span></span>","<span class=\"formatted\" title=\"\"><span class=\"numbers\">0,008007</span></span>","<span class=\"formatted\" title=\"\"><span class=\"numbers\">0,330179</span></span>","<span class=\"formatted\" title=\"\"><span class=\"numbers\">2,622695</span></span>","<span class=\"formatted\" title=\"\"><span class=\"numbers\">6,468582</span></span>","<span class=\"formatted\" title=\"\"><span class=\"numbers\">0,659336</span></span>"] },
// { name: "<span title=\"cpu_user: Double\">cpu_user</span>", children: [], rightAlign: true, values: ["<span class=\"formatted\" title=\"\"><span class=\"numbers\">112,820000</span></span>","<span class=\"formatted\" title=\"\"><span class=\"numbers\">23,190000</span></span>","<span class=\"formatted\" title=\"\"><span class=\"numbers\">0,000000</span></span>","<span class=\"formatted\" title=\"\"><span class=\"numbers\">0,000000</span></span>","<span class=\"formatted\" title=\"\"><span class=\"numbers\">0,000000</span></span>","<span class=\"formatted\" title=\"\"><span class=\"numbers\">0,000000</span></span>","<span class=\"formatted\" title=\"\"><span class=\"numbers\">4,730000</span></span>","<span class=\"formatted\" title=\"\"><span class=\"numbers\">0,000000</span></span>","<span class=\"formatted\" title=\"\"><span class=\"numbers\">1,100000</span></span>"] },
// { name: "<span title=\"cpu_kernel: Double\">cpu_kernel</span>", children: [], rightAlign: true, values: ["<span class=\"formatted\" title=\"\"><span class=\"numbers\">16,510000</span></span>","<span class=\"formatted\" title=\"\"><span class=\"numbers\">2,640000</span></span>","<span class=\"formatted\" title=\"\"><span class=\"numbers\">0,000000</span></span>","<span class=\"formatted\" title=\"\"><span class=\"numbers\">0,000000</span></span>","<span class=\"formatted\" title=\"\"><span class=\"numbers\">0,000000</span></span>","<span class=\"formatted\" title=\"\"><span class=\"numbers\">0,000000</span></span>","<span class=\"formatted\" title=\"\"><span class=\"numbers\">0,530000</span></span>","<span class=\"formatted\" title=\"\"><span class=\"numbers\">0,000000</span></span>","<span class=\"formatted\" title=\"\"><span class=\"numbers\">0,120000</span></span>"] },
// { name: "<span title=\"cpu_wallClock: Double\">cpu_wallClock</span>", children: [], rightAlign: true, values: ["<span class=\"formatted\" title=\"\"><span class=\"numbers\">66,750000</span></span>","<span class=\"formatted\" title=\"\"><span class=\"numbers\">13,290000</span></span>","<span class=\"formatted\" title=\"\"><span class=\"numbers\">0,000000</span></span>","<span class=\"formatted\" title=\"\"><span class=\"numbers\">0,000000</span></span>","<span class=\"formatted\" title=\"\"><span class=\"numbers\">0,000000</span></span>","<span class=\"formatted\" title=\"\"><span class=\"numbers\">0,000000</span></span>","<span class=\"formatted\" title=\"\"><span class=\"numbers\">2,750000</span></span>","<span class=\"formatted\" title=\"\"><span class=\"numbers\">0,000000</span></span>","<span class=\"formatted\" title=\"\"><span class=\"numbers\">0,640000</span></span>"] },
// { name: "<span title=\"heap_occupancy_before_coll: Int\">heap_occupancy_before_coll</span>", children: [], rightAlign: true, values: ["<span class=\"formatted\" title=\"\"><span class=\"numbers\">-187524096</span></span>","<span class=\"formatted\" title=\"\"><span class=\"numbers\">1177003008</span></span>","<span class=\"formatted\" title=\"\"><span class=\"numbers\">0</span></span>","<span class=\"formatted\" title=\"\"><span class=\"numbers\">0</span></span>","<span class=\"formatted\" title=\"\"><span class=\"numbers\">0</span></span>","<span class=\"formatted\" title=\"\"><span class=\"numbers\">0</span></span>","<span class=\"formatted\" title=\"\"><span class=\"numbers\">152

// %%
df.filter { type == "Young" }.sortByDesc{duration}.head(5)
// Out:
//         <html>
//         <head>
//             <style type="text/css">
//                 :root {
//     --background: #fff;
//     --background-odd: #f5f5f5;
//     --background-hover: #d9edfd;
//     --header-text-color: #474747;
//     --text-color: #848484;
//     --text-color-dark: #000;
//     --text-color-medium: #737373;
//     --text-color-pale: #b3b3b3;
//     --inner-border-color: #aaa;
//     --bold-border-color: #000;
//     --link-color: #296eaa;
//     --link-color-pale: #296eaa;
//     --link-hover: #1a466c;
// }
//
// :root[theme="dark"], :root [data-jp-theme-light="false"], .dataframe_dark{
//     --background: #303030;
//     --background-odd: #3c3c3c;
//     --background-hover: #464646;
//     --header-text-color: #dddddd;
//     --text-color: #b3b3b3;
//     --text-color-dark: #dddddd;
//     --text-color-medium: #b2b2b2;
//     --text-color-pale: #737373;
//     --inner-border-color: #707070;
//     --bold-border-color: #777777;
//     --link-color: #008dc0;
//     --link-color-pale: #97e1fb;
//     --link-hover: #00688e;
// }
//
// p.dataframe_description {
//     color: var(--text-color-dark);
// }
//
// table.dataframe {
//     font-family: "Helvetica Neue", Helvetica, Arial, sans-serif;
//     font-size: 12px;
//     background-color: var(--background);
//     color: var(--text-color-dark);
//     border: none;
//     border-collapse: collapse;
// }
//
// table.dataframe th, td {
//     padding: 6px;
//     border: 1px solid transparent;
//     text-align: left;
// }
//
// table.dataframe th {
//     background-color: var(--background);
//     color: var(--header-text-color);
// }
//
// table.dataframe td {
//     vertical-align: top;
// }
//
// table.dataframe th.bottomBorder {
//     border-bottom-color: var(--bold-border-color);
// }
//
// table.dataframe tbody > tr:nth-child(odd) {
//     background: var(--background-odd);
// }
//
// table.dataframe tbody > tr:nth-child(even) {
//     background: var(--background);
// }
//
// table.dataframe tbody > tr:hover {
//     background: var(--background-hover);
// }
//
// table.dataframe a {
//     cursor: pointer;
//     color: var(--link-color);
//     text-decoration: none;
// }
//
// table.dataframe tr:hover > td a {
//     color: var(--link-color-pale);
// }
//
// table.dataframe a:hover {
//     color: var(--link-hover);
//     text-decoration: underline;
// }
//
// table.dataframe img {
//     max-width: fit-content;
// }
//
// table.dataframe th.complex {
//     background-color: var(--background);
//     border: 1px solid var(--background);
// }
//
// table.dataframe .leftBorder {
//     border-left-color: var(--inner-border-color);
// }
//
// table.dataframe .rightBorder {
//     border-right-color: var(--inner-border-color);
// }
//
// table.dataframe .rightAlign {
//     text-align: right;
// }
//
// table.dataframe .expanderSvg {
//     width: 8px;
//     height: 8px;
//     margin-right: 3px;
// }
//
// table.dataframe .expander {
//     display: flex;
//     align-items: center;
// }
//
// /* formatting */
//
// table.dataframe .null {
//     color: var(--text-color-pale);
// }
//
// table.dataframe .structural {
//     color: var(--text-color-medium);
//     font-weight: bold;
// }
//
// table.dataframe .dataFrameCaption {
//     font-weight: bold;
// }
//
// table.dataframe .numbers {
//     color: var(--text-color-dark);
// }
//
// table.dataframe td:hover .formatted .structural, .null {
//     color: var(--text-color-dark);
// }
//
// table.dataframe tr:hover .formatted .structural, .null {
//     color: var(--text-color-dark);
// }
//
//
//
//
//             </style>
//         </head>
//         <body>
//
// <table class="dataframe" id="df_520093699"></table>
//
// <p class="dataframe_description">DataFrame: rowsCount = 5, columnsCount = 16</p>
//         </body>
//         <script>
//
// /*<!--*/
// call_DataFrame(function() { DataFrame.addTable({ cols: [{ name: "<span title=\"type: String\">type</span>", children: [], rightAlign: false, values: ["Young","Young","Young","Young","Young"] },
// { name: "<span title=\"event_type: String\">event_type</span>", children: [], rightAlign: false, values: ["PauseEvent","PauseEvent","PauseEvent","PauseEvent","PauseEvent"] },
// { name: "<span title=\"startedAt: kotlinx.datetime.Instant\">startedAt</span>", children: [], rightAlign: false, values: ["2023-07-18T18:58:28.469Z","2023-07-18T17:36:38.308Z","2023-07-18T17:18:37.791Z","2023-07-18T18:17:34.970Z","2023-07-18T21:14:14.051Z"] },
// { name: "<span title=\"duration: Double\">duration</span>", children: [], rightAlign: true, values: ["<span class=\"formatted\" title=\"\"><span class=\"numbers\">0,013244</span></span>","<span class=\"formatted\" title=\"\"><span class=\"numbers\">0,012320</span></span>","<span class=\"formatted\" title=\"\"><span class=\"numbers\">0,012031</span></span>","<span class=\"formatted\" title=\"\"><span class=\"numbers\">0,011940</span></span>","<span class=\"formatted\" title=\"\"><span class=\"numbers\">0,011532</span></span>"] },
// { name: "<span title=\"cause: String\">cause</span>", children: [], rightAlign: false, values: ["G1_EVACUATION_PAUSE","G1_EVACUATION_PAUSE","G1_EVACUATION_PAUSE","G1_EVACUATION_PAUSE","G1_EVACUATION_PAUSE"] },
// { name: "<span title=\"cpu_user: Double\">cpu_user</span>", children: [], rightAlign: true, values: ["<span class=\"formatted\" title=\"\"><span class=\"numbers\">0,02</span></span>","<span class=\"formatted\" title=\"\"><span class=\"numbers\">0,01</span></span>","<span class=\"formatted\" title=\"\"><span class=\"numbers\">0,02</span></span>","<span class=\"formatted\" title=\"\"><span class=\"numbers\">0,01</span></span>","<span class=\"formatted\" title=\"\"><span class=\"numbers\">0,02</span></span>"] },
// { name: "<span title=\"cpu_kernel: Double\">cpu_kernel</span>", children: [], rightAlign: true, values: ["<span class=\"formatted\" title=\"\"><span class=\"numbers\">0,00</span></span>","<span class=\"formatted\" title=\"\"><span class=\"numbers\">0,01</span></span>","<span class=\"formatted\" title=\"\"><span class=\"numbers\">0,00</span></span>","<span class=\"formatted\" title=\"\"><span class=\"numbers\">0,00</span></span>","<span class=\"formatted\" title=\"\"><span class=\"numbers\">0,00</span></span>"] },
// { name: "<span title=\"cpu_wallClock: Double\">cpu_wallClock</span>", children: [], rightAlign: true, values: ["<span class=\"formatted\" title=\"\"><span class=\"numbers\">0,01</span></span>","<span class=\"formatted\" title=\"\"><span class=\"numbers\">0,01</span></span>","<span class=\"formatted\" title=\"\"><span class=\"numbers\">0,01</span></span>","<span class=\"formatted\" title=\"\"><span class=\"numbers\">0,01</span></span>","<span class=\"formatted\" title=\"\"><span class=\"numbers\">0,01</span></span>"] },
// { name: "<span title=\"heap_occupancy_before_coll: Int\">heap_occupancy_before_coll</span>", children: [], rightAlign: true, values: ["<span class=\"formatted\" title=\"\"><span class=\"numbers\">750592</span></span>","<span class=\"formatted\" title=\"\"><span class=\"numbers\">746496</span></span>","<span class=\"formatted\" title=\"\"><span class=\"numbers\">729088</span></span>","<span class=\"formatted\" title=\"\"><span class=\"numbers\">765952</span></span>","<span class=\"formatted\" title=\"\"><span class=\"numbers\">726016</span></span>"] },
// { name: "<span title=\"heap_occupancy_after_coll: Int\">heap_occupancy_after_coll</span>", children: [], rightAlign: true, values: ["<span class=\"formatted\" title=\"\"><span class=\"numbers\">162816</span></span>","<span class=\"formatted\" title=\"\"><span class=\"numbers\">167936</span></span>","<span class=\"formatted\" title=\"\"><span class=\"numbers\">151552</span></span>","<span class=\"formatted\" title=\"\"><span class=\"numbers\">205824</span></span>","<span class=\"formatted\" title=\"\"><span class=\"numbers\">138240</span></span>"] },
// { name: "<span title=\"heap_size_before_coll: Int\">heap_size_before_coll</span>", children: [], rightAlign: true, values: ["<span class=\"formatted\" title=\"\"><span class=\"numbers\">921600</span></span>","<span class=\"formatted\" title=\"\"><span class=\"numbers\">921600</span></span>","<span class=\"formatted\" title=\"\"><span class=\"numbers\">921600</span></span>","<span class=\"formatted\" title=\"\"><span class=\"numbers\">921600</span></span>","<span class=\"formatted\" title=\"\"><span class=\"numbers\

// %%
df.schema()
// Out:
// type: String
// event_type: String
// startedAt: kotlinx.datetime.Instant
// duration: Double
// cause: String
// cpu_user: Double
// cpu_kernel: Double
// cpu_wallClock: Double
// heap_occupancy_before_coll: Int
// heap_occupancy_after_coll: Int
// heap_size_before_coll: Int
// heap_size_after_coll: Int
// perm_or_meta_occupancy_before_coll: Int
// perm_or_meta_occupancy_after_coll: Int
// perm_or_meta_size_before_coll: Int
// perm_or_meta_size_after_coll: Int

// %%
df.groupBy{cause}.count()
// Out:
//         <html>
//         <head>
//             <style type="text/css">
//                 :root {
//     --background: #fff;
//     --background-odd: #f5f5f5;
//     --background-hover: #d9edfd;
//     --header-text-color: #474747;
//     --text-color: #848484;
//     --text-color-dark: #000;
//     --text-color-medium: #737373;
//     --text-color-pale: #b3b3b3;
//     --inner-border-color: #aaa;
//     --bold-border-color: #000;
//     --link-color: #296eaa;
//     --link-color-pale: #296eaa;
//     --link-hover: #1a466c;
// }
//
// :root[theme="dark"], :root [data-jp-theme-light="false"], .dataframe_dark{
//     --background: #303030;
//     --background-odd: #3c3c3c;
//     --background-hover: #464646;
//     --header-text-color: #dddddd;
//     --text-color: #b3b3b3;
//     --text-color-dark: #dddddd;
//     --text-color-medium: #b2b2b2;
//     --text-color-pale: #737373;
//     --inner-border-color: #707070;
//     --bold-border-color: #777777;
//     --link-color: #008dc0;
//     --link-color-pale: #97e1fb;
//     --link-hover: #00688e;
// }
//
// p.dataframe_description {
//     color: var(--text-color-dark);
// }
//
// table.dataframe {
//     font-family: "Helvetica Neue", Helvetica, Arial, sans-serif;
//     font-size: 12px;
//     background-color: var(--background);
//     color: var(--text-color-dark);
//     border: none;
//     border-collapse: collapse;
// }
//
// table.dataframe th, td {
//     padding: 6px;
//     border: 1px solid transparent;
//     text-align: left;
// }
//
// table.dataframe th {
//     background-color: var(--background);
//     color: var(--header-text-color);
// }
//
// table.dataframe td {
//     vertical-align: top;
// }
//
// table.dataframe th.bottomBorder {
//     border-bottom-color: var(--bold-border-color);
// }
//
// table.dataframe tbody > tr:nth-child(odd) {
//     background: var(--background-odd);
// }
//
// table.dataframe tbody > tr:nth-child(even) {
//     background: var(--background);
// }
//
// table.dataframe tbody > tr:hover {
//     background: var(--background-hover);
// }
//
// table.dataframe a {
//     cursor: pointer;
//     color: var(--link-color);
//     text-decoration: none;
// }
//
// table.dataframe tr:hover > td a {
//     color: var(--link-color-pale);
// }
//
// table.dataframe a:hover {
//     color: var(--link-hover);
//     text-decoration: underline;
// }
//
// table.dataframe img {
//     max-width: fit-content;
// }
//
// table.dataframe th.complex {
//     background-color: var(--background);
//     border: 1px solid var(--background);
// }
//
// table.dataframe .leftBorder {
//     border-left-color: var(--inner-border-color);
// }
//
// table.dataframe .rightBorder {
//     border-right-color: var(--inner-border-color);
// }
//
// table.dataframe .rightAlign {
//     text-align: right;
// }
//
// table.dataframe .expanderSvg {
//     width: 8px;
//     height: 8px;
//     margin-right: 3px;
// }
//
// table.dataframe .expander {
//     display: flex;
//     align-items: center;
// }
//
// /* formatting */
//
// table.dataframe .null {
//     color: var(--text-color-pale);
// }
//
// table.dataframe .structural {
//     color: var(--text-color-medium);
//     font-weight: bold;
// }
//
// table.dataframe .dataFrameCaption {
//     font-weight: bold;
// }
//
// table.dataframe .numbers {
//     color: var(--text-color-dark);
// }
//
// table.dataframe td:hover .formatted .structural, .null {
//     color: var(--text-color-dark);
// }
//
// table.dataframe tr:hover .formatted .structural, .null {
//     color: var(--text-color-dark);
// }
//
//
//
//
//             </style>
//         </head>
//         <body>
//
// <table class="dataframe" id="df_520093700"></table>
//
// <p class="dataframe_description">DataFrame: rowsCount = 5, columnsCount = 2</p>
//         </body>
//         <script>
//
// /*<!--*/
// call_DataFrame(function() { DataFrame.addTable({ cols: [{ name: "<span title=\"cause: String\">cause</span>", children: [], rightAlign: false, values: ["G1_EVACUATION_PAUSE","G1_HUMONGOUS_ALLOCATION","GCCAUSE_NOT_SET","UNKNOWN_GCCAUSE","GC_LOCKER"] },
// { name: "<span title=\"count: Int\">count</span>", children: [], rightAlign: true, values: ["<span class=\"formatted\" title=\"\"><span class=\"numbers\">11626</span></span>","<span class=\"formatted\" title=\"\"><span class=\"numbers\">2196</span></span>","<span class=\"formatted\" title=\"\"><span class=\"numbers\">2208</span></span>","<span class=\"formatted\" title=\"\"><span class=\"numbers\">2547</span></span>","<span class=\"formatted\" title=\"\"><span class=\"numbers\">45</span></span>"] },
// ], id: 520093700, rootId: 520093700, totalRows: 5 } ) });
// /*-->*/
//
// call_DataFrame(function() { DataFrame.renderTable(520093700) });
//
//
//         </script>
//         </html>

// %%
df.valueCounts(false) { type }.plot {
    bars {
        x(type)
        y("count")
        fillColor(type) {
            scale = categoricalColorHue()
            legend.type = legend.none()
        }
    }
    layout.title = "Pauses type count"
    layout.size = 950 to 500
}
// Out:
// Line_39.jupyter.kts (7:34 - 38) Unresolved reference. None of the following candidates is applicable because of receiver type mismatch:
// public fun <T> Array<out TypeVariable(T)>.none(): Boolean defined in kotlin.collections
// public inline fun <T> Array<out TypeVariable(T)>.none(predicate: (TypeVariable(T)) -> Boolean): Boolean defined in kotlin.collections
// public fun BooleanArray.none(): Boolean defined in kotlin.collections
// public inline fun BooleanArray.none(predicate: (Boolean) -> Boolean): Boolean defined in kotlin.collections
// public fun ByteArray.none(): Boolean defined in kotlin.collections
// public inline fun ByteArray.none(predicate: (Byte) -> Boolean): Boolean defined in kotlin.collections
// public fun CharArray.none(): Boolean defined in kotlin.collections
// public inline fun CharArray.none(predicate: (Char) -> Boolean): Boolean defined in kotlin.collections
// public fun CharSequence.none(): Boolean defined in kotlin.text
// public inline fun CharSequence.none(predicate: (Char) -> Boolean): Boolean defined in kotlin.text
// public fun DoubleArray.none(): Boolean defined in kotlin.collections
// public inline fun DoubleArray.none(predicate: (Double) -> Boolean): Boolean defined in kotlin.collections
// public fun FloatArray.none(): Boolean defined in kotlin.collections
// public inline fun FloatArray.none(predicate: (Float) -> Boolean): Boolean defined in kotlin.collections
// public fun IntArray.none(): Boolean defined in kotlin.collections
// public inline fun IntArray.none(predicate: (Int) -> Boolean): Boolean defined in kotlin.collections
// public fun LongArray.none(): Boolean defined in kotlin.collections
// public inline fun LongArray.none(predicate: (Long) -> Boolean): Boolean defined in kotlin.collections
// public fun ShortArray.none(): Boolean defined in kotlin.collections
// public inline fun ShortArray.none(predicate: (Short) -> Boolean): Boolean defined in kotlin.collections
// public inline fun UByteArray.none(): Boolean defined in kotlin.collections
// public inline fun UByteArray.none(predicate: (UByte) -> Boolean): Boolean defined in kotlin.collections
// public inline fun UIntArray.none(): Boolean defined in kotlin.collections
// public inline fun UIntArray.none(predicate: (UInt) -> Boolean): Boolean defined in kotlin.collections
// public inline fun ULongArray.none(): Boolean defined in kotlin.collections
// public inline fun ULongArray.none(predicate: (ULong) -> Boolean): Boolean defined in kotlin.collections
// public inline fun UShortArray.none(): Boolean defined in kotlin.collections
// public inline fun UShortArray.none(predicate: (UShort) -> Boolean): Boolean defined in kotlin.collections
// public fun <T> Iterable<TypeVariable(T)>.none(): Boolean defined in kotlin.collections
// public inline fun <T> Iterable<TypeVariable(T)>.none(predicate: (TypeVariable(T)) -> Boolean): Boolean defined in kotlin.collections
// public fun <K, V> Map<out TypeVariable(K), TypeVariable(V)>.none(): Boolean defined in kotlin.collections
// public inline fun <K, V> Map<out TypeVariable(K), TypeVariable(V)>.none(predicate: (Map.Entry<TypeVariable(K), TypeVariable(V)>) -> Boolean): Boolean defined in kotlin.collections
// public fun <T> Sequence<TypeVariable(T)>.none(): Boolean defined in kotlin.sequences
// public inline fun <T> Sequence<TypeVariable(T)>.none(predicate: (TypeVariable(T)) -> Boolean): Boolean defined in kotlin.sequences

// %%
df.describe()
// Out:
//         <html>
//         <head>
//             <style type="text/css">
//                 :root {
//     --background: #fff;
//     --background-odd: #f5f5f5;
//     --background-hover: #d9edfd;
//     --header-text-color: #474747;
//     --text-color: #848484;
//     --text-color-dark: #000;
//     --text-color-medium: #737373;
//     --text-color-pale: #b3b3b3;
//     --inner-border-color: #aaa;
//     --bold-border-color: #000;
//     --link-color: #296eaa;
//     --link-color-pale: #296eaa;
//     --link-hover: #1a466c;
// }
//
// :root[theme="dark"], :root [data-jp-theme-light="false"], .dataframe_dark{
//     --background: #303030;
//     --background-odd: #3c3c3c;
//     --background-hover: #464646;
//     --header-text-color: #dddddd;
//     --text-color: #b3b3b3;
//     --text-color-dark: #dddddd;
//     --text-color-medium: #b2b2b2;
//     --text-color-pale: #737373;
//     --inner-border-color: #707070;
//     --bold-border-color: #777777;
//     --link-color: #008dc0;
//     --link-color-pale: #97e1fb;
//     --link-hover: #00688e;
// }
//
// p.dataframe_description {
//     color: var(--text-color-dark);
// }
//
// table.dataframe {
//     font-family: "Helvetica Neue", Helvetica, Arial, sans-serif;
//     font-size: 12px;
//     background-color: var(--background);
//     color: var(--text-color-dark);
//     border: none;
//     border-collapse: collapse;
// }
//
// table.dataframe th, td {
//     padding: 6px;
//     border: 1px solid transparent;
//     text-align: left;
// }
//
// table.dataframe th {
//     background-color: var(--background);
//     color: var(--header-text-color);
// }
//
// table.dataframe td {
//     vertical-align: top;
// }
//
// table.dataframe th.bottomBorder {
//     border-bottom-color: var(--bold-border-color);
// }
//
// table.dataframe tbody > tr:nth-child(odd) {
//     background: var(--background-odd);
// }
//
// table.dataframe tbody > tr:nth-child(even) {
//     background: var(--background);
// }
//
// table.dataframe tbody > tr:hover {
//     background: var(--background-hover);
// }
//
// table.dataframe a {
//     cursor: pointer;
//     color: var(--link-color);
//     text-decoration: none;
// }
//
// table.dataframe tr:hover > td a {
//     color: var(--link-color-pale);
// }
//
// table.dataframe a:hover {
//     color: var(--link-hover);
//     text-decoration: underline;
// }
//
// table.dataframe img {
//     max-width: fit-content;
// }
//
// table.dataframe th.complex {
//     background-color: var(--background);
//     border: 1px solid var(--background);
// }
//
// table.dataframe .leftBorder {
//     border-left-color: var(--inner-border-color);
// }
//
// table.dataframe .rightBorder {
//     border-right-color: var(--inner-border-color);
// }
//
// table.dataframe .rightAlign {
//     text-align: right;
// }
//
// table.dataframe .expanderSvg {
//     width: 8px;
//     height: 8px;
//     margin-right: 3px;
// }
//
// table.dataframe .expander {
//     display: flex;
//     align-items: center;
// }
//
// /* formatting */
//
// table.dataframe .null {
//     color: var(--text-color-pale);
// }
//
// table.dataframe .structural {
//     color: var(--text-color-medium);
//     font-weight: bold;
// }
//
// table.dataframe .dataFrameCaption {
//     font-weight: bold;
// }
//
// table.dataframe .numbers {
//     color: var(--text-color-dark);
// }
//
// table.dataframe td:hover .formatted .structural, .null {
//     color: var(--text-color-dark);
// }
//
// table.dataframe tr:hover .formatted .structural, .null {
//     color: var(--text-color-dark);
// }
//
//
//
//
//             </style>
//         </head>
//         <body>
//
// <table class="dataframe" id="df_520093708"></table>
//
// <p class="dataframe_description">DataFrame: rowsCount = 16, columnsCount = 12</p>
//         </body>
//         <script>
//
// /*<!--*/
// call_DataFrame(function() { DataFrame.addTable({ cols: [{ name: "<span title=\"name: String\">name</span>", children: [], rightAlign: false, values: ["type","event_type","startedAt","duration","cause","cpu_user","cpu_kernel","cpu_wallClock","heap_occupancy_before_coll","heap_occupancy_after_coll","heap_size_before_coll","heap_size_after_coll","perm_or_meta_occupancy_before_coll","perm_or_meta_occupancy_after_coll","perm_or_meta_size_before_coll","perm_or_meta_size_after_coll"] },
// { name: "<span title=\"type: Any\">type</span>", children: [], rightAlign: false, values: ["String","String","Instant","Double","String","Double","Double","Double","Int","Int","Int","Int","Int","Int","Int","Int"] },
// { name: "<span title=\"count: Int\">count</span>", children: [], rightAlign: true, values: ["<span class=\"formatted\" title=\"\"><span class=\"numbers\">18622</span></span>","<span class=\"formatted\" title=\"\"><span class=\"numbers\">18622</span></span>","<span class=\"formatted\" title=\"\"><span class=\"numbers\">18622</span></span>","<span class=\"formatted\" title=\"\"><span class=\"numbers\">18622</span></span>","<span class=\"formatted\" title=\"\"><span class=\"numbers\">18622</span></span>","<span class=\"formatted\" title=\"\"><span class=\"numbers\">18622</span></span>","<span class=\"formatted\" title=\"\"><span class=\"numbers\">18622</span></span>","<span class=\"formatted\" title=\"\"><span class=\"numbers\">18622</span></span>","<span class=\"formatted\" title=\"\"><span class=\"numbers\">18622</span></span>","<span class=\"formatted\" title=\"\"><span class=\"numbers\">18622</span></span>","<span class=\"formatted\" title=\"\"><span class=\"numbers\">18622</span></span>","<span class=\"formatted\" title=\"\"><span class=\"numbers\">18622</span></span>","<span class=\"formatted\" title=\"\"><span class=\"numbers\">18622</span></span>","<span class=\"formatted\" title=\"\"><span class=\"numbers\">18622</span></span>","<span class=\"formatted\" title=\"\"><span class=\"numbers\">18622</span></span>","<span class=\"formatted\" title=\"\"><span class=\"numbers\">18622</span></span>"] },
// { name: "<span title=\"unique: Int\">unique</span>", children: [], rightAlign: true, values: ["<span class=\"formatted\" title=\"\"><span class=\"numbers\">9</span></span>","<span class=\"formatted\" title=\"\"><span class=\"numbers\">2</span></span>","<span class=\"formatted\" title=\"\"><span class=\"numbers\">16442</span></span>","<span class=\"formatted\" title=\"\"><span class=\"numbers\">5630</span></span>","<span class=\"formatted\" title=\"\"><span class=\"numbers\">5</span></span>","<span class=\"formatted\" title=\"\"><span class=\"numbers\">9</span></span>","<span class=\"formatted\" title=\"\"><span class=\"numbers\">4</span></span>","<span class=\"formatted\" title=\"\"><span class=\"numbers\">5</span></span>","<span class=\"formatted\" title=\"\"><span class=\"numbers\">617</span></span>","<span class=\"formatted\" title=\"\"><span class=\"numbers\">140</span></span>","<span class=\"formatted\" title=\"\"><span class=\"numbers\">2</span></span>","<span class=\"formatted\" title=\"\"><span class=\"numbers\">2</span></span>","<span class=\"formatted\" title=\"\"><span class=\"numbers\">9</span></span>","<span class=\"formatted\" title=\"\"><span class=\"numbers\">9</span></span>","<span class=\"formatted\" title=\"\"><span class=\"numbers\">4</span></span>","<span class=\"formatted\" title=\"\"><span class=\"numbers\">4</span></span>"] },
// { name: "<span title=\"nulls: Int\">nulls</span>", children: [], rightAlign: true, values: ["<span class=\"formatted\" title=\"\"><span class=\"numbers\">0</span></span>","<span class=\"formatted\" title=\"\"><span class=\"numbers\">0</span></span>","<span class=\"formatted\" title=\"\"><span class=\"numbers\">0</span></span>","<span class=\"formatted\" title=\"\"><span class=\"numbers\">0</span></span>","<span class=\"formatted\" title=\"\"><span class=\"numbers\">0</span></span>","<span class=\"formatted\" title=\"\"><span class=\"numbers\">0</span></span>","<span class=\"formatted\" title=\"\"><span class=\"numbers\">0</span></span>","<span class=\"formatted\" title=\"\"><span class=\"numbers\">0</span></span>","<span class=\"formatted\" title=\"\"><span class=\"numbers\">0</span></span>","<span class=\"formatted\" title=\"\"><span class=\"numbers\">0</span></span>","<span class=\"formatted\" title=\"\"><span class=\"numbers\">0</span></span>","<span class=\"formatted\" title=\"\"><span class=\"numbers\">0</span></span>","<span class=\"formatted\" title=\"

// %%
df.select {type and duration}.groupBy{type}.sum()
        .add("max [s]"){df.filter { row -> it.type==row.type }.select("duration").max()}
        .add("mean [s]"){df.filter { row -> it.type==row.type }.select("duration").mean()}
// Out:
//         <html>
//         <head>
//             <style type="text/css">
//                 :root {
//     --background: #fff;
//     --background-odd: #f5f5f5;
//     --background-hover: #d9edfd;
//     --header-text-color: #474747;
//     --text-color: #848484;
//     --text-color-dark: #000;
//     --text-color-medium: #737373;
//     --text-color-pale: #b3b3b3;
//     --inner-border-color: #aaa;
//     --bold-border-color: #000;
//     --link-color: #296eaa;
//     --link-color-pale: #296eaa;
//     --link-hover: #1a466c;
// }
//
// :root[theme="dark"], :root [data-jp-theme-light="false"], .dataframe_dark{
//     --background: #303030;
//     --background-odd: #3c3c3c;
//     --background-hover: #464646;
//     --header-text-color: #dddddd;
//     --text-color: #b3b3b3;
//     --text-color-dark: #dddddd;
//     --text-color-medium: #b2b2b2;
//     --text-color-pale: #737373;
//     --inner-border-color: #707070;
//     --bold-border-color: #777777;
//     --link-color: #008dc0;
//     --link-color-pale: #97e1fb;
//     --link-hover: #00688e;
// }
//
// p.dataframe_description {
//     color: var(--text-color-dark);
// }
//
// table.dataframe {
//     font-family: "Helvetica Neue", Helvetica, Arial, sans-serif;
//     font-size: 12px;
//     background-color: var(--background);
//     color: var(--text-color-dark);
//     border: none;
//     border-collapse: collapse;
// }
//
// table.dataframe th, td {
//     padding: 6px;
//     border: 1px solid transparent;
//     text-align: left;
// }
//
// table.dataframe th {
//     background-color: var(--background);
//     color: var(--header-text-color);
// }
//
// table.dataframe td {
//     vertical-align: top;
// }
//
// table.dataframe th.bottomBorder {
//     border-bottom-color: var(--bold-border-color);
// }
//
// table.dataframe tbody > tr:nth-child(odd) {
//     background: var(--background-odd);
// }
//
// table.dataframe tbody > tr:nth-child(even) {
//     background: var(--background);
// }
//
// table.dataframe tbody > tr:hover {
//     background: var(--background-hover);
// }
//
// table.dataframe a {
//     cursor: pointer;
//     color: var(--link-color);
//     text-decoration: none;
// }
//
// table.dataframe tr:hover > td a {
//     color: var(--link-color-pale);
// }
//
// table.dataframe a:hover {
//     color: var(--link-hover);
//     text-decoration: underline;
// }
//
// table.dataframe img {
//     max-width: fit-content;
// }
//
// table.dataframe th.complex {
//     background-color: var(--background);
//     border: 1px solid var(--background);
// }
//
// table.dataframe .leftBorder {
//     border-left-color: var(--inner-border-color);
// }
//
// table.dataframe .rightBorder {
//     border-right-color: var(--inner-border-color);
// }
//
// table.dataframe .rightAlign {
//     text-align: right;
// }
//
// table.dataframe .expanderSvg {
//     width: 8px;
//     height: 8px;
//     margin-right: 3px;
// }
//
// table.dataframe .expander {
//     display: flex;
//     align-items: center;
// }
//
// /* formatting */
//
// table.dataframe .null {
//     color: var(--text-color-pale);
// }
//
// table.dataframe .structural {
//     color: var(--text-color-medium);
//     font-weight: bold;
// }
//
// table.dataframe .dataFrameCaption {
//     font-weight: bold;
// }
//
// table.dataframe .numbers {
//     color: var(--text-color-dark);
// }
//
// table.dataframe td:hover .formatted .structural, .null {
//     color: var(--text-color-dark);
// }
//
// table.dataframe tr:hover .formatted .structural, .null {
//     color: var(--text-color-dark);
// }
//
//
//
//
//             </style>
//         </head>
//         <body>
//
// <table class="dataframe" id="df_520093709"></table>
//
// <p class="dataframe_description">DataFrame: rowsCount = 9, columnsCount = 4</p>
//         </body>
//         <script>
//
// /*<!--*/
// call_DataFrame(function() { DataFrame.addTable({ cols: [{ name: "<span title=\"type: String\">type</span>", children: [], rightAlign: false, values: ["Young","G1GCYoungInitialMark","G1GCConcurrentUndoCycle","ConcurrentCleanupForNextMark","ConcurrentClearClaimedMarks","ConcurrentRootRegionScan","G1GCRemark","G1GCConcurrentCleanup","Mixed"] },
// { name: "<span title=\"duration: Double\">duration</span>", children: [], rightAlign: true, values: ["<span class=\"formatted\" title=\"\"><span class=\"numbers\">67,066846</span></span>","<span class=\"formatted\" title=\"\"><span class=\"numbers\">13,436891</span></span>","<span class=\"formatted\" title=\"\"><span class=\"numbers\">3,207935</span></span>","<span class=\"formatted\" title=\"\"><span class=\"numbers\">3,305661</span></span>","<span class=\"formatted\" title=\"\"><span class=\"numbers\">0,008007</span></span>","<span class=\"formatted\" title=\"\"><span class=\"numbers\">0,330179</span></span>","<span class=\"formatted\" title=\"\"><span class=\"numbers\">2,622695</span></span>","<span class=\"formatted\" title=\"\"><span class=\"numbers\">6,468582</span></span>","<span class=\"formatted\" title=\"\"><span class=\"numbers\">0,659336</span></span>"] },
// { name: "<span title=\"duration: Double\">duration</span>", children: [], rightAlign: true, values: ["<span class=\"formatted\" title=\"\"><span class=\"numbers\">0,013244</span></span>","<span class=\"formatted\" title=\"\"><span class=\"numbers\">0,013829</span></span>","<span class=\"formatted\" title=\"\"><span class=\"numbers\">0,007948</span></span>","<span class=\"formatted\" title=\"\"><span class=\"numbers\">0,007913</span></span>","<span class=\"formatted\" title=\"\"><span class=\"numbers\">0,000169</span></span>","<span class=\"formatted\" title=\"\"><span class=\"numbers\">0,005558</span></span>","<span class=\"formatted\" title=\"\"><span class=\"numbers\">0,046171</span></span>","<span class=\"formatted\" title=\"\"><span class=\"numbers\">0,070570</span></span>","<span class=\"formatted\" title=\"\"><span class=\"numbers\">0,010278</span></span>"] },
// { name: "<span title=\"max [s]: DataRow\">max [s]</span>", children: [2], rightAlign: false, values: ["<span class=\"formatted\" title=\"duration: 0.013244\"><span class=\"structural\">{ </span><span class=\"structural\">duration: </span><span class=\"numbers\">0,0</span><span class=\"structural\"> }</span></span>","<span class=\"formatted\" title=\"duration: 0.013829000000000001\"><span class=\"structural\">{ </span><span class=\"structural\">duration: </span><span class=\"numbers\">0,0</span><span class=\"structural\"> }</span></span>","<span class=\"formatted\" title=\"duration: 0.007948\"><span class=\"structural\">{ </span><span class=\"structural\">duration: </span><span class=\"numbers\">0,0</span><span class=\"structural\"> }</span></span>","<span class=\"formatted\" title=\"duration: 0.007913\"><span class=\"structural\">{ </span><span class=\"structural\">duration: </span><span class=\"numbers\">0,0</span><span class=\"structural\"> }</span></span>","<span class=\"formatted\" title=\"duration: 1.6900000000000002E-4\"><span class=\"structural\">{ </span><span class=\"structural\">duration: </span><span class=\"numbers\">0,0</span><span class=\"structural\"> }</span></span>","<span class=\"formatted\" title=\"duration: 0.005558\"><span class=\"structural\">{ </span><span class=\"structural\">duration: </span><span class=\"numbers\">0,0</span><span class=\"structural\"> }</span></span>","<span class=\"formatted\" title=\"duration: 0.046171\"><span class=\"structural\">{ </span><span class=\"structural\">duration: </span><span class=\"numbers\">0,0</span><span class=\"structural\"> }</span></span>","<span class=\"formatted\" title=\"duration: 0.07057\"><span class=\"structural\">{ </span><span class=\"structural\">duration: </span><span class=\"numbers\">0,1</span><span class=\"structural\"> }</span></span>","<span class=\"formatted\" title=\"duration: 0.010278\"><span class=\"structural\">{ </span><span class=\"structural\">duration: </span><span class=\"numbers\">0,0</span><span class=\"structural\"> }</span></span>"] },
// { name: "<span title=\"duration: Double\">duration</span>", children: [], rightAlign: true, values: ["<span class=\"formatted\" title=\"\"><span class=\"numbers\">0,005809</span></span>","<span class=\"formatted\" title=\"\"><span class=\"numbers\">0,006086</span></span>","<span class=\"formatted\" title=\"\"><span class=\"numbers\">0,001531</span></span>","<span class=\"formatted\" title=\"\"><span cla

// %%
df.select {type and duration}.groupBy{type}.aggregate {
    count() into "count"
    sum(duration) into "sum [s]"
    max(duration) into "max [s]"
    min(duration) into "min [s]"
    mean(duration) into "avg [s]"
 }
// Out:
//         <html>
//         <head>
//             <style type="text/css">
//                 :root {
//     --background: #fff;
//     --background-odd: #f5f5f5;
//     --background-hover: #d9edfd;
//     --header-text-color: #474747;
//     --text-color: #848484;
//     --text-color-dark: #000;
//     --text-color-medium: #737373;
//     --text-color-pale: #b3b3b3;
//     --inner-border-color: #aaa;
//     --bold-border-color: #000;
//     --link-color: #296eaa;
//     --link-color-pale: #296eaa;
//     --link-hover: #1a466c;
// }
//
// :root[theme="dark"], :root [data-jp-theme-light="false"], .dataframe_dark{
//     --background: #303030;
//     --background-odd: #3c3c3c;
//     --background-hover: #464646;
//     --header-text-color: #dddddd;
//     --text-color: #b3b3b3;
//     --text-color-dark: #dddddd;
//     --text-color-medium: #b2b2b2;
//     --text-color-pale: #737373;
//     --inner-border-color: #707070;
//     --bold-border-color: #777777;
//     --link-color: #008dc0;
//     --link-color-pale: #97e1fb;
//     --link-hover: #00688e;
// }
//
// p.dataframe_description {
//     color: var(--text-color-dark);
// }
//
// table.dataframe {
//     font-family: "Helvetica Neue", Helvetica, Arial, sans-serif;
//     font-size: 12px;
//     background-color: var(--background);
//     color: var(--text-color-dark);
//     border: none;
//     border-collapse: collapse;
// }
//
// table.dataframe th, td {
//     padding: 6px;
//     border: 1px solid transparent;
//     text-align: left;
// }
//
// table.dataframe th {
//     background-color: var(--background);
//     color: var(--header-text-color);
// }
//
// table.dataframe td {
//     vertical-align: top;
// }
//
// table.dataframe th.bottomBorder {
//     border-bottom-color: var(--bold-border-color);
// }
//
// table.dataframe tbody > tr:nth-child(odd) {
//     background: var(--background-odd);
// }
//
// table.dataframe tbody > tr:nth-child(even) {
//     background: var(--background);
// }
//
// table.dataframe tbody > tr:hover {
//     background: var(--background-hover);
// }
//
// table.dataframe a {
//     cursor: pointer;
//     color: var(--link-color);
//     text-decoration: none;
// }
//
// table.dataframe tr:hover > td a {
//     color: var(--link-color-pale);
// }
//
// table.dataframe a:hover {
//     color: var(--link-hover);
//     text-decoration: underline;
// }
//
// table.dataframe img {
//     max-width: fit-content;
// }
//
// table.dataframe th.complex {
//     background-color: var(--background);
//     border: 1px solid var(--background);
// }
//
// table.dataframe .leftBorder {
//     border-left-color: var(--inner-border-color);
// }
//
// table.dataframe .rightBorder {
//     border-right-color: var(--inner-border-color);
// }
//
// table.dataframe .rightAlign {
//     text-align: right;
// }
//
// table.dataframe .expanderSvg {
//     width: 8px;
//     height: 8px;
//     margin-right: 3px;
// }
//
// table.dataframe .expander {
//     display: flex;
//     align-items: center;
// }
//
// /* formatting */
//
// table.dataframe .null {
//     color: var(--text-color-pale);
// }
//
// table.dataframe .structural {
//     color: var(--text-color-medium);
//     font-weight: bold;
// }
//
// table.dataframe .dataFrameCaption {
//     font-weight: bold;
// }
//
// table.dataframe .numbers {
//     color: var(--text-color-dark);
// }
//
// table.dataframe td:hover .formatted .structural, .null {
//     color: var(--text-color-dark);
// }
//
// table.dataframe tr:hover .formatted .structural, .null {
//     color: var(--text-color-dark);
// }
//
//
//
//
//             </style>
//         </head>
//         <body>
//
// <table class="dataframe" id="df_520093703"></table>
//
// <p class="dataframe_description">DataFrame: rowsCount = 9, columnsCount = 6</p>
//         </body>
//         <script>
//
// /*<!--*/
// call_DataFrame(function() { DataFrame.addTable({ cols: [{ name: "<span title=\"type: String\">type</span>", children: [], rightAlign: false, values: ["Young","G1GCYoungInitialMark","G1GCConcurrentUndoCycle","ConcurrentCleanupForNextMark","ConcurrentClearClaimedMarks","ConcurrentRootRegionScan","G1GCRemark","G1GCConcurrentCleanup","Mixed"] },
// { name: "<span title=\"count: Int\">count</span>", children: [], rightAlign: true, values: ["<span class=\"formatted\" title=\"\"><span class=\"numbers\">11546</span></span>","<span class=\"formatted\" title=\"\"><span class=\"numbers\">2208</span></span>","<span class=\"formatted\" title=\"\"><span class=\"numbers\">2095</span></span>","<span class=\"formatted\" title=\"\"><span class=\"numbers\">2208</span></span>","<span class=\"formatted\" title=\"\"><span class=\"numbers\">113</span></span>","<span class=\"formatted\" title=\"\"><span class=\"numbers\">113</span></span>","<span class=\"formatted\" title=\"\"><span class=\"numbers\">113</span></span>","<span class=\"formatted\" title=\"\"><span class=\"numbers\">113</span></span>","<span class=\"formatted\" title=\"\"><span class=\"numbers\">113</span></span>"] },
// { name: "<span title=\"sum [s]: Double\">sum [s]</span>", children: [], rightAlign: true, values: ["<span class=\"formatted\" title=\"\"><span class=\"numbers\">67,066846</span></span>","<span class=\"formatted\" title=\"\"><span class=\"numbers\">13,436891</span></span>","<span class=\"formatted\" title=\"\"><span class=\"numbers\">3,207935</span></span>","<span class=\"formatted\" title=\"\"><span class=\"numbers\">3,305661</span></span>","<span class=\"formatted\" title=\"\"><span class=\"numbers\">0,008007</span></span>","<span class=\"formatted\" title=\"\"><span class=\"numbers\">0,330179</span></span>","<span class=\"formatted\" title=\"\"><span class=\"numbers\">2,622695</span></span>","<span class=\"formatted\" title=\"\"><span class=\"numbers\">6,468582</span></span>","<span class=\"formatted\" title=\"\"><span class=\"numbers\">0,659336</span></span>"] },
// { name: "<span title=\"max [s]: Double\">max [s]</span>", children: [], rightAlign: true, values: ["<span class=\"formatted\" title=\"\"><span class=\"numbers\">0,013244</span></span>","<span class=\"formatted\" title=\"\"><span class=\"numbers\">0,013829</span></span>","<span class=\"formatted\" title=\"\"><span class=\"numbers\">0,007948</span></span>","<span class=\"formatted\" title=\"\"><span class=\"numbers\">0,007913</span></span>","<span class=\"formatted\" title=\"\"><span class=\"numbers\">0,000169</span></span>","<span class=\"formatted\" title=\"\"><span class=\"numbers\">0,005558</span></span>","<span class=\"formatted\" title=\"\"><span class=\"numbers\">0,046171</span></span>","<span class=\"formatted\" title=\"\"><span class=\"numbers\">0,070570</span></span>","<span class=\"formatted\" title=\"\"><span class=\"numbers\">0,010278</span></span>"] },
// { name: "<span title=\"min [s]: Double\">min [s]</span>", children: [], rightAlign: true, values: ["<span class=\"formatted\" title=\"\"><span class=\"numbers\">0,002985</span></span>","<span class=\"formatted\" title=\"\"><span class=\"numbers\">0,003086</span></span>","<span class=\"formatted\" title=\"\"><span class=\"numbers\">0,000794</span></span>","<span class=\"formatted\" title=\"\"><span class=\"numbers\">0,000735</span></span>","<span class=\"formatted\" title=\"\"><span class=\"numbers\">0,000018</span></span>","<span class=\"formatted\" title=\"\"><span class=\"numbers\">0,001817</span></span>","<span class=\"formatted\" title=\"\"><span class=\"numbers\">0,019551</span></span>","<span class=\"formatted\" title=\"\"><span class=\"numbers\">0,054119</span></span>","<span class=\"formatted\" title=\"\"><span class=\"numbers\">0,003568</span></span>"] },
// { name: "<span title=\"avg [s]: Double\">avg [s]</span>", children: [], rightAlign: true, values: ["<span class=\"formatted\" title=\"\"><span class=\"numbers\">0,005809</span></span>","<span class=\"formatted\" title=\"\"><span class=\"numbers\">0,006086</span></span>","<span class=\"formatted\" title=\"\"><span class=\"numbers\">0,001531</span></span>","<span class=\"formatted\" title=\"\"><span class=\"numbers\">0,001497</span></span>","<span class=\"formatted\" title=\"\"><span class=\"numbers\">0,000071</span></span>","<span class=\"formatted\" title=\"\"><span class=\"numbers\">0,002922</span></span>","<span class=\"formatted\" title=\"\"><span class=\"numbers\">0,023210</span></span>","<span class=\"formatted\" title=\"\"><span class=\"numbers\">0,05

// %%
df.sum {duration}
// Out:
// 97.10613200000051

// %%
df.select {event_type and duration}.groupBy{event_type}.sum()
// Out:
//         <html>
//         <head>
//             <style type="text/css">
//                 :root {
//     --background: #fff;
//     --background-odd: #f5f5f5;
//     --background-hover: #d9edfd;
//     --header-text-color: #474747;
//     --text-color: #848484;
//     --text-color-dark: #000;
//     --text-color-medium: #737373;
//     --text-color-pale: #b3b3b3;
//     --inner-border-color: #aaa;
//     --bold-border-color: #000;
//     --link-color: #296eaa;
//     --link-color-pale: #296eaa;
//     --link-hover: #1a466c;
// }
//
// :root[theme="dark"], :root [data-jp-theme-light="false"], .dataframe_dark{
//     --background: #303030;
//     --background-odd: #3c3c3c;
//     --background-hover: #464646;
//     --header-text-color: #dddddd;
//     --text-color: #b3b3b3;
//     --text-color-dark: #dddddd;
//     --text-color-medium: #b2b2b2;
//     --text-color-pale: #737373;
//     --inner-border-color: #707070;
//     --bold-border-color: #777777;
//     --link-color: #008dc0;
//     --link-color-pale: #97e1fb;
//     --link-hover: #00688e;
// }
//
// p.dataframe_description {
//     color: var(--text-color-dark);
// }
//
// table.dataframe {
//     font-family: "Helvetica Neue", Helvetica, Arial, sans-serif;
//     font-size: 12px;
//     background-color: var(--background);
//     color: var(--text-color-dark);
//     border: none;
//     border-collapse: collapse;
// }
//
// table.dataframe th, td {
//     padding: 6px;
//     border: 1px solid transparent;
//     text-align: left;
// }
//
// table.dataframe th {
//     background-color: var(--background);
//     color: var(--header-text-color);
// }
//
// table.dataframe td {
//     vertical-align: top;
// }
//
// table.dataframe th.bottomBorder {
//     border-bottom-color: var(--bold-border-color);
// }
//
// table.dataframe tbody > tr:nth-child(odd) {
//     background: var(--background-odd);
// }
//
// table.dataframe tbody > tr:nth-child(even) {
//     background: var(--background);
// }
//
// table.dataframe tbody > tr:hover {
//     background: var(--background-hover);
// }
//
// table.dataframe a {
//     cursor: pointer;
//     color: var(--link-color);
//     text-decoration: none;
// }
//
// table.dataframe tr:hover > td a {
//     color: var(--link-color-pale);
// }
//
// table.dataframe a:hover {
//     color: var(--link-hover);
//     text-decoration: underline;
// }
//
// table.dataframe img {
//     max-width: fit-content;
// }
//
// table.dataframe th.complex {
//     background-color: var(--background);
//     border: 1px solid var(--background);
// }
//
// table.dataframe .leftBorder {
//     border-left-color: var(--inner-border-color);
// }
//
// table.dataframe .rightBorder {
//     border-right-color: var(--inner-border-color);
// }
//
// table.dataframe .rightAlign {
//     text-align: right;
// }
//
// table.dataframe .expanderSvg {
//     width: 8px;
//     height: 8px;
//     margin-right: 3px;
// }
//
// table.dataframe .expander {
//     display: flex;
//     align-items: center;
// }
//
// /* formatting */
//
// table.dataframe .null {
//     color: var(--text-color-pale);
// }
//
// table.dataframe .structural {
//     color: var(--text-color-medium);
//     font-weight: bold;
// }
//
// table.dataframe .dataFrameCaption {
//     font-weight: bold;
// }
//
// table.dataframe .numbers {
//     color: var(--text-color-dark);
// }
//
// table.dataframe td:hover .formatted .structural, .null {
//     color: var(--text-color-dark);
// }
//
// table.dataframe tr:hover .formatted .structural, .null {
//     color: var(--text-color-dark);
// }
//
//
//
//
//             </style>
//         </head>
//         <body>
//
// <table class="dataframe" id="df_520093704"></table>
//
// <p class="dataframe_description">DataFrame: rowsCount = 2, columnsCount = 2</p>
//         </body>
//         <script>
//
// /*<!--*/
// call_DataFrame(function() { DataFrame.addTable({ cols: [{ name: "<span title=\"event_type: String\">event_type</span>", children: [], rightAlign: false, values: ["PauseEvent","ConcurrentEvent"] },
// { name: "<span title=\"duration: Double\">duration</span>", children: [], rightAlign: true, values: ["<span class=\"formatted\" title=\"\"><span class=\"numbers\">83,785768</span></span>","<span class=\"formatted\" title=\"\"><span class=\"numbers\">13,320364</span></span>"] },
// ], id: 520093704, rootId: 520093704, totalRows: 2 } ) });
// /*-->*/
//
// call_DataFrame(function() { DataFrame.renderTable(520093704) });
//
//
//         </script>
//         </html>

// %%
df.select {type and duration}.groupBy{type}.sum()
// Out:
//         <html>
//         <head>
//             <style type="text/css">
//                 :root {
//     --background: #fff;
//     --background-odd: #f5f5f5;
//     --background-hover: #d9edfd;
//     --header-text-color: #474747;
//     --text-color: #848484;
//     --text-color-dark: #000;
//     --text-color-medium: #737373;
//     --text-color-pale: #b3b3b3;
//     --inner-border-color: #aaa;
//     --bold-border-color: #000;
//     --link-color: #296eaa;
//     --link-color-pale: #296eaa;
//     --link-hover: #1a466c;
// }
//
// :root[theme="dark"], :root [data-jp-theme-light="false"], .dataframe_dark{
//     --background: #303030;
//     --background-odd: #3c3c3c;
//     --background-hover: #464646;
//     --header-text-color: #dddddd;
//     --text-color: #b3b3b3;
//     --text-color-dark: #dddddd;
//     --text-color-medium: #b2b2b2;
//     --text-color-pale: #737373;
//     --inner-border-color: #707070;
//     --bold-border-color: #777777;
//     --link-color: #008dc0;
//     --link-color-pale: #97e1fb;
//     --link-hover: #00688e;
// }
//
// p.dataframe_description {
//     color: var(--text-color-dark);
// }
//
// table.dataframe {
//     font-family: "Helvetica Neue", Helvetica, Arial, sans-serif;
//     font-size: 12px;
//     background-color: var(--background);
//     color: var(--text-color-dark);
//     border: none;
//     border-collapse: collapse;
// }
//
// table.dataframe th, td {
//     padding: 6px;
//     border: 1px solid transparent;
//     text-align: left;
// }
//
// table.dataframe th {
//     background-color: var(--background);
//     color: var(--header-text-color);
// }
//
// table.dataframe td {
//     vertical-align: top;
// }
//
// table.dataframe th.bottomBorder {
//     border-bottom-color: var(--bold-border-color);
// }
//
// table.dataframe tbody > tr:nth-child(odd) {
//     background: var(--background-odd);
// }
//
// table.dataframe tbody > tr:nth-child(even) {
//     background: var(--background);
// }
//
// table.dataframe tbody > tr:hover {
//     background: var(--background-hover);
// }
//
// table.dataframe a {
//     cursor: pointer;
//     color: var(--link-color);
//     text-decoration: none;
// }
//
// table.dataframe tr:hover > td a {
//     color: var(--link-color-pale);
// }
//
// table.dataframe a:hover {
//     color: var(--link-hover);
//     text-decoration: underline;
// }
//
// table.dataframe img {
//     max-width: fit-content;
// }
//
// table.dataframe th.complex {
//     background-color: var(--background);
//     border: 1px solid var(--background);
// }
//
// table.dataframe .leftBorder {
//     border-left-color: var(--inner-border-color);
// }
//
// table.dataframe .rightBorder {
//     border-right-color: var(--inner-border-color);
// }
//
// table.dataframe .rightAlign {
//     text-align: right;
// }
//
// table.dataframe .expanderSvg {
//     width: 8px;
//     height: 8px;
//     margin-right: 3px;
// }
//
// table.dataframe .expander {
//     display: flex;
//     align-items: center;
// }
//
// /* formatting */
//
// table.dataframe .null {
//     color: var(--text-color-pale);
// }
//
// table.dataframe .structural {
//     color: var(--text-color-medium);
//     font-weight: bold;
// }
//
// table.dataframe .dataFrameCaption {
//     font-weight: bold;
// }
//
// table.dataframe .numbers {
//     color: var(--text-color-dark);
// }
//
// table.dataframe td:hover .formatted .structural, .null {
//     color: var(--text-color-dark);
// }
//
// table.dataframe tr:hover .formatted .structural, .null {
//     color: var(--text-color-dark);
// }
//
//
//
//
//             </style>
//         </head>
//         <body>
//
// <table class="dataframe" id="df_520093705"></table>
//
// <p class="dataframe_description">DataFrame: rowsCount = 9, columnsCount = 2</p>
//         </body>
//         <script>
//
// /*<!--*/
// call_DataFrame(function() { DataFrame.addTable({ cols: [{ name: "<span title=\"type: String\">type</span>", children: [], rightAlign: false, values: ["Young","G1GCYoungInitialMark","G1GCConcurrentUndoCycle","ConcurrentCleanupForNextMark","ConcurrentClearClaimedMarks","ConcurrentRootRegionScan","G1GCRemark","G1GCConcurrentCleanup","Mixed"] },
// { name: "<span title=\"duration: Double\">duration</span>", children: [], rightAlign: true, values: ["<span class=\"formatted\" title=\"\"><span class=\"numbers\">67,066846</span></span>","<span class=\"formatted\" title=\"\"><span class=\"numbers\">13,436891</span></span>","<span class=\"formatted\" title=\"\"><span class=\"numbers\">3,207935</span></span>","<span class=\"formatted\" title=\"\"><span class=\"numbers\">3,305661</span></span>","<span class=\"formatted\" title=\"\"><span class=\"numbers\">0,008007</span></span>","<span class=\"formatted\" title=\"\"><span class=\"numbers\">0,330179</span></span>","<span class=\"formatted\" title=\"\"><span class=\"numbers\">2,622695</span></span>","<span class=\"formatted\" title=\"\"><span class=\"numbers\">6,468582</span></span>","<span class=\"formatted\" title=\"\"><span class=\"numbers\">0,659336</span></span>"] },
// ], id: 520093705, rootId: 520093705, totalRows: 9 } ) });
// /*-->*/
//
// call_DataFrame(function() { DataFrame.renderTable(520093705) });
//
//
//         </script>
//         </html>

// %%
df.filter { type=="Young" }.select{cause}.groupBy{cause}.count()
// Out:
//         <html>
//         <head>
//             <style type="text/css">
//                 :root {
//     --background: #fff;
//     --background-odd: #f5f5f5;
//     --background-hover: #d9edfd;
//     --header-text-color: #474747;
//     --text-color: #848484;
//     --text-color-dark: #000;
//     --text-color-medium: #737373;
//     --text-color-pale: #b3b3b3;
//     --inner-border-color: #aaa;
//     --bold-border-color: #000;
//     --link-color: #296eaa;
//     --link-color-pale: #296eaa;
//     --link-hover: #1a466c;
// }
//
// :root[theme="dark"], :root [data-jp-theme-light="false"], .dataframe_dark{
//     --background: #303030;
//     --background-odd: #3c3c3c;
//     --background-hover: #464646;
//     --header-text-color: #dddddd;
//     --text-color: #b3b3b3;
//     --text-color-dark: #dddddd;
//     --text-color-medium: #b2b2b2;
//     --text-color-pale: #737373;
//     --inner-border-color: #707070;
//     --bold-border-color: #777777;
//     --link-color: #008dc0;
//     --link-color-pale: #97e1fb;
//     --link-hover: #00688e;
// }
//
// p.dataframe_description {
//     color: var(--text-color-dark);
// }
//
// table.dataframe {
//     font-family: "Helvetica Neue", Helvetica, Arial, sans-serif;
//     font-size: 12px;
//     background-color: var(--background);
//     color: var(--text-color-dark);
//     border: none;
//     border-collapse: collapse;
// }
//
// table.dataframe th, td {
//     padding: 6px;
//     border: 1px solid transparent;
//     text-align: left;
// }
//
// table.dataframe th {
//     background-color: var(--background);
//     color: var(--header-text-color);
// }
//
// table.dataframe td {
//     vertical-align: top;
// }
//
// table.dataframe th.bottomBorder {
//     border-bottom-color: var(--bold-border-color);
// }
//
// table.dataframe tbody > tr:nth-child(odd) {
//     background: var(--background-odd);
// }
//
// table.dataframe tbody > tr:nth-child(even) {
//     background: var(--background);
// }
//
// table.dataframe tbody > tr:hover {
//     background: var(--background-hover);
// }
//
// table.dataframe a {
//     cursor: pointer;
//     color: var(--link-color);
//     text-decoration: none;
// }
//
// table.dataframe tr:hover > td a {
//     color: var(--link-color-pale);
// }
//
// table.dataframe a:hover {
//     color: var(--link-hover);
//     text-decoration: underline;
// }
//
// table.dataframe img {
//     max-width: fit-content;
// }
//
// table.dataframe th.complex {
//     background-color: var(--background);
//     border: 1px solid var(--background);
// }
//
// table.dataframe .leftBorder {
//     border-left-color: var(--inner-border-color);
// }
//
// table.dataframe .rightBorder {
//     border-right-color: var(--inner-border-color);
// }
//
// table.dataframe .rightAlign {
//     text-align: right;
// }
//
// table.dataframe .expanderSvg {
//     width: 8px;
//     height: 8px;
//     margin-right: 3px;
// }
//
// table.dataframe .expander {
//     display: flex;
//     align-items: center;
// }
//
// /* formatting */
//
// table.dataframe .null {
//     color: var(--text-color-pale);
// }
//
// table.dataframe .structural {
//     color: var(--text-color-medium);
//     font-weight: bold;
// }
//
// table.dataframe .dataFrameCaption {
//     font-weight: bold;
// }
//
// table.dataframe .numbers {
//     color: var(--text-color-dark);
// }
//
// table.dataframe td:hover .formatted .structural, .null {
//     color: var(--text-color-dark);
// }
//
// table.dataframe tr:hover .formatted .structural, .null {
//     color: var(--text-color-dark);
// }
//
//
//
//
//             </style>
//         </head>
//         <body>
//
// <table class="dataframe" id="df_520093706"></table>
//
// <p class="dataframe_description">DataFrame: rowsCount = 2, columnsCount = 2</p>
//         </body>
//         <script>
//
// /*<!--*/
// call_DataFrame(function() { DataFrame.addTable({ cols: [{ name: "<span title=\"cause: String\">cause</span>", children: [], rightAlign: false, values: ["G1_EVACUATION_PAUSE","GC_LOCKER"] },
// { name: "<span title=\"count: Int\">count</span>", children: [], rightAlign: true, values: ["<span class=\"formatted\" title=\"\"><span class=\"numbers\">11502</span></span>","<span class=\"formatted\" title=\"\"><span class=\"numbers\">44</span></span>"] },
// ], id: 520093706, rootId: 520093706, totalRows: 2 } ) });
// /*-->*/
//
// call_DataFrame(function() { DataFrame.renderTable(520093706) });
//
//
//         </script>
//         </html>

// %%
import kotlinx.datetime.TimeZone

df.convert { startedAt }.toLocalDateTime(TimeZone.UTC)
// Out:
//         <html>
//         <head>
//             <style type="text/css">
//                 :root {
//     --background: #fff;
//     --background-odd: #f5f5f5;
//     --background-hover: #d9edfd;
//     --header-text-color: #474747;
//     --text-color: #848484;
//     --text-color-dark: #000;
//     --text-color-medium: #737373;
//     --text-color-pale: #b3b3b3;
//     --inner-border-color: #aaa;
//     --bold-border-color: #000;
//     --link-color: #296eaa;
//     --link-color-pale: #296eaa;
//     --link-hover: #1a466c;
// }
//
// :root[theme="dark"], :root [data-jp-theme-light="false"], .dataframe_dark{
//     --background: #303030;
//     --background-odd: #3c3c3c;
//     --background-hover: #464646;
//     --header-text-color: #dddddd;
//     --text-color: #b3b3b3;
//     --text-color-dark: #dddddd;
//     --text-color-medium: #b2b2b2;
//     --text-color-pale: #737373;
//     --inner-border-color: #707070;
//     --bold-border-color: #777777;
//     --link-color: #008dc0;
//     --link-color-pale: #97e1fb;
//     --link-hover: #00688e;
// }
//
// p.dataframe_description {
//     color: var(--text-color-dark);
// }
//
// table.dataframe {
//     font-family: "Helvetica Neue", Helvetica, Arial, sans-serif;
//     font-size: 12px;
//     background-color: var(--background);
//     color: var(--text-color-dark);
//     border: none;
//     border-collapse: collapse;
// }
//
// table.dataframe th, td {
//     padding: 6px;
//     border: 1px solid transparent;
//     text-align: left;
// }
//
// table.dataframe th {
//     background-color: var(--background);
//     color: var(--header-text-color);
// }
//
// table.dataframe td {
//     vertical-align: top;
// }
//
// table.dataframe th.bottomBorder {
//     border-bottom-color: var(--bold-border-color);
// }
//
// table.dataframe tbody > tr:nth-child(odd) {
//     background: var(--background-odd);
// }
//
// table.dataframe tbody > tr:nth-child(even) {
//     background: var(--background);
// }
//
// table.dataframe tbody > tr:hover {
//     background: var(--background-hover);
// }
//
// table.dataframe a {
//     cursor: pointer;
//     color: var(--link-color);
//     text-decoration: none;
// }
//
// table.dataframe tr:hover > td a {
//     color: var(--link-color-pale);
// }
//
// table.dataframe a:hover {
//     color: var(--link-hover);
//     text-decoration: underline;
// }
//
// table.dataframe img {
//     max-width: fit-content;
// }
//
// table.dataframe th.complex {
//     background-color: var(--background);
//     border: 1px solid var(--background);
// }
//
// table.dataframe .leftBorder {
//     border-left-color: var(--inner-border-color);
// }
//
// table.dataframe .rightBorder {
//     border-right-color: var(--inner-border-color);
// }
//
// table.dataframe .rightAlign {
//     text-align: right;
// }
//
// table.dataframe .expanderSvg {
//     width: 8px;
//     height: 8px;
//     margin-right: 3px;
// }
//
// table.dataframe .expander {
//     display: flex;
//     align-items: center;
// }
//
// /* formatting */
//
// table.dataframe .null {
//     color: var(--text-color-pale);
// }
//
// table.dataframe .structural {
//     color: var(--text-color-medium);
//     font-weight: bold;
// }
//
// table.dataframe .dataFrameCaption {
//     font-weight: bold;
// }
//
// table.dataframe .numbers {
//     color: var(--text-color-dark);
// }
//
// table.dataframe td:hover .formatted .structural, .null {
//     color: var(--text-color-dark);
// }
//
// table.dataframe tr:hover .formatted .structural, .null {
//     color: var(--text-color-dark);
// }
//
//
//
//
//             </style>
//         </head>
//         <body>
//
// <table class="dataframe" id="df_520093707"></table>
//
// <p class="dataframe_description">... showing only top 20 of 18622 rows</p><p class="dataframe_description">DataFrame: rowsCount = 18622, columnsCount = 16</p>
//         </body>
//         <script>
//
// /*<!--*/
// call_DataFrame(function() { DataFrame.addTable({ cols: [{ name: "<span title=\"type: String\">type</span>", children: [], rightAlign: false, values: ["Young","Young","Young","Young","Young","Young","Young","Young","Young","G1GCYoungInitialMark","G1GCConcurrentUndoCycle","ConcurrentCleanupForNextMark","Young","Young","Young","Young","Young","Young","G1GCYoungInitialMark","G1GCConcurrentUndoCycle"] },
// { name: "<span title=\"event_type: String\">event_type</span>", children: [], rightAlign: false, values: ["PauseEvent","PauseEvent","PauseEvent","PauseEvent","PauseEvent","PauseEvent","PauseEvent","PauseEvent","PauseEvent","PauseEvent","ConcurrentEvent","ConcurrentEvent","PauseEvent","PauseEvent","PauseEvent","PauseEvent","PauseEvent","PauseEvent","PauseEvent","ConcurrentEvent"] },
// { name: "<span title=\"startedAt: kotlinx.datetime.LocalDateTime\">startedAt</span>", children: [], rightAlign: false, values: ["2023-07-18T16:38:34.550","2023-07-18T16:38:40.761","2023-07-18T16:38:47.252","2023-07-18T16:38:53.418","2023-07-18T16:38:58.973","2023-07-18T16:39:04.665","2023-07-18T16:39:10.505","2023-07-18T16:39:15.615","2023-07-18T16:39:21.262","2023-07-18T16:39:26.095","2023-07-18T16:39:26.104","2023-07-18T16:39:26.104","2023-07-18T16:39:33.385","2023-07-18T16:39:39.429","2023-07-18T16:39:45.274","2023-07-18T16:39:51.058","2023-07-18T16:39:57.673","2023-07-18T16:40:03.787","2023-07-18T16:40:07.412","2023-07-18T16:40:07.419"] },
// { name: "<span title=\"duration: Double\">duration</span>", children: [], rightAlign: true, values: ["<span class=\"formatted\" title=\"\"><span class=\"numbers\">0,007961</span></span>","<span class=\"formatted\" title=\"\"><span class=\"numbers\">0,007288</span></span>","<span class=\"formatted\" title=\"\"><span class=\"numbers\">0,007701</span></span>","<span class=\"formatted\" title=\"\"><span class=\"numbers\">0,006213</span></span>","<span class=\"formatted\" title=\"\"><span class=\"numbers\">0,007023</span></span>","<span class=\"formatted\" title=\"\"><span class=\"numbers\">0,008063</span></span>","<span class=\"formatted\" title=\"\"><span class=\"numbers\">0,006614</span></span>","<span class=\"formatted\" title=\"\"><span class=\"numbers\">0,009664</span></span>","<span class=\"formatted\" title=\"\"><span class=\"numbers\">0,006702</span></span>","<span class=\"formatted\" title=\"\"><span class=\"numbers\">0,009153</span></span>","<span class=\"formatted\" title=\"\"><span class=\"numbers\">0,002713</span></span>","<span class=\"formatted\" title=\"\"><span class=\"numbers\">0,002684</span></span>","<span class=\"formatted\" title=\"\"><span class=\"numbers\">0,007018</span></span>","<span class=\"formatted\" title=\"\"><span class=\"numbers\">0,007426</span></span>","<span class=\"formatted\" title=\"\"><span class=\"numbers\">0,006734</span></span>","<span class=\"formatted\" title=\"\"><span class=\"numbers\">0,007435</span></span>","<span class=\"formatted\" title=\"\"><span class=\"numbers\">0,008182</span></span>","<span class=\"formatted\" title=\"\"><span class=\"numbers\">0,006963</span></span>","<span class=\"formatted\" title=\"\"><span class=\"numbers\">0,007265</span></span>","<span class=\"formatted\" title=\"\"><span class=\"numbers\">0,001260</span></span>"] },
// { name: "<span title=\"cause: String\">cause</span>", children: [], rightAlign: false, values: ["G1_EVACUATION_PAUSE","G1_EVACUATION_PAUSE","G1_EVACUATION_PAUSE","G1_EVACUATION_PAUSE","G1_EVACUATION_PAUSE","G1_EVACUATION_PAUSE","G1_EVACUATION_PAUSE","G1_EVACUATION_PAUSE","G1_EVACUATION_PAUSE","G1_HUMONGOUS_ALLOCATION","GCCAUSE_NOT_SET","UNKNOWN_GCCAUSE","G1_EVACUATION_PAUSE","G1_EVACUATION_PAUSE","G1_EVACUATION_PAUSE","G1_EVACUATION_PAUSE","G1_EVACUATION_PAUSE","G1_EVACUATION_PAUSE","G1_HUMONGOUS_ALLOCATION","GCCAUSE_NOT_SET"] },
// { name: "<span title=\"cpu_user: Double\">cpu_user</span>", children: [], rightAlign: true, values: ["<span class=\"formatted\" title=\"\"><span class=\"numbers\">0,02</span></span>","<span class=\"formatted\" title=\"\"><span class=\"numbers\">0,01</span></span>","<span class=\"formatted\" title=\"\"><span class=\"numbers\">0,01</span></span>","<span class=\"formatted\" title=\"\"><span class=\"numbers\">0,01</span></span>","<span class=\"formatted\" title=\"\"><span class=\"numbers\">0,01</span></span>","<span class=\"formatted\" title=\"\"><span class=\"numbers\">0,01</span></span>","<span class=\"formatted\" title=\"\"><span class=\"numbers\">0,01</span></span>","<span class=\"form

// %%
import kotlinx.datetime.TimeZone
import kotlinx.datetime.toJavaInstant
import java.text.SimpleDateFormat
import java.time.Duration

val first = df.first().startedAt.toJavaInstant()
val last = df.last().startedAt.toJavaInstant()
val uptimeInSeconds = Duration.between(first,last).toSeconds()
val pausedDurationInSeconds:Double=df.filter {event_type=="PauseEvent"}.select{duration}.sum().get("duration") as Double

val percentage=(pausedDurationInSeconds * 100)/uptimeInSeconds

println(first)
println(last)
println(pausedDurationInSeconds)
println(percentage)
// Out:
// 2023-07-18T16:38:34.550Z
// 2023-07-19T15:50:04.875Z
// 83.78576800000022
// 0.10035425559947327
