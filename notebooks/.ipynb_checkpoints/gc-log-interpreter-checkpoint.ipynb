// %% [markdown]
// # Part I - Garbage Collector Essentials
//
// Exellent articles about GC Log Anathomy:
//  - [Java,JVM Logs, GC Logs, G1GC -Monday with JVM logs - G1GC Stop-the-world phases](https://krzysztofslusarski.github.io/2021/08/10/monday-phases.html)
//
// Garbage collector, JVM memory allocation - series
//  - [Stages and levels of Java garbage collection](https://developers.redhat.com/articles/2021/08/20/stages-and-levels-java-garbage-collection#)

// %% [markdown]
// # Part II - Initial steps
// *(Import all needed [kotlin for data scince](https://kotlinlang.org/docs/data-science-overview.html) libraries)*

// %%
%use kandy(0.4.4)
%use dataframe(0.11.0)
%use kotlin-statistics(1.2.1)
import org.jetbrains.kotlinx.dataframe.io.readCSV

//import all gc events from csv file (file was generated via gc-log-wizard application)
var dfRaw = DataFrame.readCSV("../gclogs/pauses.csv")
// Out:
//             <div id="kotlin_out_0"></div>
//             <script type="text/javascript">
//                             if(!window.kotlinQueues) {
//                 window.kotlinQueues = {};
//             }
//             if(!window.kotlinQueues["kandyLetsPlot"]) {
//                 var resQueue = [];
//                 window.kotlinQueues["kandyLetsPlot"] = resQueue;
//                 window["call_kandyLetsPlot"] = function(f) {
//                     resQueue.push(f);
//                 }
//             }
//             (function (){
//                 var modifiers = [(function(script) {
//     script.src = "https://cdn.jsdelivr.net/gh/JetBrains/lets-plot@v3.1.0/js-package/distr/lets-plot.min.js"
//     script.type = "text/javascript";
// })];
//                 var e = document.getElementById("kotlin_out_0");
//                 modifiers.forEach(function (gen) {
//                     var script = document.createElement("script");
//                     gen(script)
//                     script.addEventListener("load", function() {
//                         window["call_kandyLetsPlot"] = function(f) {f();};
//                         window.kotlinQueues["kandyLetsPlot"].forEach(function(f) {f();});
//                         window.kotlinQueues["kandyLetsPlot"] = [];
//                     }, false);
//                     script.addEventListener("error", function() {
//                         window["call_kandyLetsPlot"] = function(f) {};
//                         window.kotlinQueues["kandyLetsPlot"] = [];
//                         var div = document.createElement("div");
//                         div.style.color = 'darkred';
//                         div.textContent = 'Error loading resource kandyLetsPlot';
//                         document.getElementById("kotlin_out_0").appendChild(div);
//                     }, false);
//
//                     e.appendChild(script);
//                 });
//             })();
//             </script>
//             <div id="kotlin_out_1"></div>
//             <script type="text/javascript">
//                             if(!window.kotlinQueues) {
//                 window.kotlinQueues = {};
//             }
//             if(!window.kotlinQueues["DataFrame"]) {
//                 var resQueue = [];
//                 window.kotlinQueues["DataFrame"] = resQueue;
//                 window["call_DataFrame"] = function(f) {
//                     resQueue.push(f);
//                 }
//             }
//             (function (){
//                 var modifiers = [(function(script) {
//     script.src = "https://cdn.jsdelivr.net/gh/Kotlin/dataframe@3db46ccccaa1291c0627307d64133317f545e6ae/core/src/main/resources/init.js"
//     script.type = "text/javascript";
// })];
//                 var e = document.getElementById("kotlin_out_1");
//                 modifiers.forEach(function (gen) {
//                     var script = document.createElement("script");
//                     gen(script)
//                     script.addEventListener("load", function() {
//                         window["call_DataFrame"] = function(f) {f();};
//                         window.kotlinQueues["DataFrame"].forEach(function(f) {f();});
//                         window.kotlinQueues["DataFrame"] = [];
//                     }, false);
//                     script.addEventListener("error", function() {
//                         window["call_DataFrame"] = function(f) {};
//                         window.kotlinQueues["DataFrame"] = [];
//                         var div = document.createElement("div");
//                         div.style.color = 'darkred';
//                         div.textContent = 'Error loading resource DataFrame';
//                         document.getElementById("kotlin_out_1").appendChild(div);
//                     }, false);
//
//                     e.appendChild(script);
//                 });
//             })();
//             </script>
//                 <style>
//                 :root {
//     --background: #fff;
//     --background-odd: #f5f5f5;
//     --background-hover: #d9edfd;
//     --header-text-color: #474747;
//     --text-color: #848484;
//     --text-color-dark: #000;
//     --text-color-medium: #737373;
//     --text-color-pale: #b3b3b3;
//     --inner-border-color: #aaa;
//     --bold-border-color: #000;
//     --link-color: #296eaa;
//     --link-color-pale: #296eaa;
//     --link-hover: #1a466c;
// }
//
// :root[theme="dark"], :root [data-jp-theme-light="false"], .dataframe_dark{
//     --background: #303030;
//     --background-odd: #3c3c3c;
//     --background-hover: #464646;
//     --header-text-color: #dddddd;
//     --text-color: #b3b3b3;
//     --text-color-dark: #dddddd;
//     --text-color-medium: #b2b2b2;
//     --text-color-pale: #737373;
//     --inner-border-color: #707070;
//     --bold-border-color: #777777;
//     --link-color: #008dc0;
//     --link-color-pale: #97e1fb;
//     --link-hover: #00688e;
// }
//
// p.dataframe_description {
//     color: var(--text-color-dark);
// }
//
// table.dataframe {
//     font-family: "Helvetica Neue", Helvetica, Arial, sans-serif;
//     font-size: 12px;
//     background-color: var(--background);
//     color: var(--text-color-dark);
//     border: none;
//     border-collapse: collapse;
// }
//
// table.dataframe th, td {
//     padding: 6px;
//     border: 1px solid transparent;
//     text-align: left;
// }
//
// table.dataframe th {
//     background-color: var(--background);
//     color: var(--header-text-color);
// }
//
// table.dataframe td {
//     vertical-align: top;
// }
//
// table.dataframe th.bottomBorder {
//     border-bottom-color: var(--bold-border-color);
// }
//
// table.dataframe tbody > tr:nth-child(odd) {
//     background: var(--background-odd);
// }
//
// table.dataframe tbody > tr:nth-child(even) {
//     background: var(--background);
// }
//
// table.dataframe tbody > tr:hover {
//     background: var(--background-hover);
// }
//
// table.dataframe a {
//     cursor: pointer;
//     color: var(--link-color);
//     text-decoration: none;
// }
//
// table.dataframe tr:hover > td a {
//     color: var(--link-color-pale);
// }
//
// table.dataframe a:hover {
//     color: var(--link-hover);
//     text-decoration: underline;
// }
//
// table.dataframe img {
//     max-width: fit-content;
// }
//
// table.dataframe th.complex {
//     background-color: var(--background);
//     border: 1px solid var(--background);
// }
//
// table.dataframe .leftBorder {
//     border-left-color: var(--inner-border-color);
// }
//
// table.dataframe .rightBorder {
//     border-right-color: var(--inner-border-color);
// }
//
// table.dataframe .rightAlign {
//     text-align: right;
// }
//
// table.dataframe .expanderSvg {
//     width: 8px;
//     height: 8px;
//     margin-right: 3px;
// }
//
// table.dataframe .expander {
//     display: flex;
//     align-items: center;
// }
//
// /* formatting */
//
// table.dataframe .null {
//     color: var(--text-color-pale);
// }
//
// table.dataframe .structural {
//     color: var(--text-color-medium);
//     font-weight: bold;
// }
//
// table.dataframe .dataFrameCaption {
//     font-weight: bold;
// }
//
// table.dataframe .numbers {
//     color: var(--text-color-dark);
// }
//
// table.dataframe td:hover .formatted .structural, .null {
//     color: var(--text-color-dark);
// }
//
// table.dataframe tr:hover .formatted .structural, .null {
//     color: var(--text-color-dark);
// }
//
//
//                 </style>

// %%
//convet string columnt to timestamp datatype
dfRaw=dfRaw.convert { startedAt }.toLocalDateTime(kotlinx.datetime.TimeZone.UTC)
dfRaw=dfRaw.convert { duration }.with {it*1000}
//and sort it by timestamp ascending
val df = dfRaw.sortBy { startedAt }

dfRaw.head(4)
// Out:
//         <html>
//         <head>
//             <style type="text/css">
//                 :root {
//     --background: #fff;
//     --background-odd: #f5f5f5;
//     --background-hover: #d9edfd;
//     --header-text-color: #474747;
//     --text-color: #848484;
//     --text-color-dark: #000;
//     --text-color-medium: #737373;
//     --text-color-pale: #b3b3b3;
//     --inner-border-color: #aaa;
//     --bold-border-color: #000;
//     --link-color: #296eaa;
//     --link-color-pale: #296eaa;
//     --link-hover: #1a466c;
// }
//
// :root[theme="dark"], :root [data-jp-theme-light="false"], .dataframe_dark{
//     --background: #303030;
//     --background-odd: #3c3c3c;
//     --background-hover: #464646;
//     --header-text-color: #dddddd;
//     --text-color: #b3b3b3;
//     --text-color-dark: #dddddd;
//     --text-color-medium: #b2b2b2;
//     --text-color-pale: #737373;
//     --inner-border-color: #707070;
//     --bold-border-color: #777777;
//     --link-color: #008dc0;
//     --link-color-pale: #97e1fb;
//     --link-hover: #00688e;
// }
//
// p.dataframe_description {
//     color: var(--text-color-dark);
// }
//
// table.dataframe {
//     font-family: "Helvetica Neue", Helvetica, Arial, sans-serif;
//     font-size: 12px;
//     background-color: var(--background);
//     color: var(--text-color-dark);
//     border: none;
//     border-collapse: collapse;
// }
//
// table.dataframe th, td {
//     padding: 6px;
//     border: 1px solid transparent;
//     text-align: left;
// }
//
// table.dataframe th {
//     background-color: var(--background);
//     color: var(--header-text-color);
// }
//
// table.dataframe td {
//     vertical-align: top;
// }
//
// table.dataframe th.bottomBorder {
//     border-bottom-color: var(--bold-border-color);
// }
//
// table.dataframe tbody > tr:nth-child(odd) {
//     background: var(--background-odd);
// }
//
// table.dataframe tbody > tr:nth-child(even) {
//     background: var(--background);
// }
//
// table.dataframe tbody > tr:hover {
//     background: var(--background-hover);
// }
//
// table.dataframe a {
//     cursor: pointer;
//     color: var(--link-color);
//     text-decoration: none;
// }
//
// table.dataframe tr:hover > td a {
//     color: var(--link-color-pale);
// }
//
// table.dataframe a:hover {
//     color: var(--link-hover);
//     text-decoration: underline;
// }
//
// table.dataframe img {
//     max-width: fit-content;
// }
//
// table.dataframe th.complex {
//     background-color: var(--background);
//     border: 1px solid var(--background);
// }
//
// table.dataframe .leftBorder {
//     border-left-color: var(--inner-border-color);
// }
//
// table.dataframe .rightBorder {
//     border-right-color: var(--inner-border-color);
// }
//
// table.dataframe .rightAlign {
//     text-align: right;
// }
//
// table.dataframe .expanderSvg {
//     width: 8px;
//     height: 8px;
//     margin-right: 3px;
// }
//
// table.dataframe .expander {
//     display: flex;
//     align-items: center;
// }
//
// /* formatting */
//
// table.dataframe .null {
//     color: var(--text-color-pale);
// }
//
// table.dataframe .structural {
//     color: var(--text-color-medium);
//     font-weight: bold;
// }
//
// table.dataframe .dataFrameCaption {
//     font-weight: bold;
// }
//
// table.dataframe .numbers {
//     color: var(--text-color-dark);
// }
//
// table.dataframe td:hover .formatted .structural, .null {
//     color: var(--text-color-dark);
// }
//
// table.dataframe tr:hover .formatted .structural, .null {
//     color: var(--text-color-dark);
// }
//
//
//
//
//             </style>
//         </head>
//         <body>
//
// <table class="dataframe" id="df_-1207959552"></table>
//
// <p class="dataframe_description">DataFrame: rowsCount = 4, columnsCount = 16</p>
//         </body>
//         <script>
//
// /*<!--*/
// call_DataFrame(function() { DataFrame.addTable({ cols: [{ name: "<span title=\"type: String\">type</span>", children: [], rightAlign: false, values: ["Young","Young","Young","Young"] },
// { name: "<span title=\"event_type: String\">event_type</span>", children: [], rightAlign: false, values: ["PauseEvent","PauseEvent","PauseEvent","PauseEvent"] },
// { name: "<span title=\"startedAt: kotlinx.datetime.LocalDateTime\">startedAt</span>", children: [], rightAlign: false, values: ["2023-07-18T16:38:34.550","2023-07-18T16:38:40.761","2023-07-18T16:38:47.252","2023-07-18T16:38:53.418"] },
// { name: "<span title=\"duration: Double\">duration</span>", children: [], rightAlign: true, values: ["<span class=\"formatted\" title=\"\"><span class=\"numbers\">7,961000</span></span>","<span class=\"formatted\" title=\"\"><span class=\"numbers\">7,288000</span></span>","<span class=\"formatted\" title=\"\"><span class=\"numbers\">7,701000</span></span>","<span class=\"formatted\" title=\"\"><span class=\"numbers\">6,213000</span></span>"] },
// { name: "<span title=\"cause: String\">cause</span>", children: [], rightAlign: false, values: ["G1_EVACUATION_PAUSE","G1_EVACUATION_PAUSE","G1_EVACUATION_PAUSE","G1_EVACUATION_PAUSE"] },
// { name: "<span title=\"cpu_user: Double\">cpu_user</span>", children: [], rightAlign: true, values: ["<span class=\"formatted\" title=\"\"><span class=\"numbers\">0,02</span></span>","<span class=\"formatted\" title=\"\"><span class=\"numbers\">0,01</span></span>","<span class=\"formatted\" title=\"\"><span class=\"numbers\">0,01</span></span>","<span class=\"formatted\" title=\"\"><span class=\"numbers\">0,01</span></span>"] },
// { name: "<span title=\"cpu_kernel: Double\">cpu_kernel</span>", children: [], rightAlign: true, values: ["<span class=\"formatted\" title=\"\"><span class=\"numbers\">0,0</span></span>","<span class=\"formatted\" title=\"\"><span class=\"numbers\">0,0</span></span>","<span class=\"formatted\" title=\"\"><span class=\"numbers\">0,0</span></span>","<span class=\"formatted\" title=\"\"><span class=\"numbers\">0,0</span></span>"] },
// { name: "<span title=\"cpu_wallClock: Double\">cpu_wallClock</span>", children: [], rightAlign: true, values: ["<span class=\"formatted\" title=\"\"><span class=\"numbers\">0,01</span></span>","<span class=\"formatted\" title=\"\"><span class=\"numbers\">0,01</span></span>","<span class=\"formatted\" title=\"\"><span class=\"numbers\">0,01</span></span>","<span class=\"formatted\" title=\"\"><span class=\"numbers\">0,00</span></span>"] },
// { name: "<span title=\"heap_occupancy_before_coll: Int\">heap_occupancy_before_coll</span>", children: [], rightAlign: true, values: ["<span class=\"formatted\" title=\"\"><span class=\"numbers\">742400</span></span>","<span class=\"formatted\" title=\"\"><span class=\"numbers\">751616</span></span>","<span class=\"formatted\" title=\"\"><span class=\"numbers\">745472</span></span>","<span class=\"formatted\" title=\"\"><span class=\"numbers\">746496</span></span>"] },
// { name: "<span title=\"heap_occupancy_after_coll: Int\">heap_occupancy_after_coll</span>", children: [], rightAlign: true, values: ["<span class=\"formatted\" title=\"\"><span class=\"numbers\">177152</span></span>","<span class=\"formatted\" title=\"\"><span class=\"numbers\">177152</span></span>","<span class=\"formatted\" title=\"\"><span class=\"numbers\">178176</span></span>","<span class=\"formatted\" title=\"\"><span class=\"numbers\">177152</span></span>"] },
// { name: "<span title=\"heap_size_before_coll: Int\">heap_size_before_coll</span>", children: [], rightAlign: true, values: ["<span class=\"formatted\" title=\"\"><span class=\"numbers\">921600</span></span>","<span class=\"formatted\" title=\"\"><span class=\"numbers\">921600</span></span>","<span class=\"formatted\" title=\"\"><span class=\"numbers\">921600</span></span>","<span class=\"formatted\" title=\"\"><span class=\"numbers\">921600</span></span>"] },
// { name: "<span title=\"heap_size_after_coll: Int\">heap_size_after_coll</span>", children: [], rightAlign: true, values: ["<span class=\"formatted\" title=\"\"><span class=\"numbers\">921600</span></span>","<span class=\"formatted\" title=\"\"><span class=\"numbers\">921600</span></span>","<span class=\"formatted\" title=\"\"><span class=\"numbers\">921600</span></span>","<span class=\"formatted\" title=\"\"><span class=\"numbers\">921600</span></span>"] },
// { name: "<span title=\"perm_or_meta_occupancy_before_coll: Int\">perm_or_meta_occupancy_before_coll</span>", children: [], rightAlign: true, values: ["<span class

// %%
//initial theme for charts
val blankTheme = theme {
    global.line {
        blank = true
    }
    blankAxes()
}

// %% [markdown]
// # Part III - Events data structure
//
// *(Now we can use DSL to data examinations). We can use kotlin dataframe feature.*

// %%
//list all columns
df.schema()
// Out:
// type: String
// event_type: String
// startedAt: kotlinx.datetime.LocalDateTime
// duration: Double
// cause: String
// cpu_user: Double
// cpu_kernel: Double
// cpu_wallClock: Double
// heap_occupancy_before_coll: Int
// heap_occupancy_after_coll: Int
// heap_size_before_coll: Int
// heap_size_after_coll: Int
// perm_or_meta_occupancy_before_coll: Int
// perm_or_meta_occupancy_after_coll: Int
// perm_or_meta_size_before_coll: Int
// perm_or_meta_size_after_coll: Int

// %% [markdown]
// ### The most useful columns
//
// #### *1. type - (GC Event type)*
// Event type - is visualized on [this chart] (https://github.com/microsoft/gctoolkit/blob/main/images/GCToolkit_Events.png) as a G1GcEvent family
//
// #### *2. event_type*
// Column grouping stop-the-world and concurrent events. Allows calculation of pauses duration and comparation them with concurrent phases duration.
//
// #### *3. startedAt*
// Timestamp
//
// #### *4. duration*
// Phase duration **(in seconds!)**
//
// #### *5. cause - GC causes*
//
// #### *Summary*
// **Based on these columns we can perform many useful aggregations and visualisations!**

// %% [markdown]
// # Part IV - Analysis of GC performing

// %% [markdown]
// ## All phases - examination

// %%
//get aggregated info about each gc phase duration
val all = df.count()
val phasesSummary=df.select {type and duration}.groupBy{type}.aggregate {
    count() into "count"
    duration.toList().percentile(50.0) into "Per.50 [ms]"
    duration.toList().percentile(75.0) into "Per.75 [ms]"
    duration.toList().percentile(95.0) into "Per.95 [ms]"
    duration.toList().percentile(99.0) into "Per.99 [ms]"
    duration.toList().percentile(99.0) into "Per.100 [ms]"
    sum(duration) into "sum [ms]"
    max(duration) into "max [ms]"
    min(duration) into "min [ms]"
    mean(duration) into "avg [ms]"
    ((count().toDouble()*100/all))  into "percentage"
 }
phasesSummary
// Out:
//         <html>
//         <head>
//             <style type="text/css">
//                 :root {
//     --background: #fff;
//     --background-odd: #f5f5f5;
//     --background-hover: #d9edfd;
//     --header-text-color: #474747;
//     --text-color: #848484;
//     --text-color-dark: #000;
//     --text-color-medium: #737373;
//     --text-color-pale: #b3b3b3;
//     --inner-border-color: #aaa;
//     --bold-border-color: #000;
//     --link-color: #296eaa;
//     --link-color-pale: #296eaa;
//     --link-hover: #1a466c;
// }
//
// :root[theme="dark"], :root [data-jp-theme-light="false"], .dataframe_dark{
//     --background: #303030;
//     --background-odd: #3c3c3c;
//     --background-hover: #464646;
//     --header-text-color: #dddddd;
//     --text-color: #b3b3b3;
//     --text-color-dark: #dddddd;
//     --text-color-medium: #b2b2b2;
//     --text-color-pale: #737373;
//     --inner-border-color: #707070;
//     --bold-border-color: #777777;
//     --link-color: #008dc0;
//     --link-color-pale: #97e1fb;
//     --link-hover: #00688e;
// }
//
// p.dataframe_description {
//     color: var(--text-color-dark);
// }
//
// table.dataframe {
//     font-family: "Helvetica Neue", Helvetica, Arial, sans-serif;
//     font-size: 12px;
//     background-color: var(--background);
//     color: var(--text-color-dark);
//     border: none;
//     border-collapse: collapse;
// }
//
// table.dataframe th, td {
//     padding: 6px;
//     border: 1px solid transparent;
//     text-align: left;
// }
//
// table.dataframe th {
//     background-color: var(--background);
//     color: var(--header-text-color);
// }
//
// table.dataframe td {
//     vertical-align: top;
// }
//
// table.dataframe th.bottomBorder {
//     border-bottom-color: var(--bold-border-color);
// }
//
// table.dataframe tbody > tr:nth-child(odd) {
//     background: var(--background-odd);
// }
//
// table.dataframe tbody > tr:nth-child(even) {
//     background: var(--background);
// }
//
// table.dataframe tbody > tr:hover {
//     background: var(--background-hover);
// }
//
// table.dataframe a {
//     cursor: pointer;
//     color: var(--link-color);
//     text-decoration: none;
// }
//
// table.dataframe tr:hover > td a {
//     color: var(--link-color-pale);
// }
//
// table.dataframe a:hover {
//     color: var(--link-hover);
//     text-decoration: underline;
// }
//
// table.dataframe img {
//     max-width: fit-content;
// }
//
// table.dataframe th.complex {
//     background-color: var(--background);
//     border: 1px solid var(--background);
// }
//
// table.dataframe .leftBorder {
//     border-left-color: var(--inner-border-color);
// }
//
// table.dataframe .rightBorder {
//     border-right-color: var(--inner-border-color);
// }
//
// table.dataframe .rightAlign {
//     text-align: right;
// }
//
// table.dataframe .expanderSvg {
//     width: 8px;
//     height: 8px;
//     margin-right: 3px;
// }
//
// table.dataframe .expander {
//     display: flex;
//     align-items: center;
// }
//
// /* formatting */
//
// table.dataframe .null {
//     color: var(--text-color-pale);
// }
//
// table.dataframe .structural {
//     color: var(--text-color-medium);
//     font-weight: bold;
// }
//
// table.dataframe .dataFrameCaption {
//     font-weight: bold;
// }
//
// table.dataframe .numbers {
//     color: var(--text-color-dark);
// }
//
// table.dataframe td:hover .formatted .structural, .null {
//     color: var(--text-color-dark);
// }
//
// table.dataframe tr:hover .formatted .structural, .null {
//     color: var(--text-color-dark);
// }
//
//
//
//
//             </style>
//         </head>
//         <body>
//
// <table class="dataframe" id="df_-1207959551"></table>
//
// <p class="dataframe_description">DataFrame: rowsCount = 9, columnsCount = 12</p>
//         </body>
//         <script>
//
// /*<!--*/
// call_DataFrame(function() { DataFrame.addTable({ cols: [{ name: "<span title=\"type: String\">type</span>", children: [], rightAlign: false, values: ["Young","G1GCYoungInitialMark","G1GCConcurrentUndoCycle","ConcurrentCleanupForNextMark","ConcurrentClearClaimedMarks","ConcurrentRootRegionScan","G1GCRemark","G1GCConcurrentCleanup","Mixed"] },
// { name: "<span title=\"count: Int\">count</span>", children: [], rightAlign: true, values: ["<span class=\"formatted\" title=\"\"><span class=\"numbers\">11546</span></span>","<span class=\"formatted\" title=\"\"><span class=\"numbers\">2208</span></span>","<span class=\"formatted\" title=\"\"><span class=\"numbers\">2095</span></span>","<span class=\"formatted\" title=\"\"><span class=\"numbers\">2208</span></span>","<span class=\"formatted\" title=\"\"><span class=\"numbers\">113</span></span>","<span class=\"formatted\" title=\"\"><span class=\"numbers\">113</span></span>","<span class=\"formatted\" title=\"\"><span class=\"numbers\">113</span></span>","<span class=\"formatted\" title=\"\"><span class=\"numbers\">113</span></span>","<span class=\"formatted\" title=\"\"><span class=\"numbers\">113</span></span>"] },
// { name: "<span title=\"Per.50 [ms]: Double\">Per.50 [ms]</span>", children: [], rightAlign: true, values: ["<span class=\"formatted\" title=\"\"><span class=\"numbers\">5,6520</span></span>","<span class=\"formatted\" title=\"\"><span class=\"numbers\">5,9125</span></span>","<span class=\"formatted\" title=\"\"><span class=\"numbers\">1,3910</span></span>","<span class=\"formatted\" title=\"\"><span class=\"numbers\">1,3540</span></span>","<span class=\"formatted\" title=\"\"><span class=\"numbers\">0,0650</span></span>","<span class=\"formatted\" title=\"\"><span class=\"numbers\">2,8070</span></span>","<span class=\"formatted\" title=\"\"><span class=\"numbers\">21,8450</span></span>","<span class=\"formatted\" title=\"\"><span class=\"numbers\">56,7020</span></span>","<span class=\"formatted\" title=\"\"><span class=\"numbers\">5,3230</span></span>"] },
// { name: "<span title=\"Per.75 [ms]: Double\">Per.75 [ms]</span>", children: [], rightAlign: true, values: ["<span class=\"formatted\" title=\"\"><span class=\"numbers\">6,316000</span></span>","<span class=\"formatted\" title=\"\"><span class=\"numbers\">6,699500</span></span>","<span class=\"formatted\" title=\"\"><span class=\"numbers\">1,637000</span></span>","<span class=\"formatted\" title=\"\"><span class=\"numbers\">1,600750</span></span>","<span class=\"formatted\" title=\"\"><span class=\"numbers\">0,093500</span></span>","<span class=\"formatted\" title=\"\"><span class=\"numbers\">3,138500</span></span>","<span class=\"formatted\" title=\"\"><span class=\"numbers\">24,452000</span></span>","<span class=\"formatted\" title=\"\"><span class=\"numbers\">58,664000</span></span>","<span class=\"formatted\" title=\"\"><span class=\"numbers\">7,044500</span></span>"] },
// { name: "<span title=\"Per.95 [ms]: Double\">Per.95 [ms]</span>", children: [], rightAlign: true, values: ["<span class=\"formatted\" title=\"\"><span class=\"numbers\">7,618300</span></span>","<span class=\"formatted\" title=\"\"><span class=\"numbers\">8,050100</span></span>","<span class=\"formatted\" title=\"\"><span class=\"numbers\">2,515400</span></span>","<span class=\"formatted\" title=\"\"><span class=\"numbers\">2,564100</span></span>","<span class=\"formatted\" title=\"\"><span class=\"numbers\">0,130500</span></span>","<span class=\"formatted\" title=\"\"><span class=\"numbers\">4,608800</span></span>","<span class=\"formatted\" title=\"\"><span class=\"numbers\">32,087600</span></span>","<span class=\"formatted\" title=\"\"><span class=\"numbers\">61,712600</span></span>","<span class=\"formatted\" title=\"\"><span class=\"numbers\">9,173000</span></span>"] },
// { name: "<span title=\"Per.99 [ms]: Double\">Per.99 [ms]</span>", children: [], rightAlign: true, values: ["<span class=\"formatted\" title=\"\"><span class=\"numbers\">9,021000</span></span>","<span class=\"formatted\" title=\"\"><span class=\"numbers\">9,417290</span></span>","<span class=\"formatted\" title=\"\"><span class=\"numbers\">3,568360</span></span>","<span class=\"formatted\" title=\"\"><span class=\"numbers\">3,550020</span></span>","<span class=\"formatted\" title=\"\"><span class=\"numbers\">0,168160</span></span>","<span class=\"formatted\" title=\"\"><span class=\"numbers\">5,484220</span></span>","<span class=\"formatted\" title=\"\"><span class=\"numbers\">44,675380</span></span>","<span class=\"formatted\" title=\"\"><span

// %%
val (w, h) = 700 to 350

phasesSummary.plot {
    pie {
        slice(percentage)
        fillColor(type)
        size=30.0
    }
    layout {
        size = w to h
        theme(blankTheme)
        title="GC phases - percentage"
    }
 }
// Out:
//             <script type="text/javascript" data-lets-plot-script="library" src="https://cdn.jsdelivr.net/gh/JetBrains/lets-plot@v3.1.0/js-package/distr/lets-plot.min.js"></script>
//                <div id="0K1sSL"></div>
//    <script type="text/javascript" data-lets-plot-script="plot">
//        var plotSpec={
// "ggtitle":{
// "text":"GC phases - percentage"
// },
// "mapping":{
// },
// "data":{
// "percentage":[62.001933197293525,11.85694340027924,11.250134249812051,11.85694340027924,0.6068091504671893,0.6068091504671893,0.6068091504671893,0.6068091504671893,0.6068091504671893],
// "type":["Young","G1GCYoungInitialMark","G1GCConcurrentUndoCycle","ConcurrentCleanupForNextMark","ConcurrentClearClaimedMarks","ConcurrentRootRegionScan","G1GCRemark","G1GCConcurrentCleanup","Mixed"]
// },
// "ggsize":{
// "width":700.0,
// "height":350.0
// },
// "kind":"plot",
// "scales":[{
// "aesthetic":"fill",
// "discrete":true
// }],
// "layers":[{
// "mapping":{
// "slice":"percentage",
// "fill":"type"
// },
// "stat":"identity",
// "size":30.0,
// "sampling":"none",
// "position":"identity",
// "geom":"pie",
// "data":{
// }
// }],
// "theme":{
// "axis":"blank",
// "axis_ontop":false,
// "axis_ontop_y":false,
// "line":{
// "blank":true
// },
// "axis_ontop_x":false
// }
// };
//        var plotContainer = document.getElementById("0K1sSL");
//        LetsPlot.buildPlotFromProcessedSpecs(plotSpec, -1, -1, plotContainer);
//    </script>
//         <svg id=e055c668-6220-4aa5-90ec-21f0b8708f63 xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" class="plt-container" width="700.0" height="350.0">
//   <style type="text/css">
//   .plt-container {
//    font-family: Lucida Grande, sans-serif;
//    user-select: none;
//    -webkit-user-select: none;
//    -moz-user-select: none;
//    -ms-user-select: none;
// }
// text {
//    text-rendering: optimizeLegibility;
// }
// #pmWd1LA .plot-title {
//    fill: #474747;
//    font-family: Lucida Grande, sans-serif;
//    font-size: 16.0px;
//    font-weight: normal;
//    font-style: normal;
// }
// #pmWd1LA .plot-subtitle {
//    fill: #474747;
//    font-family: Lucida Grande, sans-serif;
//    font-size: 15.0px;
//    font-weight: normal;
//    font-style: normal;
// }
// #pmWd1LA .plot-caption {
//    fill: #474747;
//    font-family: Lucida Grande, sans-serif;
//    font-size: 13.0px;
//    font-weight: normal;
//    font-style: normal;
// }
// #pmWd1LA .legend-title {
//    fill: #474747;
//    font-family: Lucida Grande, sans-serif;
//    font-size: 15.0px;
//    font-weight: normal;
//    font-style: normal;
// }
// #pmWd1LA .legend-item {
//    fill: #474747;
//    font-family: Lucida Grande, sans-serif;
//    font-size: 13.0px;
//    font-weight: normal;
//    font-style: normal;
// }
// #pmWd1LA .axis-title-x {
//    fill: #474747;
//    font-family: Lucida Grande, sans-serif;
//    font-size: 15.0px;
//    font-weight: normal;
//    font-style: normal;
// }
// #pmWd1LA .axis-text-x {
//    fill: #474747;
//    font-family: Lucida Grande, sans-serif;
//    font-size: 13.0px;
//    font-weight: normal;
//    font-style: normal;
// }
// #dfBMsa1 .axis-tooltip-text-x {
//    fill: #ffffff;
//    font-family: Lucida Grande, sans-serif;
//    font-size: 13.0px;
//    font-weight: normal;
//    font-style: normal;
// }
// #pmWd1LA .axis-title-y {
//    fill: #474747;
//    font-family: Lucida Grande, sans-serif;
//    font-size: 15.0px;
//    font-weight: normal;
//    font-style: normal;
// }
// #pmWd1LA .axis-text-y {
//    fill: #474747;
//    font-family: Lucida Grande, sans-serif;
//    font-size: 13.0px;
//    font-weight: normal;
//    font-style: normal;
// }
// #dfBMsa1 .axis-tooltip-text-y {
//    fill: #ffffff;
//    font-family: Lucida Grande, sans-serif;
//    font-size: 13.0px;
//    font-weight: normal;
//    font-style: normal;
// }
// #pmWd1LA .facet-strip-text-x {
//    fill: #474747;
//    font-family: Lucida Grande, sans-serif;
//    font-size: 13.0px;
//    font-weight: normal;
//    font-style: normal;
// }
// #pmWd1LA .facet-strip-text-y {
//    fill: #474747;
//    font-family: Lucida Grande, sans-serif;
//    font-size: 13.0px;
//    font-weight: normal;
//    font-style: normal;
// }
// #dfBMsa1 .tooltip-text {
//    fill: #474747;
//    font-family: Lucida Grande, sans-serif;
//    font-size: 13.0px;
//    font-weight: normal;
//    font-style: normal;
// }
// #dfBMsa1 .tooltip-title {
//    fill: #474747;
//    font-family: Lucida Grande, sans-serif;
//    font-size: 13.0px;
//    font-weight: bold;
//    font-style: normal;
// }
// #dfBMsa1 .tooltip-label {
//    fill: #474747;
//    font-family: Lucida Grande, sans-serif;
//    font-size: 13.0px;
//    font-weight: bold;
//    font-style: normal;
// }
//
//   </style>
//   <g id="pmWd1LA">
//     <rect x="0.0" y="0.0" height="350.0" width="700.0" stroke="rgb(71,71,71)" stroke-opacity="1.0" stroke-width="0.0" fill="rgb(255,255,255)" fill-opacity="1.0">
//     </rect>
//     <g transform="translate(10.0 34.0 ) ">
//       <g transform="translate(0.0 306.0 ) ">
//       </g>
//       <g transform="">
//       </g>
//       <g transform="" clip-path="url(#cc2iwBZ)" clip-bounds-jfx="[rect (0.0, 0.0), (420.9168073575391, 306.0)]">
//         <defs>
//           <clipPath id="cc2iwBZ">
//             <rect x="0.0" y="0.0" width="420.9168073575391" height="306.0">
//             </rect>
//           </clipPath>
//         </defs>
//         <g>
//           <path d="M210.45840367876954 153.0 L313.15375058631787 262.3328208889641 A150.0 150.0 0.0 1 1 210.45840367876954 3.0 L210.45840367876954 153.0 A0.0 0.0 0.0 1 0 210.45840367876954 153.0 " fill="rgb(141,211,199)" stroke-width="0.0" fill-opacity="1.0" stroke="rgb(255,255,255)" stroke-opacity="1.0">
//           </path>
//         </g>
//         <g>
//           <path d="M210.45840367876954 153.0 L210.45840367876954 3.0 A150.0 150.0 0.0 0 1 312.15348341056057 42.736176565726396 L210.45840367876954 153.0 A0.0 0.0 0.0 0 0 210.45840367876954 153.0 " fill="rgb(255,255,179)" stroke-width="0.0" fill-opacity="1.0" stroke="rgb(255,255,255)" stroke-opacity="1.0">
//           </path>
//         </g>
//         <g>
//           <path d="M210.45840367876954 153.0 L312.15348341056057 42.736176565726396 A150.0 150.0 0.0 0 1 359.3987240470457 135.20165826276866 L210.45840367876954 153.0 A0.0 0.0 0.0 0 0 210.45840367876954 153.0 " fill="rgb(190,186,218)" stroke-width="0.0" fill-opacity="1.0" stroke="rgb(255,255,255)" stroke-opacity="1.0">
//           </path>
//         </g>
//         <g>
//           <path d="M210.45840367876954 153.0 L359.3987240470457 135.20165826276866 A150.0 150.0 0.0 0 1 332.0099568080572 240.89323029595602 L210.45840367876954 153.0 A0.0 0.0 0.0 0 0 210.45840367876954 153.0 " fill="rgb(251,128,114)" stroke-width="0.0" fill-opacity="1.0" stroke="rgb(255,255,255)" stroke-opacity="1.0">
//           </path>
//         </g>
//         <g>
//           <path d="M210.45840367876954 153.0 L332.0099568080572 240.89323029595602 A150.0 150.0 0.0 0 1 328.57133158392196 245.4626208890504 L210.45840367876954 153.0 A0.0 0.0 0.0 0 0 210.45840367876954 153.0 " fill="rgb(128,177,211)" stroke-width="0.0" fill-opacity="1.0" stroke="rgb(255,255,255)" stroke-opacity="1.0">
//           </path>
//         </g>
//         <g>
//           <path d="M210.45840367876954 153.0 L328.57133158392196 245.4626208890504 A150.0 150.0 0.0 0 1 324.96103066885075 249.8976181976127 L210.45840367876954 153.0 A0.0 0.0 0.0 0 0 210.45840367876954 153.0 " fill="rgb(253,180,98)" stroke-width="0.0" fill-opacity="1.0" stroke="rgb(255,255,255)" stroke-opacity="1.0">
//           </path>
//         </g>
//         <g>
//           <path d="M210.45840367876954 153.0 L324.96103066885075 249.8976181976127 A150.0 150.0 0.0 0 1 321.18430159090906 254.19177600749208 L210.45840367876954 153.0 A0.0 0.0 0.0 0 0 210.45840367876954 153.0 " fill="rgb(179,222,105)" stroke-width="0.0" fill-opacity="1.0" stroke="rgb(255,255,255)" stroke-opacity="1.0">
//           </path>
//         </g>
//         <g>
//           <path d="M210.45840367876954 153.0 L321.18430159090906 254.19177600749208 A150.0 150.0 0.0 0 1 317.2466337794543 258.3388528130205 L210.45840367876954 153.0 A0.0 0.0 0.0 0 0 210.45840367876954 153.0 " fill="rgb(252,205,229)" stroke-width="0.0" fill-opacity="1.0" stroke="rgb(255,255,255)" stroke-opacity="1.0">
//           </path>
//         </g>
//         <g>
//           <path d="M210.45840367876954 153.0 L317.2466337794543 258.3388528130205 A150.0 150.0 0.0 0 1 313.15375058631764 262.33282088

// %%
phasesSummary.plot {
    bars {
        x(type)
        y("sum [ms]")
       
        fillColor("sum [ms]"<Int>()) {
            scale = continuous(range = Color.YELLOW..Color.RED)
   
        borderLine.width = 0.0
    }
    }
    layout.title = "Phases duration sum [ms]"
    layout.size = 950 to 500
}
// Out:
//             <script type="text/javascript" data-lets-plot-script="library" src="https://cdn.jsdelivr.net/gh/JetBrains/lets-plot@v3.1.0/js-package/distr/lets-plot.min.js"></script>
//                <div id="vkTXzh"></div>
//    <script type="text/javascript" data-lets-plot-script="plot">
//        var plotSpec={
// "ggtitle":{
// "text":"Phases duration sum [ms]"
// },
// "mapping":{
// },
// "data":{
// "type":["Young","G1GCYoungInitialMark","G1GCConcurrentUndoCycle","ConcurrentCleanupForNextMark","ConcurrentClearClaimedMarks","ConcurrentRootRegionScan","G1GCRemark","G1GCConcurrentCleanup","Mixed"],
// "sum [ms]":[67066.84599999999,13436.891000000012,3207.9350000000004,3305.6609999999982,8.007,330.1789999999999,2622.6949999999997,6468.581999999999,659.3359999999999]
// },
// "ggsize":{
// "width":950.0,
// "height":500.0
// },
// "kind":"plot",
// "scales":[{
// "aesthetic":"x",
// "discrete":true
// },{
// "aesthetic":"y",
// "limits":[null,null]
// },{
// "aesthetic":"fill",
// "scale_mapper_kind":"color_gradient",
// "high":"#ee6666",
// "low":"#fac858",
// "limits":[null,null]
// }],
// "layers":[{
// "mapping":{
// "x":"type",
// "y":"sum [ms]",
// "fill":"sum [ms]"
// },
// "stat":"identity",
// "size":0.0,
// "sampling":"none",
// "position":"dodge",
// "geom":"bar",
// "data":{
// }
// }]
// };
//        var plotContainer = document.getElementById("vkTXzh");
//        LetsPlot.buildPlotFromProcessedSpecs(plotSpec, -1, -1, plotContainer);
//    </script>
//         <svg id=d070a18e-28fc-4a00-a43c-5d4e4bc20fb5 xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" class="plt-container" width="950.0" height="500.0">
//   <style type="text/css">
//   .plt-container {
//    font-family: Lucida Grande, sans-serif;
//    user-select: none;
//    -webkit-user-select: none;
//    -moz-user-select: none;
//    -ms-user-select: none;
// }
// text {
//    text-rendering: optimizeLegibility;
// }
// #p1zIfAZ .plot-title {
//    fill: #474747;
//    font-family: Lucida Grande, sans-serif;
//    font-size: 16.0px;
//    font-weight: normal;
//    font-style: normal;
// }
// #p1zIfAZ .plot-subtitle {
//    fill: #474747;
//    font-family: Lucida Grande, sans-serif;
//    font-size: 15.0px;
//    font-weight: normal;
//    font-style: normal;
// }
// #p1zIfAZ .plot-caption {
//    fill: #474747;
//    font-family: Lucida Grande, sans-serif;
//    font-size: 13.0px;
//    font-weight: normal;
//    font-style: normal;
// }
// #p1zIfAZ .legend-title {
//    fill: #474747;
//    font-family: Lucida Grande, sans-serif;
//    font-size: 15.0px;
//    font-weight: normal;
//    font-style: normal;
// }
// #p1zIfAZ .legend-item {
//    fill: #474747;
//    font-family: Lucida Grande, sans-serif;
//    font-size: 13.0px;
//    font-weight: normal;
//    font-style: normal;
// }
// #p1zIfAZ .axis-title-x {
//    fill: #474747;
//    font-family: Lucida Grande, sans-serif;
//    font-size: 15.0px;
//    font-weight: normal;
//    font-style: normal;
// }
// #p1zIfAZ .axis-text-x {
//    fill: #474747;
//    font-family: Lucida Grande, sans-serif;
//    font-size: 13.0px;
//    font-weight: normal;
//    font-style: normal;
// }
// #dh4CoHI .axis-tooltip-text-x {
//    fill: #ffffff;
//    font-family: Lucida Grande, sans-serif;
//    font-size: 13.0px;
//    font-weight: normal;
//    font-style: normal;
// }
// #p1zIfAZ .axis-title-y {
//    fill: #474747;
//    font-family: Lucida Grande, sans-serif;
//    font-size: 15.0px;
//    font-weight: normal;
//    font-style: normal;
// }
// #p1zIfAZ .axis-text-y {
//    fill: #474747;
//    font-family: Lucida Grande, sans-serif;
//    font-size: 13.0px;
//    font-weight: normal;
//    font-style: normal;
// }
// #dh4CoHI .axis-tooltip-text-y {
//    fill: #ffffff;
//    font-family: Lucida Grande, sans-serif;
//    font-size: 13.0px;
//    font-weight: normal;
//    font-style: normal;
// }
// #p1zIfAZ .facet-strip-text-x {
//    fill: #474747;
//    font-family: Lucida Grande, sans-serif;
//    font-size: 13.0px;
//    font-weight: normal;
//    font-style: normal;
// }
// #p1zIfAZ .facet-strip-text-y {
//    fill: #474747;
//    font-family: Lucida Grande, sans-serif;
//    font-size: 13.0px;
//    font-weight: normal;
//    font-style: normal;
// }
// #dh4CoHI .tooltip-text {
//    fill: #474747;
//    font-family: Lucida Grande, sans-serif;
//    font-size: 13.0px;
//    font-weight: normal;
//    font-style: normal;
// }
// #dh4CoHI .tooltip-title {
//    fill: #474747;
//    font-family: Lucida Grande, sans-serif;
//    font-size: 13.0px;
//    font-weight: bold;
//    font-style: normal;
// }
// #dh4CoHI .tooltip-label {
//    fill: #474747;
//    font-family: Lucida Grande, sans-serif;
//    font-size: 13.0px;
//    font-weight: bold;
//    font-style: normal;
// }
//
//   </style>
//   <g id="p1zIfAZ">
//     <rect x="0.0" y="0.0" height="500.0" width="950.0" stroke="rgb(71,71,71)" stroke-opacity="1.0" stroke-width="0.0" fill="rgb(255,255,255)" fill-opacity="1.0">
//     </rect>
//     <g transform="translate(23.0 34.0 ) ">
//       <g transform="translate(50.97651758668602 315.6952247934389 ) ">
//         <line x1="54.100734447772155" y1="-0.0" x2="54.100734447772155" y2="-315.6952247934389" stroke="rgb(233,233,233)" stroke-opacity="1.0" stroke-width="1.0">
//         </line>
//         <line x1="137.33263359819085" y1="-0.0" x2="137.33263359819085" y2="-315.6952247934389" stroke="rgb(233,233,233)" stroke-opacity="1.0" stroke-width="1.0">
//         </line>
//         <line x1="220.56453274860957" y1="-0.0" x2="220.56453274860957" y2="-315.6952247934389" stroke="rgb(233,233,233)" stroke-opacity="1.0" stroke-width="1.0">
//         </line>
//         <line x1="303.7964318990282" y1="-0.0" x2="303.7964318990282" y2="-315.6952247934389" stroke="rgb(233,233,233)" stroke-opacity="1.0" stroke-width="1.0">
//         </line>
//         <line x1="387.02833104944693" y1="-0.0" x2="387.02833104944693" y2="-315.6952247934389" stroke="rgb(233,233,233)" stroke-opacity="1.0" stroke-width="1.0">
//         </line>
//         <line x1="470.26023019986565" y1="-0.0" x2="470.26023019986565" y2="-315.6952247934389" stroke="rgb(233,233,233)" stroke-opacity="1.0" stroke-width="1.0">
//         </line>
//         <line x1="553.4921293502844" y1="-0.0" x2="553.4921293502844" y2="-315.6952247934389" stroke="rgb(233,233,233)" stroke-opacity="1.0" stroke-width="1.0">
//         </line>
//         <line x1="636.7240285007031" y1="-0.0" x2="636.7240285007031" y2="-315.6952247934389" stroke="rgb(233,233,233)" stroke-opacity="1.0" stroke-width="1.0">
//         </line>
//         <line x1="719.9559276511218" y1="-0.0" x2="719.9559276511218" y2="-315.6952247934389" stroke="rgb(233,233,233)" stroke-opacity="1.0" stroke-width="1.0">
//         </line>
//         <g transform="translate(54.100734447772155 0.0 ) ">
//           <line stroke-width="1.0" stroke="rgb(71,71,71)" stroke-opacity="1.0" x2="0.0" y2="4.0">
//           </line>
//           <g transform="translate(0.0 7.0 ) rotate(-30.0 ) ">
//             <text class="axis-text-x" text-anchor="end" dy="0.7em">
//             Young
//             </text>
//           </g>
//         </g>
//         <g transform="translate(137.33263359819085 0.0 ) ">
//           <line stroke-width="1.0" stroke="rgb(71,71,71)" stroke-opacity="1.0" x2="0.0" y2="4.0">
//           </line>
//           <g transform="translate(0.0 7.0 ) rotate(-30.0 ) ">
//             <text class="axis-text-x" text-anchor="end" dy="0.7em">
//             G1GCYoungInitialMark
//             </text>
//           </g>
//         </g>
//         <g transform="translate(220.56453274860957 0.0 ) ">
//           <line stroke-width="1.0" stroke="rgb(71,71,71)" stroke-opacity="1.0" x2="0.0" y2="4.0">
//           </line>
//           <g transform="translate(0.0 7.0 ) rotate(-30.0 ) ">
//             <text class="axis-text-x" text-anchor="end" dy="0.7em">
//             G1GCConcurrentUndoCycle
//             </text>
//           </g>
//         </g>
//         <g transform="translate(303.7964318990282 0.0 ) ">
//           <line stroke-width="1.0" stroke="rgb(71,71,71)" stroke-opacity="1.0" x2="0.0" y2="4.0">
//           </line>
//           <g transform="translate(0.0 7.0 ) rotate(-30.0 ) ">
//             <text class="axis-text-x" text-anchor="end" dy="0.7em">
//             ConcurrentCleanupForNextMark
//             </text>
//           </g>
//         </g>
//         <g transform="translate(387.02833104944693 0.0 ) ">
//           <line stroke-width="1.0" stroke="rgb(71,71,71)" stroke-opacity="1.0" x2="0.0" y2="4.0">
//           </

// %% [markdown]
// ## Pauses - examination

// %% [markdown]
// <img style="float: left; margin-right:20px;" src="idea.png">  **Tip:** Of most interest to us are the phases that cause the application threads to stop.<br> We call these phases of the *stop-the-world* type. <br> We can find them using the filter *event_type=="PauseEvent"*!

// %%
//get aggregated info about each gc phase duration
val all = df.filter{event_type=="PauseEvent"}.count()
val pausesSummary=df.filter{event_type=="PauseEvent"}.select {type and duration}.groupBy{type}.aggregate {
    count() into "count"
    duration.toList().percentile(50.0) into "Per.50 [ms]"
    duration.toList().percentile(75.0) into "Per.75 [ms]"
    duration.toList().percentile(95.0) into "Per.95 [ms]"
    duration.toList().percentile(99.0) into "Per.99 [ms]"
    duration.toList().percentile(99.0) into "Per.100 [ms]"
    sum(duration) into "sum [ms]"
    max(duration) into "max [ms]"
    min(duration) into "min [ms]"
    mean(duration) into "avg [ms]"
    ((count().toDouble()*100/all))  into "percentage"
 }
pausesSummary
// Out:
//         <html>
//         <head>
//             <style type="text/css">
//                 :root {
//     --background: #fff;
//     --background-odd: #f5f5f5;
//     --background-hover: #d9edfd;
//     --header-text-color: #474747;
//     --text-color: #848484;
//     --text-color-dark: #000;
//     --text-color-medium: #737373;
//     --text-color-pale: #b3b3b3;
//     --inner-border-color: #aaa;
//     --bold-border-color: #000;
//     --link-color: #296eaa;
//     --link-color-pale: #296eaa;
//     --link-hover: #1a466c;
// }
//
// :root[theme="dark"], :root [data-jp-theme-light="false"], .dataframe_dark{
//     --background: #303030;
//     --background-odd: #3c3c3c;
//     --background-hover: #464646;
//     --header-text-color: #dddddd;
//     --text-color: #b3b3b3;
//     --text-color-dark: #dddddd;
//     --text-color-medium: #b2b2b2;
//     --text-color-pale: #737373;
//     --inner-border-color: #707070;
//     --bold-border-color: #777777;
//     --link-color: #008dc0;
//     --link-color-pale: #97e1fb;
//     --link-hover: #00688e;
// }
//
// p.dataframe_description {
//     color: var(--text-color-dark);
// }
//
// table.dataframe {
//     font-family: "Helvetica Neue", Helvetica, Arial, sans-serif;
//     font-size: 12px;
//     background-color: var(--background);
//     color: var(--text-color-dark);
//     border: none;
//     border-collapse: collapse;
// }
//
// table.dataframe th, td {
//     padding: 6px;
//     border: 1px solid transparent;
//     text-align: left;
// }
//
// table.dataframe th {
//     background-color: var(--background);
//     color: var(--header-text-color);
// }
//
// table.dataframe td {
//     vertical-align: top;
// }
//
// table.dataframe th.bottomBorder {
//     border-bottom-color: var(--bold-border-color);
// }
//
// table.dataframe tbody > tr:nth-child(odd) {
//     background: var(--background-odd);
// }
//
// table.dataframe tbody > tr:nth-child(even) {
//     background: var(--background);
// }
//
// table.dataframe tbody > tr:hover {
//     background: var(--background-hover);
// }
//
// table.dataframe a {
//     cursor: pointer;
//     color: var(--link-color);
//     text-decoration: none;
// }
//
// table.dataframe tr:hover > td a {
//     color: var(--link-color-pale);
// }
//
// table.dataframe a:hover {
//     color: var(--link-hover);
//     text-decoration: underline;
// }
//
// table.dataframe img {
//     max-width: fit-content;
// }
//
// table.dataframe th.complex {
//     background-color: var(--background);
//     border: 1px solid var(--background);
// }
//
// table.dataframe .leftBorder {
//     border-left-color: var(--inner-border-color);
// }
//
// table.dataframe .rightBorder {
//     border-right-color: var(--inner-border-color);
// }
//
// table.dataframe .rightAlign {
//     text-align: right;
// }
//
// table.dataframe .expanderSvg {
//     width: 8px;
//     height: 8px;
//     margin-right: 3px;
// }
//
// table.dataframe .expander {
//     display: flex;
//     align-items: center;
// }
//
// /* formatting */
//
// table.dataframe .null {
//     color: var(--text-color-pale);
// }
//
// table.dataframe .structural {
//     color: var(--text-color-medium);
//     font-weight: bold;
// }
//
// table.dataframe .dataFrameCaption {
//     font-weight: bold;
// }
//
// table.dataframe .numbers {
//     color: var(--text-color-dark);
// }
//
// table.dataframe td:hover .formatted .structural, .null {
//     color: var(--text-color-dark);
// }
//
// table.dataframe tr:hover .formatted .structural, .null {
//     color: var(--text-color-dark);
// }
//
//
//
//
//             </style>
//         </head>
//         <body>
//
// <table class="dataframe" id="df_-1207959550"></table>
//
// <p class="dataframe_description">DataFrame: rowsCount = 4, columnsCount = 12</p>
//         </body>
//         <script>
//
// /*<!--*/
// call_DataFrame(function() { DataFrame.addTable({ cols: [{ name: "<span title=\"type: String\">type</span>", children: [], rightAlign: false, values: ["Young","G1GCYoungInitialMark","G1GCRemark","Mixed"] },
// { name: "<span title=\"count: Int\">count</span>", children: [], rightAlign: true, values: ["<span class=\"formatted\" title=\"\"><span class=\"numbers\">11546</span></span>","<span class=\"formatted\" title=\"\"><span class=\"numbers\">2208</span></span>","<span class=\"formatted\" title=\"\"><span class=\"numbers\">113</span></span>","<span class=\"formatted\" title=\"\"><span class=\"numbers\">113</span></span>"] },
// { name: "<span title=\"Per.50 [ms]: Double\">Per.50 [ms]</span>", children: [], rightAlign: true, values: ["<span class=\"formatted\" title=\"\"><span class=\"numbers\">5,6520</span></span>","<span class=\"formatted\" title=\"\"><span class=\"numbers\">5,9125</span></span>","<span class=\"formatted\" title=\"\"><span class=\"numbers\">21,8450</span></span>","<span class=\"formatted\" title=\"\"><span class=\"numbers\">5,3230</span></span>"] },
// { name: "<span title=\"Per.75 [ms]: Double\">Per.75 [ms]</span>", children: [], rightAlign: true, values: ["<span class=\"formatted\" title=\"\"><span class=\"numbers\">6,316000</span></span>","<span class=\"formatted\" title=\"\"><span class=\"numbers\">6,699500</span></span>","<span class=\"formatted\" title=\"\"><span class=\"numbers\">24,452000</span></span>","<span class=\"formatted\" title=\"\"><span class=\"numbers\">7,044500</span></span>"] },
// { name: "<span title=\"Per.95 [ms]: Double\">Per.95 [ms]</span>", children: [], rightAlign: true, values: ["<span class=\"formatted\" title=\"\"><span class=\"numbers\">7,618300</span></span>","<span class=\"formatted\" title=\"\"><span class=\"numbers\">8,050100</span></span>","<span class=\"formatted\" title=\"\"><span class=\"numbers\">32,087600</span></span>","<span class=\"formatted\" title=\"\"><span class=\"numbers\">9,173000</span></span>"] },
// { name: "<span title=\"Per.99 [ms]: Double\">Per.99 [ms]</span>", children: [], rightAlign: true, values: ["<span class=\"formatted\" title=\"\"><span class=\"numbers\">9,021000</span></span>","<span class=\"formatted\" title=\"\"><span class=\"numbers\">9,417290</span></span>","<span class=\"formatted\" title=\"\"><span class=\"numbers\">44,675380</span></span>","<span class=\"formatted\" title=\"\"><span class=\"numbers\">10,211780</span></span>"] },
// { name: "<span title=\"Per.100 [ms]: Double\">Per.100 [ms]</span>", children: [], rightAlign: true, values: ["<span class=\"formatted\" title=\"\"><span class=\"numbers\">9,021000</span></span>","<span class=\"formatted\" title=\"\"><span class=\"numbers\">9,417290</span></span>","<span class=\"formatted\" title=\"\"><span class=\"numbers\">44,675380</span></span>","<span class=\"formatted\" title=\"\"><span class=\"numbers\">10,211780</span></span>"] },
// { name: "<span title=\"sum [ms]: Double\">sum [ms]</span>", children: [], rightAlign: true, values: ["<span class=\"formatted\" title=\"\"><span class=\"numbers\">67066,846000</span></span>","<span class=\"formatted\" title=\"\"><span class=\"numbers\">13436,891000</span></span>","<span class=\"formatted\" title=\"\"><span class=\"numbers\">2622,695000</span></span>","<span class=\"formatted\" title=\"\"><span class=\"numbers\">659,336000</span></span>"] },
// { name: "<span title=\"max [ms]: Double\">max [ms]</span>", children: [], rightAlign: true, values: ["<span class=\"formatted\" title=\"\"><span class=\"numbers\">13,244</span></span>","<span class=\"formatted\" title=\"\"><span class=\"numbers\">13,829</span></span>","<span class=\"formatted\" title=\"\"><span class=\"numbers\">46,171</span></span>","<span class=\"formatted\" title=\"\"><span class=\"numbers\">10,278</span></span>"] },
// { name: "<span title=\"min [ms]: Double\">min [ms]</span>", children: [], rightAlign: true, values: ["<span class=\"formatted\" title=\"\"><span class=\"numbers\">2,985</span></span>","<span class=\"formatted\" title=\"\"><span class=\"numbers\">3,086</span></span>","<span class=\"formatted\" title=\"\"><span class=\"numbers\">19,551</span></span>","<span class=\"formatted\" title=\"\"><span class=\"numbers\">3,568</span></span>"] },
// { name: "<span title=\"avg [ms]: Double\">avg [ms]</span>", children: [], rightAlign: true, values: ["<span class=\"formatted\" title=\"\"><span class=\"numbers\">5,808665</span></span>","<span class=\"formatted\" title=\"\"><span class=\"numbers\">6,085548</span></span>","<span class=\"formatted\" title=\"\"><span cla

// %%
val (w, h) = 700 to 350

pausesSummary.plot {
    pie {
        slice(count)
        fillColor(type)
        size=30.0
    }
    layout {
        size = w to h
        theme(blankTheme)
        title="Stop the world pauses - percentage"
    }
 }
// Out:
//             <script type="text/javascript" data-lets-plot-script="library" src="https://cdn.jsdelivr.net/gh/JetBrains/lets-plot@v3.1.0/js-package/distr/lets-plot.min.js"></script>
//                <div id="aXdS2L"></div>
//    <script type="text/javascript" data-lets-plot-script="plot">
//        var plotSpec={
// "ggtitle":{
// "text":"Stop the world pauses - percentage"
// },
// "mapping":{
// },
// "data":{
// "count":[11546.0,2208.0,113.0,113.0],
// "type":["Young","G1GCYoungInitialMark","G1GCRemark","Mixed"]
// },
// "ggsize":{
// "width":700.0,
// "height":350.0
// },
// "kind":"plot",
// "scales":[{
// "aesthetic":"fill",
// "discrete":true
// }],
// "layers":[{
// "mapping":{
// "slice":"count",
// "fill":"type"
// },
// "stat":"identity",
// "size":30.0,
// "sampling":"none",
// "position":"identity",
// "geom":"pie",
// "data":{
// }
// }],
// "theme":{
// "axis":"blank",
// "axis_ontop":false,
// "axis_ontop_y":false,
// "line":{
// "blank":true
// },
// "axis_ontop_x":false
// }
// };
//        var plotContainer = document.getElementById("aXdS2L");
//        LetsPlot.buildPlotFromProcessedSpecs(plotSpec, -1, -1, plotContainer);
//    </script>
//         <svg id=c83068ff-e926-4b15-989a-296b0ec54678 xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" class="plt-container" width="700.0" height="350.0">
//   <style type="text/css">
//   .plt-container {
//    font-family: Lucida Grande, sans-serif;
//    user-select: none;
//    -webkit-user-select: none;
//    -moz-user-select: none;
//    -ms-user-select: none;
// }
// text {
//    text-rendering: optimizeLegibility;
// }
// #pjWfIri .plot-title {
//    fill: #474747;
//    font-family: Lucida Grande, sans-serif;
//    font-size: 16.0px;
//    font-weight: normal;
//    font-style: normal;
// }
// #pjWfIri .plot-subtitle {
//    fill: #474747;
//    font-family: Lucida Grande, sans-serif;
//    font-size: 15.0px;
//    font-weight: normal;
//    font-style: normal;
// }
// #pjWfIri .plot-caption {
//    fill: #474747;
//    font-family: Lucida Grande, sans-serif;
//    font-size: 13.0px;
//    font-weight: normal;
//    font-style: normal;
// }
// #pjWfIri .legend-title {
//    fill: #474747;
//    font-family: Lucida Grande, sans-serif;
//    font-size: 15.0px;
//    font-weight: normal;
//    font-style: normal;
// }
// #pjWfIri .legend-item {
//    fill: #474747;
//    font-family: Lucida Grande, sans-serif;
//    font-size: 13.0px;
//    font-weight: normal;
//    font-style: normal;
// }
// #pjWfIri .axis-title-x {
//    fill: #474747;
//    font-family: Lucida Grande, sans-serif;
//    font-size: 15.0px;
//    font-weight: normal;
//    font-style: normal;
// }
// #pjWfIri .axis-text-x {
//    fill: #474747;
//    font-family: Lucida Grande, sans-serif;
//    font-size: 13.0px;
//    font-weight: normal;
//    font-style: normal;
// }
// #dRCmS5u .axis-tooltip-text-x {
//    fill: #ffffff;
//    font-family: Lucida Grande, sans-serif;
//    font-size: 13.0px;
//    font-weight: normal;
//    font-style: normal;
// }
// #pjWfIri .axis-title-y {
//    fill: #474747;
//    font-family: Lucida Grande, sans-serif;
//    font-size: 15.0px;
//    font-weight: normal;
//    font-style: normal;
// }
// #pjWfIri .axis-text-y {
//    fill: #474747;
//    font-family: Lucida Grande, sans-serif;
//    font-size: 13.0px;
//    font-weight: normal;
//    font-style: normal;
// }
// #dRCmS5u .axis-tooltip-text-y {
//    fill: #ffffff;
//    font-family: Lucida Grande, sans-serif;
//    font-size: 13.0px;
//    font-weight: normal;
//    font-style: normal;
// }
// #pjWfIri .facet-strip-text-x {
//    fill: #474747;
//    font-family: Lucida Grande, sans-serif;
//    font-size: 13.0px;
//    font-weight: normal;
//    font-style: normal;
// }
// #pjWfIri .facet-strip-text-y {
//    fill: #474747;
//    font-family: Lucida Grande, sans-serif;
//    font-size: 13.0px;
//    font-weight: normal;
//    font-style: normal;
// }
// #dRCmS5u .tooltip-text {
//    fill: #474747;
//    font-family: Lucida Grande, sans-serif;
//    font-size: 13.0px;
//    font-weight: normal;
//    font-style: normal;
// }
// #dRCmS5u .tooltip-title {
//    fill: #474747;
//    font-family: Lucida Grande, sans-serif;
//    font-size: 13.0px;
//    font-weight: bold;
//    font-style: normal;
// }
// #dRCmS5u .tooltip-label {
//    fill: #474747;
//    font-family: Lucida Grande, sans-serif;
//    font-size: 13.0px;
//    font-weight: bold;
//    font-style: normal;
// }
//
//   </style>
//   <g id="pjWfIri">
//     <rect x="0.0" y="0.0" height="350.0" width="700.0" stroke="rgb(71,71,71)" stroke-opacity="1.0" stroke-width="0.0" fill="rgb(255,255,255)" fill-opacity="1.0">
//     </rect>
//     <g transform="translate(10.0 34.0 ) ">
//       <g transform="translate(0.0 306.0 ) ">
//       </g>
//       <g transform="">
//       </g>
//       <g transform="" clip-path="url(#c3nDxn1)" clip-bounds-jfx="[rect (0.0, 0.0), (476.9517441991895, 306.0)]">
//         <defs>
//           <clipPath id="c3nDxn1">
//             <rect x="0.0" y="0.0" width="476.9517441991895" height="306.0">
//             </rect>
//           </clipPath>
//         </defs>
//         <g>
//           <path d="M238.47587209959474 153.0 L371.742164942297 84.15165076806039 A150.0 150.0 0.0 1 1 238.47587209959474 3.0 L238.47587209959474 153.0 A0.0 0.0 0.0 1 0 238.47587209959474 153.0 " fill="rgb(102,194,165)" stroke-width="0.0" fill-opacity="1.0" stroke="rgb(255,255,255)" stroke-opacity="1.0">
//           </path>
//         </g>
//         <g>
//           <path d="M238.47587209959474 153.0 L238.47587209959474 3.0 A150.0 150.0 0.0 0 1 364.0741270783868 70.99342498139359 L238.47587209959474 153.0 A0.0 0.0 0.0 0 0 238.47587209959474 153.0 " fill="rgb(252,141,98)" stroke-width="0.0" fill-opacity="1.0" stroke="rgb(255,255,255)" stroke-opacity="1.0">
//           </path>
//         </g>
//         <g>
//           <path d="M238.47587209959474 153.0 L364.0741270783868 70.99342498139359 A150.0 150.0 0.0 0 1 368.0752480864023 77.47515810125726 L238.47587209959474 153.0 A0.0 0.0 0.0 0 0 238.47587209959474 153.0 " fill="rgb(141,160,203)" stroke-width="0.0" fill-opacity="1.0" stroke="rgb(255,255,255)" stroke-opacity="1.0">
//           </path>
//         </g>
//         <g>
//           <path d="M238.47587209959474 153.0 L368.0752480864023 77.47515810125726 A150.0 150.0 0.0 0 1 371.742164942297 84.15165076806035 L238.47587209959474 153.0 A0.0 0.0 0.0 0 0 238.47587209959474 153.0 " fill="rgb(231,138,195)" stroke-width="0.0" fill-opacity="1.0" stroke="rgb(255,255,255)" stroke-opacity="1.0">
//           </path>
//         </g>
//       </g>
//     </g>
//     <g transform="translate(10.0 15.2 ) ">
//       <text class="plot-title" y="0.0">
//       Stop the world pauses - percentage
//       </text>
//     </g>
//     <g transform="translate(496.9517441991895 119.75 ) ">
//       <rect x="5.0" y="5.0" height="124.5" width="193.04825580081052" stroke="rgb(71,71,71)" stroke-opacity="1.0" stroke-width="0.0" fill="rgb(255,255,255)" fill-opacity="1.0">
//       </rect>
//       <g transform="translate(10.0 10.0 ) ">
//         <g transform="translate(0.0 10.5 ) ">
//           <text class="legend-title" y="0.0">
//           type
//           </text>
//         </g>
//         <g transform="translate(0.0 22.5 ) ">
//           <g transform="">
//             <g>
//               <rect x="0.0" y="0.0" height="23.0" width="23.0" stroke-width="0.0" fill="rgb(255,255,255)" fill-opacity="1.0">
//               </rect>
//               <g transform="translate(1.0 1.0 ) ">
//                 <g>
//                   <circle cx="10.5" cy="10.5" r="5.0" fill="rgb(102,194,165)" fill-opacity="1.0" stroke="rgb(255,255,255)" stroke-opacity="1.0" stroke-width="1.5">
//                   </circle>
//                 </g>
//               </g>
//               <rect x="0.0" y="0.0" height="23.0" width="23.0" stroke="rgb(255,255,255)" stroke-opacity="1.0" stroke-width="1.0" fill-opacity="0.0">
//               </rect>
//             </g>
//             <g transform="translate(26.9903027277341 16.05 ) ">
//               <text class="legend-item" y="0.0">
//               Young
//               </text>
//             </g>
//           </g>
//           <g transform="translate(0.0 23.0 ) ">
//             <g>
//               <rect x="0.0" y="0.0" height="23.0" width="23.0" stroke-width="0.0" fill="rgb(255,255,255)" fill-opacity="1.0">
//               </rect>
//               <g transform="translate(1.0 1.0 ) ">
//                 <g>
//                   <circle cx="10.5" cy="10.5" r="5.0" fill="rgb(252,141,98)" fill-opacity="1.0

// %%
pausesSummary.plot {
    bars {
        x(type)
        y("sum [ms]")
       
        fillColor("sum [ms]"<Int>()) {
            scale = continuous(range = Color.YELLOW..Color.RED)
   
        borderLine.width = 0.0
    }
    }
    layout.title = "Stop the world pauses duration sum [ms]"
    layout.size = 950 to 500
}
// Out:
//             <script type="text/javascript" data-lets-plot-script="library" src="https://cdn.jsdelivr.net/gh/JetBrains/lets-plot@v3.1.0/js-package/distr/lets-plot.min.js"></script>
//                <div id="6ASpYW"></div>
//    <script type="text/javascript" data-lets-plot-script="plot">
//        var plotSpec={
// "ggtitle":{
// "text":"Stop the world pauses duration sum [ms]"
// },
// "mapping":{
// },
// "data":{
// "type":["Young","G1GCYoungInitialMark","G1GCRemark","Mixed"],
// "sum [ms]":[67066.84599999999,13436.891000000012,2622.6949999999997,659.3359999999999]
// },
// "ggsize":{
// "width":950.0,
// "height":500.0
// },
// "kind":"plot",
// "scales":[{
// "aesthetic":"x",
// "discrete":true
// },{
// "aesthetic":"y",
// "limits":[null,null]
// },{
// "aesthetic":"fill",
// "scale_mapper_kind":"color_gradient",
// "high":"#ee6666",
// "low":"#fac858",
// "limits":[null,null]
// }],
// "layers":[{
// "mapping":{
// "x":"type",
// "y":"sum [ms]",
// "fill":"sum [ms]"
// },
// "stat":"identity",
// "size":0.0,
// "sampling":"none",
// "position":"dodge",
// "geom":"bar",
// "data":{
// }
// }]
// };
//        var plotContainer = document.getElementById("6ASpYW");
//        LetsPlot.buildPlotFromProcessedSpecs(plotSpec, -1, -1, plotContainer);
//    </script>
//         <svg id=9765aa8a-0fc6-479f-b9b5-db5c2eae8ac3 xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" class="plt-container" width="950.0" height="500.0">
//   <style type="text/css">
//   .plt-container {
//    font-family: Lucida Grande, sans-serif;
//    user-select: none;
//    -webkit-user-select: none;
//    -moz-user-select: none;
//    -ms-user-select: none;
// }
// text {
//    text-rendering: optimizeLegibility;
// }
// #pGkJaw2 .plot-title {
//    fill: #474747;
//    font-family: Lucida Grande, sans-serif;
//    font-size: 16.0px;
//    font-weight: normal;
//    font-style: normal;
// }
// #pGkJaw2 .plot-subtitle {
//    fill: #474747;
//    font-family: Lucida Grande, sans-serif;
//    font-size: 15.0px;
//    font-weight: normal;
//    font-style: normal;
// }
// #pGkJaw2 .plot-caption {
//    fill: #474747;
//    font-family: Lucida Grande, sans-serif;
//    font-size: 13.0px;
//    font-weight: normal;
//    font-style: normal;
// }
// #pGkJaw2 .legend-title {
//    fill: #474747;
//    font-family: Lucida Grande, sans-serif;
//    font-size: 15.0px;
//    font-weight: normal;
//    font-style: normal;
// }
// #pGkJaw2 .legend-item {
//    fill: #474747;
//    font-family: Lucida Grande, sans-serif;
//    font-size: 13.0px;
//    font-weight: normal;
//    font-style: normal;
// }
// #pGkJaw2 .axis-title-x {
//    fill: #474747;
//    font-family: Lucida Grande, sans-serif;
//    font-size: 15.0px;
//    font-weight: normal;
//    font-style: normal;
// }
// #pGkJaw2 .axis-text-x {
//    fill: #474747;
//    font-family: Lucida Grande, sans-serif;
//    font-size: 13.0px;
//    font-weight: normal;
//    font-style: normal;
// }
// #dTEtZR2 .axis-tooltip-text-x {
//    fill: #ffffff;
//    font-family: Lucida Grande, sans-serif;
//    font-size: 13.0px;
//    font-weight: normal;
//    font-style: normal;
// }
// #pGkJaw2 .axis-title-y {
//    fill: #474747;
//    font-family: Lucida Grande, sans-serif;
//    font-size: 15.0px;
//    font-weight: normal;
//    font-style: normal;
// }
// #pGkJaw2 .axis-text-y {
//    fill: #474747;
//    font-family: Lucida Grande, sans-serif;
//    font-size: 13.0px;
//    font-weight: normal;
//    font-style: normal;
// }
// #dTEtZR2 .axis-tooltip-text-y {
//    fill: #ffffff;
//    font-family: Lucida Grande, sans-serif;
//    font-size: 13.0px;
//    font-weight: normal;
//    font-style: normal;
// }
// #pGkJaw2 .facet-strip-text-x {
//    fill: #474747;
//    font-family: Lucida Grande, sans-serif;
//    font-size: 13.0px;
//    font-weight: normal;
//    font-style: normal;
// }
// #pGkJaw2 .facet-strip-text-y {
//    fill: #474747;
//    font-family: Lucida Grande, sans-serif;
//    font-size: 13.0px;
//    font-weight: normal;
//    font-style: normal;
// }
// #dTEtZR2 .tooltip-text {
//    fill: #474747;
//    font-family: Lucida Grande, sans-serif;
//    font-size: 13.0px;
//    font-weight: normal;
//    font-style: normal;
// }
// #dTEtZR2 .tooltip-title {
//    fill: #474747;
//    font-family: Lucida Grande, sans-serif;
//    font-size: 13.0px;
//    font-weight: bold;
//    font-style: normal;
// }
// #dTEtZR2 .tooltip-label {
//    fill: #474747;
//    font-family: Lucida Grande, sans-serif;
//    font-size: 13.0px;
//    font-weight: bold;
//    font-style: normal;
// }
//
//   </style>
//   <g id="pGkJaw2">
//     <rect x="0.0" y="0.0" height="500.0" width="950.0" stroke="rgb(71,71,71)" stroke-opacity="1.0" stroke-width="0.0" fill="rgb(255,255,255)" fill-opacity="1.0">
//     </rect>
//     <g transform="translate(23.0 34.0 ) ">
//       <g transform="translate(50.97651758668602 420.0 ) ">
//         <line x1="117.00856520099558" y1="-0.0" x2="117.00856520099558" y2="-420.0" stroke="rgb(233,233,233)" stroke-opacity="1.0" stroke-width="1.0">
//         </line>
//         <line x1="297.0217424332965" y1="-0.0" x2="297.0217424332965" y2="-420.0" stroke="rgb(233,233,233)" stroke-opacity="1.0" stroke-width="1.0">
//         </line>
//         <line x1="477.03491966559733" y1="-0.0" x2="477.03491966559733" y2="-420.0" stroke="rgb(233,233,233)" stroke-opacity="1.0" stroke-width="1.0">
//         </line>
//         <line x1="657.0480968978982" y1="-0.0" x2="657.0480968978982" y2="-420.0" stroke="rgb(233,233,233)" stroke-opacity="1.0" stroke-width="1.0">
//         </line>
//         <g transform="translate(117.00856520099558 0.0 ) ">
//           <line stroke-width="1.0" stroke="rgb(71,71,71)" stroke-opacity="1.0" x2="0.0" y2="4.0">
//           </line>
//           <g transform="translate(0.0 7.0 ) ">
//             <text class="axis-text-x" text-anchor="middle" dy="0.7em">
//             Young
//             </text>
//           </g>
//         </g>
//         <g transform="translate(297.0217424332965 0.0 ) ">
//           <line stroke-width="1.0" stroke="rgb(71,71,71)" stroke-opacity="1.0" x2="0.0" y2="4.0">
//           </line>
//           <g transform="translate(0.0 7.0 ) ">
//             <text class="axis-text-x" text-anchor="middle" dy="0.7em">
//             G1GCYoungInitialMark
//             </text>
//           </g>
//         </g>
//         <g transform="translate(477.03491966559733 0.0 ) ">
//           <line stroke-width="1.0" stroke="rgb(71,71,71)" stroke-opacity="1.0" x2="0.0" y2="4.0">
//           </line>
//           <g transform="translate(0.0 7.0 ) ">
//             <text class="axis-text-x" text-anchor="middle" dy="0.7em">
//             G1GCRemark
//             </text>
//           </g>
//         </g>
//         <g transform="translate(657.0480968978982 0.0 ) ">
//           <line stroke-width="1.0" stroke="rgb(71,71,71)" stroke-opacity="1.0" x2="0.0" y2="4.0">
//           </line>
//           <g transform="translate(0.0 7.0 ) ">
//             <text class="axis-text-x" text-anchor="middle" dy="0.7em">
//             Mixed
//             </text>
//           </g>
//         </g>
//         <line x1="0.0" y1="0.0" x2="774.0566620988939" y2="0.0" stroke-width="1.0" stroke="rgb(71,71,71)" stroke-opacity="1.0">
//         </line>
//       </g>
//       <g transform="translate(50.97651758668602 0.0 ) ">
//         <line x1="0.0" y1="360.3580123627701" x2="774.0566620988939" y2="360.3580123627701" stroke="rgb(233,233,233)" stroke-opacity="1.0" stroke-width="1.0">
//         </line>
//         <line x1="0.0" y1="300.71602472554025" x2="774.0566620988939" y2="300.71602472554025" stroke="rgb(233,233,233)" stroke-opacity="1.0" stroke-width="1.0">
//         </line>
//         <line x1="0.0" y1="241.07403708831035" x2="774.0566620988939" y2="241.07403708831035" stroke="rgb(233,233,233)" stroke-opacity="1.0" stroke-width="1.0">
//         </line>
//         <line x1="0.0" y1="181.43204945108047" x2="774.0566620988939" y2="181.43204945108047" stroke="rgb(233,233,233)" stroke-opacity="1.0" stroke-width="1.0">
//         </line>
//         <line x1="0.0" y1="121.79006181385057" x2="774.0566620988939" y2="121.79006181385057" stroke="rgb(233,233,233)" stroke-opacity="1.0" stroke-width="1.0">
//         </line>
//         <line x1="0.0" y1="62.148074176620696" x2="774.0566620988939" y2="62.148074176620696" stroke="rgb(233,233,233)" stroke-opacity="1.0" stroke-width="1.0">
//         </line>
//         <g transform="translate(0.0 420.0 ) ">
//           <g transform="translate(-3.0 0.0 ) ">
//             <text class="axis-text-y" text

// %%
//get the longest stop-the-world pause - select only indicated columns
df.filter{event_type=="PauseEvent"}.select{type and event_type and startedAt and duration and cause}.maxBy{duration}
// Out:
//         <html>
//         <head>
//             <style type="text/css">
//                 :root {
//     --background: #fff;
//     --background-odd: #f5f5f5;
//     --background-hover: #d9edfd;
//     --header-text-color: #474747;
//     --text-color: #848484;
//     --text-color-dark: #000;
//     --text-color-medium: #737373;
//     --text-color-pale: #b3b3b3;
//     --inner-border-color: #aaa;
//     --bold-border-color: #000;
//     --link-color: #296eaa;
//     --link-color-pale: #296eaa;
//     --link-hover: #1a466c;
// }
//
// :root[theme="dark"], :root [data-jp-theme-light="false"], .dataframe_dark{
//     --background: #303030;
//     --background-odd: #3c3c3c;
//     --background-hover: #464646;
//     --header-text-color: #dddddd;
//     --text-color: #b3b3b3;
//     --text-color-dark: #dddddd;
//     --text-color-medium: #b2b2b2;
//     --text-color-pale: #737373;
//     --inner-border-color: #707070;
//     --bold-border-color: #777777;
//     --link-color: #008dc0;
//     --link-color-pale: #97e1fb;
//     --link-hover: #00688e;
// }
//
// p.dataframe_description {
//     color: var(--text-color-dark);
// }
//
// table.dataframe {
//     font-family: "Helvetica Neue", Helvetica, Arial, sans-serif;
//     font-size: 12px;
//     background-color: var(--background);
//     color: var(--text-color-dark);
//     border: none;
//     border-collapse: collapse;
// }
//
// table.dataframe th, td {
//     padding: 6px;
//     border: 1px solid transparent;
//     text-align: left;
// }
//
// table.dataframe th {
//     background-color: var(--background);
//     color: var(--header-text-color);
// }
//
// table.dataframe td {
//     vertical-align: top;
// }
//
// table.dataframe th.bottomBorder {
//     border-bottom-color: var(--bold-border-color);
// }
//
// table.dataframe tbody > tr:nth-child(odd) {
//     background: var(--background-odd);
// }
//
// table.dataframe tbody > tr:nth-child(even) {
//     background: var(--background);
// }
//
// table.dataframe tbody > tr:hover {
//     background: var(--background-hover);
// }
//
// table.dataframe a {
//     cursor: pointer;
//     color: var(--link-color);
//     text-decoration: none;
// }
//
// table.dataframe tr:hover > td a {
//     color: var(--link-color-pale);
// }
//
// table.dataframe a:hover {
//     color: var(--link-hover);
//     text-decoration: underline;
// }
//
// table.dataframe img {
//     max-width: fit-content;
// }
//
// table.dataframe th.complex {
//     background-color: var(--background);
//     border: 1px solid var(--background);
// }
//
// table.dataframe .leftBorder {
//     border-left-color: var(--inner-border-color);
// }
//
// table.dataframe .rightBorder {
//     border-right-color: var(--inner-border-color);
// }
//
// table.dataframe .rightAlign {
//     text-align: right;
// }
//
// table.dataframe .expanderSvg {
//     width: 8px;
//     height: 8px;
//     margin-right: 3px;
// }
//
// table.dataframe .expander {
//     display: flex;
//     align-items: center;
// }
//
// /* formatting */
//
// table.dataframe .null {
//     color: var(--text-color-pale);
// }
//
// table.dataframe .structural {
//     color: var(--text-color-medium);
//     font-weight: bold;
// }
//
// table.dataframe .dataFrameCaption {
//     font-weight: bold;
// }
//
// table.dataframe .numbers {
//     color: var(--text-color-dark);
// }
//
// table.dataframe td:hover .formatted .structural, .null {
//     color: var(--text-color-dark);
// }
//
// table.dataframe tr:hover .formatted .structural, .null {
//     color: var(--text-color-dark);
// }
//
//
//
//
//             </style>
//         </head>
//         <body>
//
// <table class="dataframe" id="df_-1207959549"></table>
//
// <p class="dataframe_description">DataRow: index = 13424, columnsCount = 5</p>
//         </body>
//         <script>
//
// /*<!--*/
// call_DataFrame(function() { DataFrame.addTable({ cols: [{ name: "<span title=\"type: String\">type</span>", children: [], rightAlign: false, values: ["G1GCRemark"] },
// { name: "<span title=\"event_type: String\">event_type</span>", children: [], rightAlign: false, values: ["PauseEvent"] },
// { name: "<span title=\"startedAt: kotlinx.datetime.LocalDateTime\">startedAt</span>", children: [], rightAlign: false, values: ["2023-07-19T14:51:49.582"] },
// { name: "<span title=\"duration: Double\">duration</span>", children: [], rightAlign: true, values: ["<span class=\"formatted\" title=\"\"><span class=\"numbers\">46,171</span></span>"] },
// { name: "<span title=\"cause: String\">cause</span>", children: [], rightAlign: false, values: ["UNKNOWN_GCCAUSE"] },
// ], id: -1207959549, rootId: -1207959549, totalRows: 1 } ) });
// /*-->*/
//
// call_DataFrame(function() { DataFrame.renderTable(-1207959549) });
//
//
//         </script>
//         </html>

// %% [markdown]
// ## GC event causes - examination

// %% [markdown]
// <img style="float: left; margin-right:20px;" src="idea.png">  **Tip:** _(screen from artcicle [Monday with JVM logs - G1GC Stop-the-world phases](https://krzysztofslusarski.github.io/2021/08/10/monday-phases.html))_
//
// ![](gc_causes.png)

// %%
val gcCausesAll=df.filter{cause!=null}.count() 
val gcCauses=df.groupBy{cause}.aggregate{
   count() into "count"
   ((count().toDouble()*100/gcCausesAll))  into "percentage" 
    }.sortBy{it["count"].desc()}

gcCauses
// Out:
//         <html>
//         <head>
//             <style type="text/css">
//                 :root {
//     --background: #fff;
//     --background-odd: #f5f5f5;
//     --background-hover: #d9edfd;
//     --header-text-color: #474747;
//     --text-color: #848484;
//     --text-color-dark: #000;
//     --text-color-medium: #737373;
//     --text-color-pale: #b3b3b3;
//     --inner-border-color: #aaa;
//     --bold-border-color: #000;
//     --link-color: #296eaa;
//     --link-color-pale: #296eaa;
//     --link-hover: #1a466c;
// }
//
// :root[theme="dark"], :root [data-jp-theme-light="false"], .dataframe_dark{
//     --background: #303030;
//     --background-odd: #3c3c3c;
//     --background-hover: #464646;
//     --header-text-color: #dddddd;
//     --text-color: #b3b3b3;
//     --text-color-dark: #dddddd;
//     --text-color-medium: #b2b2b2;
//     --text-color-pale: #737373;
//     --inner-border-color: #707070;
//     --bold-border-color: #777777;
//     --link-color: #008dc0;
//     --link-color-pale: #97e1fb;
//     --link-hover: #00688e;
// }
//
// p.dataframe_description {
//     color: var(--text-color-dark);
// }
//
// table.dataframe {
//     font-family: "Helvetica Neue", Helvetica, Arial, sans-serif;
//     font-size: 12px;
//     background-color: var(--background);
//     color: var(--text-color-dark);
//     border: none;
//     border-collapse: collapse;
// }
//
// table.dataframe th, td {
//     padding: 6px;
//     border: 1px solid transparent;
//     text-align: left;
// }
//
// table.dataframe th {
//     background-color: var(--background);
//     color: var(--header-text-color);
// }
//
// table.dataframe td {
//     vertical-align: top;
// }
//
// table.dataframe th.bottomBorder {
//     border-bottom-color: var(--bold-border-color);
// }
//
// table.dataframe tbody > tr:nth-child(odd) {
//     background: var(--background-odd);
// }
//
// table.dataframe tbody > tr:nth-child(even) {
//     background: var(--background);
// }
//
// table.dataframe tbody > tr:hover {
//     background: var(--background-hover);
// }
//
// table.dataframe a {
//     cursor: pointer;
//     color: var(--link-color);
//     text-decoration: none;
// }
//
// table.dataframe tr:hover > td a {
//     color: var(--link-color-pale);
// }
//
// table.dataframe a:hover {
//     color: var(--link-hover);
//     text-decoration: underline;
// }
//
// table.dataframe img {
//     max-width: fit-content;
// }
//
// table.dataframe th.complex {
//     background-color: var(--background);
//     border: 1px solid var(--background);
// }
//
// table.dataframe .leftBorder {
//     border-left-color: var(--inner-border-color);
// }
//
// table.dataframe .rightBorder {
//     border-right-color: var(--inner-border-color);
// }
//
// table.dataframe .rightAlign {
//     text-align: right;
// }
//
// table.dataframe .expanderSvg {
//     width: 8px;
//     height: 8px;
//     margin-right: 3px;
// }
//
// table.dataframe .expander {
//     display: flex;
//     align-items: center;
// }
//
// /* formatting */
//
// table.dataframe .null {
//     color: var(--text-color-pale);
// }
//
// table.dataframe .structural {
//     color: var(--text-color-medium);
//     font-weight: bold;
// }
//
// table.dataframe .dataFrameCaption {
//     font-weight: bold;
// }
//
// table.dataframe .numbers {
//     color: var(--text-color-dark);
// }
//
// table.dataframe td:hover .formatted .structural, .null {
//     color: var(--text-color-dark);
// }
//
// table.dataframe tr:hover .formatted .structural, .null {
//     color: var(--text-color-dark);
// }
//
//
//
//
//             </style>
//         </head>
//         <body>
//
// <table class="dataframe" id="df_-1207959548"></table>
//
// <p class="dataframe_description">DataFrame: rowsCount = 5, columnsCount = 3</p>
//         </body>
//         <script>
//
// /*<!--*/
// call_DataFrame(function() { DataFrame.addTable({ cols: [{ name: "<span title=\"cause: String\">cause</span>", children: [], rightAlign: false, values: ["G1_EVACUATION_PAUSE","UNKNOWN_GCCAUSE","GCCAUSE_NOT_SET","G1_HUMONGOUS_ALLOCATION","GC_LOCKER"] },
// { name: "<span title=\"count: Int\">count</span>", children: [], rightAlign: true, values: ["<span class=\"formatted\" title=\"\"><span class=\"numbers\">11626</span></span>","<span class=\"formatted\" title=\"\"><span class=\"numbers\">2547</span></span>","<span class=\"formatted\" title=\"\"><span class=\"numbers\">2208</span></span>","<span class=\"formatted\" title=\"\"><span class=\"numbers\">2196</span></span>","<span class=\"formatted\" title=\"\"><span class=\"numbers\">45</span></span>"] },
// { name: "<span title=\"percentage: Double\">percentage</span>", children: [], rightAlign: true, values: ["<span class=\"formatted\" title=\"\"><span class=\"numbers\">62,431533</span></span>","<span class=\"formatted\" title=\"\"><span class=\"numbers\">13,677371</span></span>","<span class=\"formatted\" title=\"\"><span class=\"numbers\">11,856943</span></span>","<span class=\"formatted\" title=\"\"><span class=\"numbers\">11,792503</span></span>","<span class=\"formatted\" title=\"\"><span class=\"numbers\">0,241650</span></span>"] },
// ], id: -1207959548, rootId: -1207959548, totalRows: 5 } ) });
// /*-->*/
//
// call_DataFrame(function() { DataFrame.renderTable(-1207959548) });
//
//
//         </script>
//         </html>

// %%
val (w, h) = 700 to 350

gcCauses.plot {
    pie {
        slice(percentage)
        fillColor(cause)
        size=30.0
    }
    layout {
        size = w to h
        theme(blankTheme)
        title="GC causes - percentage"
    }
 }
// Out:
//             <script type="text/javascript" data-lets-plot-script="library" src="https://cdn.jsdelivr.net/gh/JetBrains/lets-plot@v3.1.0/js-package/distr/lets-plot.min.js"></script>
//                <div id="BsBTpT"></div>
//    <script type="text/javascript" data-lets-plot-script="plot">
//        var plotSpec={
// "ggtitle":{
// "text":"GC causes - percentage"
// },
// "mapping":{
// },
// "data":{
// "percentage":[62.431532595854364,13.677370851680807,11.85694340027924,11.792503490495113,0.24164966169047364],
// "cause":["G1_EVACUATION_PAUSE","UNKNOWN_GCCAUSE","GCCAUSE_NOT_SET","G1_HUMONGOUS_ALLOCATION","GC_LOCKER"]
// },
// "ggsize":{
// "width":700.0,
// "height":350.0
// },
// "kind":"plot",
// "scales":[{
// "aesthetic":"fill",
// "discrete":true
// }],
// "layers":[{
// "mapping":{
// "slice":"percentage",
// "fill":"cause"
// },
// "stat":"identity",
// "size":30.0,
// "sampling":"none",
// "position":"identity",
// "geom":"pie",
// "data":{
// }
// }],
// "theme":{
// "axis":"blank",
// "axis_ontop":false,
// "axis_ontop_y":false,
// "line":{
// "blank":true
// },
// "axis_ontop_x":false
// }
// };
//        var plotContainer = document.getElementById("BsBTpT");
//        LetsPlot.buildPlotFromProcessedSpecs(plotSpec, -1, -1, plotContainer);
//    </script>
//         <svg id=36f09d86-3125-4338-87e1-6ea80c30b512 xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" class="plt-container" width="700.0" height="350.0">
//   <style type="text/css">
//   .plt-container {
//    font-family: Lucida Grande, sans-serif;
//    user-select: none;
//    -webkit-user-select: none;
//    -moz-user-select: none;
//    -ms-user-select: none;
// }
// text {
//    text-rendering: optimizeLegibility;
// }
// #pVUJyQR .plot-title {
//    fill: #474747;
//    font-family: Lucida Grande, sans-serif;
//    font-size: 16.0px;
//    font-weight: normal;
//    font-style: normal;
// }
// #pVUJyQR .plot-subtitle {
//    fill: #474747;
//    font-family: Lucida Grande, sans-serif;
//    font-size: 15.0px;
//    font-weight: normal;
//    font-style: normal;
// }
// #pVUJyQR .plot-caption {
//    fill: #474747;
//    font-family: Lucida Grande, sans-serif;
//    font-size: 13.0px;
//    font-weight: normal;
//    font-style: normal;
// }
// #pVUJyQR .legend-title {
//    fill: #474747;
//    font-family: Lucida Grande, sans-serif;
//    font-size: 15.0px;
//    font-weight: normal;
//    font-style: normal;
// }
// #pVUJyQR .legend-item {
//    fill: #474747;
//    font-family: Lucida Grande, sans-serif;
//    font-size: 13.0px;
//    font-weight: normal;
//    font-style: normal;
// }
// #pVUJyQR .axis-title-x {
//    fill: #474747;
//    font-family: Lucida Grande, sans-serif;
//    font-size: 15.0px;
//    font-weight: normal;
//    font-style: normal;
// }
// #pVUJyQR .axis-text-x {
//    fill: #474747;
//    font-family: Lucida Grande, sans-serif;
//    font-size: 13.0px;
//    font-weight: normal;
//    font-style: normal;
// }
// #dWAXjAm .axis-tooltip-text-x {
//    fill: #ffffff;
//    font-family: Lucida Grande, sans-serif;
//    font-size: 13.0px;
//    font-weight: normal;
//    font-style: normal;
// }
// #pVUJyQR .axis-title-y {
//    fill: #474747;
//    font-family: Lucida Grande, sans-serif;
//    font-size: 15.0px;
//    font-weight: normal;
//    font-style: normal;
// }
// #pVUJyQR .axis-text-y {
//    fill: #474747;
//    font-family: Lucida Grande, sans-serif;
//    font-size: 13.0px;
//    font-weight: normal;
//    font-style: normal;
// }
// #dWAXjAm .axis-tooltip-text-y {
//    fill: #ffffff;
//    font-family: Lucida Grande, sans-serif;
//    font-size: 13.0px;
//    font-weight: normal;
//    font-style: normal;
// }
// #pVUJyQR .facet-strip-text-x {
//    fill: #474747;
//    font-family: Lucida Grande, sans-serif;
//    font-size: 13.0px;
//    font-weight: normal;
//    font-style: normal;
// }
// #pVUJyQR .facet-strip-text-y {
//    fill: #474747;
//    font-family: Lucida Grande, sans-serif;
//    font-size: 13.0px;
//    font-weight: normal;
//    font-style: normal;
// }
// #dWAXjAm .tooltip-text {
//    fill: #474747;
//    font-family: Lucida Grande, sans-serif;
//    font-size: 13.0px;
//    font-weight: normal;
//    font-style: normal;
// }
// #dWAXjAm .tooltip-title {
//    fill: #474747;
//    font-family: Lucida Grande, sans-serif;
//    font-size: 13.0px;
//    font-weight: bold;
//    font-style: normal;
// }
// #dWAXjAm .tooltip-label {
//    fill: #474747;
//    font-family: Lucida Grande, sans-serif;
//    font-size: 13.0px;
//    font-weight: bold;
//    font-style: normal;
// }
//
//   </style>
//   <g id="pVUJyQR">
//     <rect x="0.0" y="0.0" height="350.0" width="700.0" stroke="rgb(71,71,71)" stroke-opacity="1.0" stroke-width="0.0" fill="rgb(255,255,255)" fill-opacity="1.0">
//     </rect>
//     <g transform="translate(10.0 34.0 ) ">
//       <g transform="translate(0.0 306.0 ) ">
//       </g>
//       <g transform="">
//       </g>
//       <g transform="" clip-path="url(#ccmbrze)" clip-bounds-jfx="[rect (0.0, 0.0), (409.9992049145292, 306.0)]">
//         <defs>
//           <clipPath id="ccmbrze">
//             <rect x="0.0" y="0.0" width="409.9992049145292" height="306.0">
//             </rect>
//           </clipPath>
//         </defs>
//         <g>
//           <path d="M204.9996024572646 153.0 L310.60835058906935 259.5213233021118 A150.0 150.0 0.0 1 1 204.99960245726453 3.0 L204.9996024572646 153.0 A0.0 0.0 0.0 1 0 204.9996024572646 153.0 " fill="rgb(102,194,165)" stroke-width="0.0" fill-opacity="1.0" stroke="rgb(255,255,255)" stroke-opacity="1.0">
//           </path>
//         </g>
//         <g>
//           <path d="M204.9996024572646 153.0 L204.99960245726453 3.0 A150.0 150.0 0.0 0 1 318.6147551732163 55.06330068186399 L204.9996024572646 153.0 A0.0 0.0 0.0 0 0 204.9996024572646 153.0 " fill="rgb(252,141,98)" stroke-width="0.0" fill-opacity="1.0" stroke="rgb(255,255,255)" stroke-opacity="1.0">
//           </path>
//         </g>
//         <g>
//           <path d="M204.9996024572646 153.0 L318.6147551732163 55.06330068186399 A150.0 150.0 0.0 0 1 354.9150796863047 158.03484728558547 L204.9996024572646 153.0 A0.0 0.0 0.0 0 0 204.9996024572646 153.0 " fill="rgb(141,160,203)" stroke-width="0.0" fill-opacity="1.0" stroke="rgb(255,255,255)" stroke-opacity="1.0">
//           </path>
//         </g>
//         <g>
//           <path d="M204.9996024572646 153.0 L354.9150796863047 158.03484728558547 A150.0 150.0 0.0 0 1 312.2134603447335 257.90561794720827 L204.9996024572646 153.0 A0.0 0.0 0.0 0 0 204.9996024572646 153.0 " fill="rgb(231,138,195)" stroke-width="0.0" fill-opacity="1.0" stroke="rgb(255,255,255)" stroke-opacity="1.0">
//           </path>
//         </g>
//         <g>
//           <path d="M204.9996024572646 153.0 L312.2134603447335 257.90561794720827 A150.0 150.0 0.0 0 1 310.6083505890693 259.52132330211185 L204.9996024572646 153.0 A0.0 0.0 0.0 0 0 204.9996024572646 153.0 " fill="rgb(166,216,84)" stroke-width="0.0" fill-opacity="1.0" stroke="rgb(255,255,255)" stroke-opacity="1.0">
//           </path>
//         </g>
//       </g>
//     </g>
//     <g transform="translate(10.0 15.2 ) ">
//       <text class="plot-title" y="0.0">
//       GC causes - percentage
//       </text>
//     </g>
//     <g transform="translate(429.9992049145292 108.25 ) ">
//       <rect x="5.0" y="5.0" height="147.5" width="260.0007950854708" stroke="rgb(71,71,71)" stroke-opacity="1.0" stroke-width="0.0" fill="rgb(255,255,255)" fill-opacity="1.0">
//       </rect>
//       <g transform="translate(10.0 10.0 ) ">
//         <g transform="translate(0.0 10.5 ) ">
//           <text class="legend-title" y="0.0">
//           cause
//           </text>
//         </g>
//         <g transform="translate(0.0 22.5 ) ">
//           <g transform="">
//             <g>
//               <rect x="0.0" y="0.0" height="23.0" width="23.0" stroke-width="0.0" fill="rgb(255,255,255)" fill-opacity="1.0">
//               </rect>
//               <g transform="translate(1.0 1.0 ) ">
//                 <g>
//                   <circle cx="10.5" cy="10.5" r="5.0" fill="rgb(102,194,165)" fill-opacity="1.0" stroke="rgb(255,255,255)" stroke-opacity="1.0" stroke-width="1.5">
//                   </circle>
//                 </g>
//               </g>
//               <rect x="0.0" y="0.0" height="23.0" width="23.0" stroke="rgb(255,255,255)" stroke-opacity="1.0" stroke-width="1.0" fill-opacity="0.0">
//               </rect>
//             </g>
//             <g transform="translate(26.9903027277341 16.05 ) ">
//               <text class="legend-item" y="0.0

// %% [markdown]
// ## App Healthcheck - examination

// %% [markdown]
// <img style="float: left; margin-right:20px;" src="idea.png">  **Tip:** TODO

// %%
import kotlinx.datetime.TimeZone
import kotlinx.datetime.toJavaInstant
import java.text.SimpleDateFormat
import java.time.Duration

val first = df.first().startedAt
val last = df.last().startedAt
//val uptimeInSeconds = Duration.between(first,last).toSeconds()
//val pausedDurationInSeconds:Double=df.filter {event_type=="PauseEvent"}.select{duration}.sum().get("duration") as Double

//val percentage=(pausedDurationInSeconds * 100)/uptimeInSeconds

//println(first)
//println(last)
//println(pausedDurationInSeconds)
//println(percentage)

// %%
//Summarize stop-the-world and concurrent phase time

df.groupBy{event_type}.sum{ duration }.sortByDesc{duration}
// Out:
//         <html>
//         <head>
//             <style type="text/css">
//                 :root {
//     --background: #fff;
//     --background-odd: #f5f5f5;
//     --background-hover: #d9edfd;
//     --header-text-color: #474747;
//     --text-color: #848484;
//     --text-color-dark: #000;
//     --text-color-medium: #737373;
//     --text-color-pale: #b3b3b3;
//     --inner-border-color: #aaa;
//     --bold-border-color: #000;
//     --link-color: #296eaa;
//     --link-color-pale: #296eaa;
//     --link-hover: #1a466c;
// }
//
// :root[theme="dark"], :root [data-jp-theme-light="false"], .dataframe_dark{
//     --background: #303030;
//     --background-odd: #3c3c3c;
//     --background-hover: #464646;
//     --header-text-color: #dddddd;
//     --text-color: #b3b3b3;
//     --text-color-dark: #dddddd;
//     --text-color-medium: #b2b2b2;
//     --text-color-pale: #737373;
//     --inner-border-color: #707070;
//     --bold-border-color: #777777;
//     --link-color: #008dc0;
//     --link-color-pale: #97e1fb;
//     --link-hover: #00688e;
// }
//
// p.dataframe_description {
//     color: var(--text-color-dark);
// }
//
// table.dataframe {
//     font-family: "Helvetica Neue", Helvetica, Arial, sans-serif;
//     font-size: 12px;
//     background-color: var(--background);
//     color: var(--text-color-dark);
//     border: none;
//     border-collapse: collapse;
// }
//
// table.dataframe th, td {
//     padding: 6px;
//     border: 1px solid transparent;
//     text-align: left;
// }
//
// table.dataframe th {
//     background-color: var(--background);
//     color: var(--header-text-color);
// }
//
// table.dataframe td {
//     vertical-align: top;
// }
//
// table.dataframe th.bottomBorder {
//     border-bottom-color: var(--bold-border-color);
// }
//
// table.dataframe tbody > tr:nth-child(odd) {
//     background: var(--background-odd);
// }
//
// table.dataframe tbody > tr:nth-child(even) {
//     background: var(--background);
// }
//
// table.dataframe tbody > tr:hover {
//     background: var(--background-hover);
// }
//
// table.dataframe a {
//     cursor: pointer;
//     color: var(--link-color);
//     text-decoration: none;
// }
//
// table.dataframe tr:hover > td a {
//     color: var(--link-color-pale);
// }
//
// table.dataframe a:hover {
//     color: var(--link-hover);
//     text-decoration: underline;
// }
//
// table.dataframe img {
//     max-width: fit-content;
// }
//
// table.dataframe th.complex {
//     background-color: var(--background);
//     border: 1px solid var(--background);
// }
//
// table.dataframe .leftBorder {
//     border-left-color: var(--inner-border-color);
// }
//
// table.dataframe .rightBorder {
//     border-right-color: var(--inner-border-color);
// }
//
// table.dataframe .rightAlign {
//     text-align: right;
// }
//
// table.dataframe .expanderSvg {
//     width: 8px;
//     height: 8px;
//     margin-right: 3px;
// }
//
// table.dataframe .expander {
//     display: flex;
//     align-items: center;
// }
//
// /* formatting */
//
// table.dataframe .null {
//     color: var(--text-color-pale);
// }
//
// table.dataframe .structural {
//     color: var(--text-color-medium);
//     font-weight: bold;
// }
//
// table.dataframe .dataFrameCaption {
//     font-weight: bold;
// }
//
// table.dataframe .numbers {
//     color: var(--text-color-dark);
// }
//
// table.dataframe td:hover .formatted .structural, .null {
//     color: var(--text-color-dark);
// }
//
// table.dataframe tr:hover .formatted .structural, .null {
//     color: var(--text-color-dark);
// }
//
//
//
//
//             </style>
//         </head>
//         <body>
//
// <table class="dataframe" id="df_-1207959547"></table>
//
// <p class="dataframe_description">DataFrame: rowsCount = 2, columnsCount = 2</p>
//         </body>
//         <script>
//
// /*<!--*/
// call_DataFrame(function() { DataFrame.addTable({ cols: [{ name: "<span title=\"event_type: String\">event_type</span>", children: [], rightAlign: false, values: ["PauseEvent","ConcurrentEvent"] },
// { name: "<span title=\"duration: Double\">duration</span>", children: [], rightAlign: true, values: ["<span class=\"formatted\" title=\"\"><span class=\"numbers\">83785,768000</span></span>","<span class=\"formatted\" title=\"\"><span class=\"numbers\">13320,364000</span></span>"] },
// ], id: -1207959547, rootId: -1207959547, totalRows: 2 } ) });
// /*-->*/
//
// call_DataFrame(function() { DataFrame.renderTable(-1207959547) });
//
//
//         </script>
//         </html>

// %%
df.filter { type=="Young" }.select{cause}.groupBy{cause}.count()
// Out:
//         <html>
//         <head>
//             <style type="text/css">
//                 :root {
//     --background: #fff;
//     --background-odd: #f5f5f5;
//     --background-hover: #d9edfd;
//     --header-text-color: #474747;
//     --text-color: #848484;
//     --text-color-dark: #000;
//     --text-color-medium: #737373;
//     --text-color-pale: #b3b3b3;
//     --inner-border-color: #aaa;
//     --bold-border-color: #000;
//     --link-color: #296eaa;
//     --link-color-pale: #296eaa;
//     --link-hover: #1a466c;
// }
//
// :root[theme="dark"], :root [data-jp-theme-light="false"], .dataframe_dark{
//     --background: #303030;
//     --background-odd: #3c3c3c;
//     --background-hover: #464646;
//     --header-text-color: #dddddd;
//     --text-color: #b3b3b3;
//     --text-color-dark: #dddddd;
//     --text-color-medium: #b2b2b2;
//     --text-color-pale: #737373;
//     --inner-border-color: #707070;
//     --bold-border-color: #777777;
//     --link-color: #008dc0;
//     --link-color-pale: #97e1fb;
//     --link-hover: #00688e;
// }
//
// p.dataframe_description {
//     color: var(--text-color-dark);
// }
//
// table.dataframe {
//     font-family: "Helvetica Neue", Helvetica, Arial, sans-serif;
//     font-size: 12px;
//     background-color: var(--background);
//     color: var(--text-color-dark);
//     border: none;
//     border-collapse: collapse;
// }
//
// table.dataframe th, td {
//     padding: 6px;
//     border: 1px solid transparent;
//     text-align: left;
// }
//
// table.dataframe th {
//     background-color: var(--background);
//     color: var(--header-text-color);
// }
//
// table.dataframe td {
//     vertical-align: top;
// }
//
// table.dataframe th.bottomBorder {
//     border-bottom-color: var(--bold-border-color);
// }
//
// table.dataframe tbody > tr:nth-child(odd) {
//     background: var(--background-odd);
// }
//
// table.dataframe tbody > tr:nth-child(even) {
//     background: var(--background);
// }
//
// table.dataframe tbody > tr:hover {
//     background: var(--background-hover);
// }
//
// table.dataframe a {
//     cursor: pointer;
//     color: var(--link-color);
//     text-decoration: none;
// }
//
// table.dataframe tr:hover > td a {
//     color: var(--link-color-pale);
// }
//
// table.dataframe a:hover {
//     color: var(--link-hover);
//     text-decoration: underline;
// }
//
// table.dataframe img {
//     max-width: fit-content;
// }
//
// table.dataframe th.complex {
//     background-color: var(--background);
//     border: 1px solid var(--background);
// }
//
// table.dataframe .leftBorder {
//     border-left-color: var(--inner-border-color);
// }
//
// table.dataframe .rightBorder {
//     border-right-color: var(--inner-border-color);
// }
//
// table.dataframe .rightAlign {
//     text-align: right;
// }
//
// table.dataframe .expanderSvg {
//     width: 8px;
//     height: 8px;
//     margin-right: 3px;
// }
//
// table.dataframe .expander {
//     display: flex;
//     align-items: center;
// }
//
// /* formatting */
//
// table.dataframe .null {
//     color: var(--text-color-pale);
// }
//
// table.dataframe .structural {
//     color: var(--text-color-medium);
//     font-weight: bold;
// }
//
// table.dataframe .dataFrameCaption {
//     font-weight: bold;
// }
//
// table.dataframe .numbers {
//     color: var(--text-color-dark);
// }
//
// table.dataframe td:hover .formatted .structural, .null {
//     color: var(--text-color-dark);
// }
//
// table.dataframe tr:hover .formatted .structural, .null {
//     color: var(--text-color-dark);
// }
//
//
//
//
//             </style>
//         </head>
//         <body>
//
// <table class="dataframe" id="df_-1207959546"></table>
//
// <p class="dataframe_description">DataFrame: rowsCount = 2, columnsCount = 2</p>
//         </body>
//         <script>
//
// /*<!--*/
// call_DataFrame(function() { DataFrame.addTable({ cols: [{ name: "<span title=\"cause: String\">cause</span>", children: [], rightAlign: false, values: ["G1_EVACUATION_PAUSE","GC_LOCKER"] },
// { name: "<span title=\"count: Int\">count</span>", children: [], rightAlign: true, values: ["<span class=\"formatted\" title=\"\"><span class=\"numbers\">11502</span></span>","<span class=\"formatted\" title=\"\"><span class=\"numbers\">44</span></span>"] },
// ], id: -1207959546, rootId: -1207959546, totalRows: 2 } ) });
// /*-->*/
//
// call_DataFrame(function() { DataFrame.renderTable(-1207959546) });
//
//
//         </script>
//         </html>

// %% [markdown]
// # Part V - Analysis of SafePoints

// %% [markdown]
// <img style="float: left; margin-right:20px;" src="idea.png">  **Tip:** TODO

// %% [markdown]
// # Part VI - Analysis of Heap occupancy

// %% [markdown]
// <img style="float: left; margin-right:20px;" src="idea.png">  **Tip:** TODO

// %%
df.filter{type=="Young"}.sortBy{startedAt}.plot {
    points {        
        x(startedAt)
        y(heap_occupancy_after_coll)
        size = 1.0
        layout{
            size = 2000 to 950
        }
    }
}
// Out:
//             <script type="text/javascript" data-lets-plot-script="library" src="https://cdn.jsdelivr.net/gh/JetBrains/lets-plot@v3.1.0/js-package/distr/lets-plot.min.js"></script>
//                <div id="VTDXOh"></div>
//    <script type="text/javascript" data-lets-plot-script="plot">
//        var plotSpec={
// "mapping":{
// },
// "data":{
// "heap_occupancy_after_coll":[177152.0,177152.0,178176.0,177152.0,178176.0,178176.0,178176.0,178176.0,178176.0,178176.0,179200.0,179200.0,179200.0,179200.0,179200.0,179200.0,179200.0,179200.0,180224.0,180224.0,179200.0,180224.0,180224.0,180224.0,180224.0,180224.0,180224.0,180224.0,180224.0,181248.0,181248.0,181248.0,181248.0,181248.0,181248.0,181248.0,181248.0,182272.0,181248.0,181248.0,182272.0,182272.0,182272.0,182272.0,182272.0,182272.0,182272.0,182272.0,182272.0,183296.0,182272.0,183296.0,183296.0,183296.0,183296.0,183296.0,183296.0,183296.0,184320.0,184320.0,185344.0,184320.0,185344.0,184320.0,184320.0,185344.0,185344.0,184320.0,185344.0,184320.0,184320.0,184320.0,184320.0,184320.0,185344.0,185344.0,185344.0,185344.0,185344.0,185344.0,186368.0,185344.0,185344.0,186368.0,186368.0,186368.0,186368.0,186368.0,186368.0,186368.0,186368.0,186368.0,186368.0,186368.0,187392.0,186368.0,187392.0,187392.0,187392.0,187392.0,187392.0,187392.0,187392.0,187392.0,188416.0,188416.0,188416.0,188416.0,188416.0,188416.0,189440.0,188416.0,189440.0,189440.0,189440.0,189440.0,189440.0,189440.0,189440.0,189440.0,190464.0,190464.0,190464.0,190464.0,190464.0,190464.0,190464.0,191488.0,190464.0,190464.0,191488.0,191488.0,191488.0,191488.0,191488.0,191488.0,192512.0,191488.0,191488.0,192512.0,192512.0,192512.0,192512.0,192512.0,193536.0,193536.0,193536.0,193536.0,193536.0,193536.0,193536.0,193536.0,193536.0,193536.0,193536.0,194560.0,194560.0,195584.0,194560.0,184320.0,132096.0,131072.0,132096.0,132096.0,132096.0,132096.0,132096.0,132096.0,132096.0,132096.0,132096.0,133120.0,133120.0,132096.0,133120.0,133120.0,134144.0,133120.0,133120.0,133120.0,133120.0,133120.0,133120.0,134144.0,134144.0,134144.0,134144.0,134144.0,134144.0,134144.0,134144.0,134144.0,134144.0,135168.0,134144.0,135168.0,135168.0,135168.0,135168.0,135168.0,135168.0,135168.0,135168.0,135168.0,135168.0,136192.0,136192.0,136192.0,136192.0,136192.0,136192.0,136192.0,137216.0,136192.0,136192.0,137216.0,137216.0,137216.0,137216.0,137216.0,137216.0,138240.0,137216.0,137216.0,138240.0,137216.0,138240.0,138240.0,138240.0,138240.0,138240.0,138240.0,138240.0,138240.0,138240.0,138240.0,139264.0,139264.0,139264.0,139264.0,139264.0,139264.0,139264.0,139264.0,139264.0,139264.0,139264.0,140288.0,140288.0,140288.0,140288.0,140288.0,140288.0,140288.0,140288.0,140288.0,141312.0,141312.0,141312.0,141312.0,141312.0,141312.0,141312.0,141312.0,141312.0,141312.0,142336.0,141312.0,142336.0,142336.0,143360.0,142336.0,142336.0,142336.0,142336.0,142336.0,142336.0,143360.0,143360.0,143360.0,143360.0,143360.0,143360.0,143360.0,143360.0,143360.0,143360.0,144384.0,143360.0,144384.0,144384.0,144384.0,144384.0,145408.0,144384.0,144384.0,144384.0,144384.0,145408.0,145408.0,144384.0,145408.0,145408.0,145408.0,145408.0,145408.0,145408.0,145408.0,146432.0,146432.0,146432.0,146432.0,146432.0,146432.0,146432.0,147456.0,147456.0,147456.0,147456.0,147456.0,147456.0,147456.0,147456.0,147456.0,148480.0,148480.0,148480.0,148480.0,148480.0,148480.0,148480.0,148480.0,148480.0,148480.0,148480.0,149504.0,149504.0,149504.0,149504.0,149504.0,150528.0,149504.0,149504.0,149504.0,150528.0,150528.0,150528.0,150528.0,150528.0,150528.0,150528.0,150528.0,150528.0,151552.0,151552.0,150528.0,151552.0,152576.0,151552.0,151552.0,151552.0,151552.0,151552.0,151552.0,152576.0,152576.0,152576.0,152576.0,152576.0,152576.0,152576.0,152576.0,152576.0,152576.0,152576.0,153600.0,153600.0,153600.0,153600.0,153600.0,153600.0,153600.0,153600.0,153600.0,153600.0,154624.0,154624.0,154624.0,154624.0,154624.0,154624.0,154624.0,154624.0,154624.0,155648.0,155648.0,155648.0,155648.0,155648.0,155648.0,155648.0,155648.0,155648.0,155648.0,155648.0,156672.0,156672.0,156672.0,155648.0,156672.0,156672.0,156672.0,156672.0,156672.0,156672.0,156672.0,156672.0,156672.0,156672.0,157696.0,157696.0,157696.0,157696.0,157696.0,157696.0,157696.0,157696.0,157696.0,157696.0,157696.0,157696.0,158720.0,158720.0,158720.0,158720.0,158720.0,158720.0,158720.0,159744.0,158720.0,159744.0,15 ...
